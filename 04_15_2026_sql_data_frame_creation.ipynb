# %% [markdown]
# #I. Notebook Description: Data Processing and Dashboard Creation for Feedstuff Analysis
#
# This notebook details the comprehensive process of loading, cleaning, and preparing feedstuff analysis data from four distinct subsets, followed by the compilation of aggregated dashboards for both gas production and nutritional values. Initially, data from CSV files for information samples, gas production, and nutrition are loaded into pandas DataFrames. A series of cleaning functions are then applied to standardize data, including removing header duplicates, normalizing ID suffixes (e.g., `-1`), enforcing consistent lab ID formats (e.g., FXX-XXXX), and mapping functional groups to a unified taxonomy (e.g., 'Grass', 'Shrub_Trees', 'Herbaceous_legumes'). SQL queries are used to join the cleaned information samples with gas production and nutrition data, generating sorted and consolidated DataFrames (e.g., `subset_X_gas_sorted_by_sql`, `subset_X_nutrition_sorted_by_sql`). These subset-specific DataFrames are subsequently concatenated into master DataFrames (e.g., `subsets_1_2_3_4_gas_sorted_by_sql`, `subsets_1_2_3_4_nutrition_sorted_by_sql`). Finally, dashboard-ready DataFrames are created by converting relevant columns to appropriate types and aggregating numerical features by `id` (calculating mean values) and retaining the first occurrence for categorical features, resulting in summarized datasets such as `subsets_1_2_3_4_gas_dashboard_complete` and `subsets_1_2_3_4_nutrition_dashboard_complete`.

# %% [markdown]
# # II. Libraries

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import sqlite3

# %% [markdown]
# # III. Cleaning functions

# %%
# Function to remove the first row (duplicated original column names)
def remove_first_row(df):
    return df.iloc[1:, :].copy()

# Usage:
# subset_1_information_samples = remove_first_row(subset_1_information_samples)

# %%
# Function to remove '-1' suffix from IDs
def remove_minus_one_suffix(series):
    return (
        series
        .astype(str)
        .str.replace(r'-1$', '', regex=True)  # Remove trailing -1
    )


# Usage:
# subset_1_information_samples['10_gene_bank_breeding_program_id'] = remove_minus_one_suffix(subset_1_information_samples['10_gene_bank_breeding_program_id'])

# %%
# Function to clean and standardize lab/sample IDs to FXX-XXXX format
def clean_lab_ids(series):
    return (
        series
        .astype(str)
        .str.replace(r'\s+', '-', regex=True)                 # Replace spaces with -
        .str.replace(r'^(F\d{2})(\d+)', r'\1-\2', regex=True) # Format FXX-XXXX
    )


# Usage:
# subset_1_information_samples['10_ciat_lab_id'] = clean_lab_ids(subset_1_information_samples['10_ciat_lab_id'])

# %%
# Function to clean and standardize Gene Bank - Breeding program IDs
def clean_standardize_ids(series):
    return (
        series
        .astype(str)
        .str.strip()                                           # Remove leading/trailing spaces
        .str.replace(r'[_\s]+', '-', regex=True)               # Replace spaces/underscores with -
        .str.replace(r'([A-Za-z])(\d)', r'\1-\2', regex=True)  # Letter followed by number
        .str.replace(r'(\d)([A-Za-z])', r'\1-\2', regex=True)  # Number followed by letter
        .str.replace(r'-+', '-', regex=True)                   # Remove repeated -
        .str.replace(r'^-|-$', '', regex=True)                 # Remove leading/trailing -
    )

# %% [markdown]
# # 1. Subset 1

# %% [markdown]
# ## 1.1. Loading data

# %%
# Load the CSVs from Drive into pandas DataFrames
subset_1_information_samples = pd.read_csv('/content/drive/MyDrive/lmf/data/04_15_2026_sql_data_frame_creation/subset_1/csv/10_information_samples.csv', encoding='latin1')
subset_1_gas_prod = pd.read_csv('/content/drive/MyDrive/lmf/data/04_15_2026_sql_data_frame_creation/subset_1/csv/31_gas_prod.csv', encoding='latin1')
subset_1_nutrition = pd.read_csv('/content/drive/MyDrive/lmf/data/04_15_2026_sql_data_frame_creation/subset_1/csv/40_result_nutrition_raw_data_vf.csv', encoding='latin1')

# %% [markdown]
# ## 1.2. Cleaning and formatting dataframes

# %%
# Clean first row containing orignal column names from excel files
subset_1_information_samples = remove_first_row(subset_1_information_samples)
subset_1_gas_prod = remove_first_row(subset_1_gas_prod)
subset_1_nutrition = remove_first_row(subset_1_nutrition)

# Remove '-1' tail from id columns
subset_1_information_samples['10_gene_bank_breeding_program_id'] = remove_minus_one_suffix(subset_1_information_samples['10_gene_bank_breeding_program_id'])
subset_1_gas_prod['31_gene_bank_id'] = remove_minus_one_suffix(subset_1_gas_prod['31_gene_bank_id'])
subset_1_nutrition['40nutrition_gene_bank_breeding_program_id'] = remove_minus_one_suffix(subset_1_nutrition['40nutrition_gene_bank_breeding_program_id'])

# Add '-' to lab ids and ensure correct format FXX-XXXX
subset_1_information_samples['10_ciat_lab_id'] = clean_lab_ids(subset_1_information_samples['10_ciat_lab_id'])
subset_1_gas_prod['31_ciat_id'] = clean_lab_ids(subset_1_gas_prod['31_ciat_id'])
subset_1_nutrition['40nutrition_sample_id'] = clean_lab_ids(subset_1_nutrition['40nutrition_sample_id'])

# Clean and standardize gene bank and breeding program ids
subset_1_information_samples['10_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_1_information_samples['10_gene_bank_breeding_program_id'])
subset_1_gas_prod['31_gene_bank_id'] = clean_standardize_ids(subset_1_gas_prod['31_gene_bank_id'])
subset_1_nutrition['40nutrition_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_1_nutrition['40nutrition_gene_bank_breeding_program_id'])

# %%
# Check functional groups categories
subset_1_information_samples['10_functional_group'].unique()
# Out:
# array(['Herbaceous', 'Climber', 'Shrub', 'Tree', 'Grass', 'FAO', 'Legume',
#        'Browse', 'Forage', 'Concentrate', 'Grasses', nan], dtype=object)

# %%
# Define the mapping for functional groups
functional_group_mapping = {
    'Grasses': 'Grass',
    'grasses': 'Grass',
    'Shrub': 'Shrub_Trees',
    'Shrub/tree': 'Shrub_Trees',
    'Shrub/Tree': 'Shrub_Trees',
    'Shrub/Trees': 'Shrub_Trees',
    'Shrub_Trees': 'Shrub_Trees',
    'Tree': 'Shrub_Trees',
    'Arbustiva ': 'Shrub_Trees',
    'Herbáceas': 'Herbaceous_legumes',
    'Herbáceas ': 'Herbaceous_legumes',
    'Herbaceous': 'Herbaceous_legumes',
    'Herbaceous legume': 'Herbaceous_legumes',
    'Climber': 'Herbaceous_legumes',
    'Legume': 'Herbaceous_legumes'
}

# Apply the mapping to centers datt
subset_1_information_samples['10_functional_group'] = subset_1_information_samples['10_functional_group'].replace(functional_group_mapping)

print('Updated functional group counts for subset_1_information_samples:')
display(subset_1_information_samples['10_functional_group'].value_counts())
# Out:
# Updated functional group counts for subset_1_information_samples:
# 10_functional_group
# Herbaceous_legumes    145
# Grass                  72
# Shrub_Trees            31
# Concentrate             7
# Forage                  6
# Browse                  4
# FAO                     1
# Name: count, dtype: int64

# %% [markdown]
# ## 1.3. SQL query and dataframe creation

# %% [markdown]
# ### 1.3.1. Gas

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_1_information_samples.to_sql('subset_1_information_samples', conn_new, if_exists='replace', index=False)
subset_1_gas_prod.to_sql('subset_1_gas_prod', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_1_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner', '10_set_ciat',
#        '10_ciat_lab_id', '10_gene_bank_breeding_program_id', '10_genus',
#        '10_species', '10_tax_name', '10_family', '10_order',
#        '10_functional_group', '10_remarks', '10_id_lab'],
#       dtype='object')

# %%
subset_1_gas_prod.columns
# Out:
# Index(['31_no', '31_date', '31_requisitioner', '31_gene_bank_id', '31_genus',
#        '31_species', '31_tax_name', '31_family', '31_order',
#        '31_functional_group', '31_ciat_id', '31_set_ciat', '31_batch',
#        '31_run', '31_replication', '31_syrange_no', '31_sample_weight_g',
#        '31_dm_incubated_mg', '31_digested_feed_mg', '31_time_0h',
#        '31_gas_0h_ml', '31_time_8h', '31_gas_8h_ml', '31_ch4_8h_percentage',
#        '31_v8_push_back_ml', '31_time_24_h', '31_gas_24h_ml',
#        '31_ch4_24h_percentage', '31_remarks', '31_gp_8h_ml', '31_gp_8_24h_ml',
#        '31_net_gas_8h_ml', '31_net_gas_24h_ml2', '31_net_gas_24h_ml',
#        '31_ch4_8h_ml', '31_ch4_8_24h_ml', '31_ch4_24h_ml',
#        '31_gas_ml_g_dm_incubated_24h', '31_percentage_dmd_truly_digestibility',
#        '31_part_fact', '31_ch4_ml_in_gas_8h', '31_ch4_ml_in_gas_24h',
#        '31_ch4_ml_g_dm_incubaed_24h', '31_ch4_ml_g_dmd_24h',
#        '31_ch4_ml_g_ndf_digested_in_24h', '31_ch4_g_g_dm_incubated_24h',
#        '31_ch4_g_g_dmd_24h'],
#       dtype='object')

# %%
subset_1_gas_prod.iloc[:4,4:15]
# Out:
#      31_genus    31_species              31_tax_name 31_family 31_order  \
# 1       Blank         Blank                    Blank     Blank    Blank
# 2       Blank         Blank                    Blank     Blank    Blank
# 3  Indigofera  suffruticosa  Indigofera suffruticosa  Fabaceae  Fabales
# 4  Indigofera  suffruticosa  Indigofera suffruticosa  Fabaceae  Fabales
#
#   31_functional_group 31_ciat_id 31_set_ciat 31_batch 31_run 31_replication
# 1               Blank      Blank           1        1      1              1
# 2               Blank      Blank           1        1      1              2
# 3          Herbaceous   F24-3416           1        1      1              1
# 4          Herbaceous   F24-3416           1        1      1              2

# %%
query_combined = """
SELECT
    s1g."31_no" as no,
    s1i."10_requisitioner" as requisitioner,
    s1i."10_ciat_lab_id" as id_lab,
    s1i."10_gene_bank_breeding_program_id" as id,
    s1i."10_order" as tax_order,
    s1i."10_family" as family,
    s1i."10_genus" as genus,
    s1i."10_species" as species,
    s1i."10_tax_name" as tax_name,
    s1i."10_functional_group" as functional_group,
    s1g."31_set_ciat" as set_ciat,
    s1g."31_batch" as batch,
    s1g."31_run" as run,
    s1g."31_replication" as replication,
    s1g."31_syrange_no" as syrange,
    s1g."31_net_gas_8h_ml" as net_gas_8h_ml,
    s1g."31_net_gas_24h_ml" as net_gas_24h_ml,
    s1g."31_ch4_8h_ml" as ch4_8h_ml,
    s1g."31_ch4_24h_ml" as ch4_24h_ml,
    s1g."31_ch4_8h_percentage" as ch4_percentage_in_gas_8h,
    s1g."31_ch4_ml_in_gas_24h" as ch4_percentage_in_gas_24h,
    s1g."31_gas_ml_g_dm_incubated_24h" as gas_ml_g_dm_incubated_24h,
    s1g."31_ch4_ml_g_ndf_digested_in_24h" as ch4_ml_g_ndf_digested_24h,
    s1g."31_ch4_ml_g_dmd_24h" as methane_intensity,
    s1g."31_percentage_dmd_truly_digestibility" as tddm
FROM
    subset_1_information_samples AS s1i
JOIN
    subset_1_gas_prod AS s1g
ON
    s1i."10_ciat_lab_id" = s1g."31_ciat_id"
ORDER BY
    CAST(no AS INTEGER) ASC
"""

subset_1_gas_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_1_gas_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#         no requisitioner    id_lab                     id    tax_order  \
# 0        3  Genetic bank  F24-3416                ABC-705      Fabales
# 1        4  Genetic bank  F24-3416                ABC-705      Fabales
# 2        5  Genetic bank  F24-3416                ABC-705      Fabales
# 3        6  Genetic bank  F24-3417                ABC-707      Fabales
# 4        7  Genetic bank  F24-3417                ABC-707      Fabales
# ...    ...           ...       ...                    ...          ...
# 3595  2302           LMF  F25-0018  Homenheim-Concentrate  Concentrate
# 3596  2302           LMF  F25-0018  Homenheim-Concentrate  Concentrate
# 3597  2302           LMF  F25-0018  Homenheim-Concentrate  Concentrate
# 3598  2302           LMF  F25-0018  Homenheim-Concentrate  Concentrate
# 3599  2302           LMF  F25-0018  Homenheim-Concentrate  Concentrate
#
#            family        genus       species                 tax_name  \
# 0        Fabaceae   Indigofera  suffruticosa  Indigofera suffruticosa
# 1        Fabaceae   Indigofera  suffruticosa  Indigofera suffruticosa
# 2        Fabaceae   Indigofera  suffruticosa  Indigofera suffruticosa
# 3        Fabaceae  Alysicarpus   ovalifolius  Alysicarpus ovalifolius
# 4        Fabaceae  Alysicarpus   ovalifolius  Alysicarpus ovalifolius
# ...           ...          ...           ...                      ...
# 3595  Concentrate    Homenheim   Concentrate    Homenheim Concentrate
# 3596  Concentrate    Homenheim   Concentrate    Homenheim Concentrate
# 3597  Concentrate    Homenheim   Concentrate    Homenheim Concentrate
# 3598  Concentrate    Homenheim   Concentrate    Homenheim Concentrate
# 3599  Concentrate    Homenheim   Concentrate    Homenheim Concentrate
#
#         functional_group  ... net_gas_8h_ml net_gas_24h_ml    ch4_8h_ml  \
# 0     Herbaceous_legumes  ...   28.17271507    62.57735271   4.00052554
# 1     Herbaceous_legumes  ...   28.17271507    61.24984258   4.22590726
# 2     Herbaceous_legumes  ...    29.5002252    63.01985609  4.071031078
# 3     Herbaceous_legumes  ...   30.82773534    67.00238649  4.285055212
# 4     Herbaceous_legumes  ...    29.5002252    66.11737974  4.130031528
# ...                  ...  ...           ...            ...          ...
# 3595         Concentrate  ...   29.79522746    56.45605598  4.528874573
# 3596         Concentrate  ...   29.79522746    56.45605598  4.528874573
# 3597         Concentrate  ...   29.79522746    56.45605598  4.528874573
# 3598         Concentrate  ...   29.79522746    56.45605598  4.528874573
# 3599         Concentrate  ...   29.79522746    56.45605598  4.528874573
#
#        ch4_24h_ml ch4_percentage_in_gas_8h ch4_percentage_in_gas_24h  \
# 0     11.15669017                     14.2               17.82863877
# 1     11.20518116                       15               18.29422035
# 2     10.97607504                     13.8               17.41685196
# 3     11.30293754                     13.9               16.86945515
# 4     11.23375951                       14               16.99063023
# ...           ...                      ...                       ...
# 3595  9.221180394                     15.2               16.33337688
# 3596  9.221180394                     15.2               16.33337688
# 3597  9.221180394                     15.2               16.33337688
# 3598  9.221180394                     15.2               16.33337688
# 3599  9.221180394                     15.2               16.33337688
#
#      gas_ml_g_dm_incubated_24h ch4_ml_g_ndf_digested_24h methane_intensity  \
# 0                  135.9455554               227.8476704       37.05164527
# 1                   133.168047               270.0095702       38.18507666
# 2                  137.0163711               249.4607864       37.08835285
# 3                  148.7414028               175.9559634        41.7140678
# 4                  146.6594117               149.5197103         39.832832
# ...                        ...                       ...               ...
# 3595               251.6736968                   #DIV/0!       67.10098338
# 3596               251.6736968                   #DIV/0!       67.10098338
# 3597               251.6736968                   #DIV/0!       67.10098338
# 3598               251.6736968                   #DIV/0!       67.10098338
# 3599               251.6736968                   #DIV/0!       67.10098338
#
#              tddm
# 0     65.41475234
# 1     63.79993989
# 2     64.34348434
# 3     60.15204354
# 4     62.55733546
# ...           ...
# 3595  61.26111917
# 3596  61.26111917
# 3597  61.26111917
# 3598  61.26111917
# 3599  61.26111917
#
# [3600 rows x 25 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_1_gas_sorted_by_sql = subset_1_gas_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_1_gas_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_1_gas_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (2277, 25)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab       id tax_order    family        genus  \
# 0  3  Genetic bank  F24-3416  ABC-705   Fabales  Fabaceae   Indigofera
# 1  4  Genetic bank  F24-3416  ABC-705   Fabales  Fabaceae   Indigofera
# 2  5  Genetic bank  F24-3416  ABC-705   Fabales  Fabaceae   Indigofera
# 3  6  Genetic bank  F24-3417  ABC-707   Fabales  Fabaceae  Alysicarpus
# 4  7  Genetic bank  F24-3417  ABC-707   Fabales  Fabaceae  Alysicarpus
#
#         species                 tax_name    functional_group  ...  \
# 0  suffruticosa  Indigofera suffruticosa  Herbaceous_legumes  ...
# 1  suffruticosa  Indigofera suffruticosa  Herbaceous_legumes  ...
# 2  suffruticosa  Indigofera suffruticosa  Herbaceous_legumes  ...
# 3   ovalifolius  Alysicarpus ovalifolius  Herbaceous_legumes  ...
# 4   ovalifolius  Alysicarpus ovalifolius  Herbaceous_legumes  ...
#
#   net_gas_8h_ml net_gas_24h_ml    ch4_8h_ml   ch4_24h_ml  \
# 0   28.17271507    62.57735271   4.00052554  11.15669017
# 1   28.17271507    61.24984258   4.22590726  11.20518116
# 2    29.5002252    63.01985609  4.071031078  10.97607504
# 3   30.82773534    67.00238649  4.285055212  11.30293754
# 4    29.5002252    66.11737974  4.130031528  11.23375951
#
#   ch4_percentage_in_gas_8h ch4_percentage_in_gas_24h  \
# 0                     14.2               17.82863877
# 1                       15               18.29422035
# 2                     13.8               17.41685196
# 3                     13.9               16.86945515
# 4                       14               16.99063023
#
#   gas_ml_g_dm_incubated_24h ch4_ml_g_ndf_digested_24h methane_intensity  \
# 0               135.9455554               227.8476704       37.05164527
# 1                133.168047               270.0095702       38.18507666
# 2               137.0163711               249.4607864       37.08835285
# 3               148.7414028               175.9559634        41.7140678
# 4               146.6594117               149.5197103         39.832832
#
#           tddm
# 0  65.41475234
# 1  63.79993989
# 2  64.34348434
# 3  60.15204354
# 4  62.55733546
#
# [5 rows x 25 columns]

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 1
subset_1_gas_sorted_by_sql.insert(0, 'subset', 1)

print("DataFrame with new 'subset' column:")
display(subset_1_gas_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab       id tax_order    family  \
# 0       1  3  Genetic bank  F24-3416  ABC-705   Fabales  Fabaceae
# 1       1  4  Genetic bank  F24-3416  ABC-705   Fabales  Fabaceae
# 2       1  5  Genetic bank  F24-3416  ABC-705   Fabales  Fabaceae
# 3       1  6  Genetic bank  F24-3417  ABC-707   Fabales  Fabaceae
# 4       1  7  Genetic bank  F24-3417  ABC-707   Fabales  Fabaceae
#
#          genus       species                 tax_name  ... net_gas_8h_ml  \
# 0   Indigofera  suffruticosa  Indigofera suffruticosa  ...   28.17271507
# 1   Indigofera  suffruticosa  Indigofera suffruticosa  ...   28.17271507
# 2   Indigofera  suffruticosa  Indigofera suffruticosa  ...    29.5002252
# 3  Alysicarpus   ovalifolius  Alysicarpus ovalifolius  ...   30.82773534
# 4  Alysicarpus   ovalifolius  Alysicarpus ovalifolius  ...    29.5002252
#
#   net_gas_24h_ml    ch4_8h_ml   ch4_24h_ml ch4_percentage_in_gas_8h  \
# 0    62.57735271   4.00052554  11.15669017                     14.2
# 1    61.24984258   4.22590726  11.20518116                       15
# 2    63.01985609  4.071031078  10.97607504                     13.8
# 3    67.00238649  4.285055212  11.30293754                     13.9
# 4    66.11737974  4.130031528  11.23375951                       14
#
#   ch4_percentage_in_gas_24h gas_ml_g_dm_incubated_24h  \
# 0               17.82863877               135.9455554
# 1               18.29422035                133.168047
# 2               17.41685196               137.0163711
# 3               16.86945515               148.7414028
# 4               16.99063023               146.6594117
#
#   ch4_ml_g_ndf_digested_24h methane_intensity         tddm
# 0               227.8476704       37.05164527  65.41475234
# 1               270.0095702       38.18507666  63.79993989
# 2               249.4607864       37.08835285  64.34348434
# 3               175.9559634        41.7140678  60.15204354
# 4               149.5197103         39.832832  62.55733546
#
# [5 rows x 26 columns]

# %%
#subset_1_gas_sorted_by_sql.to_csv("/content/drive/MyDrive/lmf/output/04_15_2026_sql_data_frame_creation/subset_1_gas_sorted_by_sql.csv", index=None)

# %% [markdown]
# ### 1.3.2. Nutrition

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_1_information_samples.to_sql('subset_1_information_samples', conn_new, if_exists='replace', index=False)
subset_1_nutrition.to_sql('subset_1_nutrition', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_1_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner', '10_set_ciat',
#        '10_ciat_lab_id', '10_gene_bank_breeding_program_id', '10_genus',
#        '10_species', '10_tax_name', '10_family', '10_order',
#        '10_functional_group', '10_remarks', '10_id_lab'],
#       dtype='object')

# %%
subset_1_nutrition.columns
# Out:
# Index(['40nutrition_no', '40nutrition_date', '40nutrition_requisitioner',
#        '40nutrition_set_ciat', '40nutrition_sample_id',
#        '40nutrition_gene_bank_breeding_program_id', '40nutrition_genus',
#        '40nutrition_species', '40nutrition_tax_name',
#        '40nutrition_dm_percentage', '40nutrition_av_dm_105',
#        '40nutrition_ash_dm', '40nutrition_av_ash_percentage',
#        '40nutrition_om_percentage', '40nutrition_om_percentage.1',
#        '40nutrition_pc_percentage_dm', '40nutrition_av_pc_percentage',
#        '40nutrition_adf_percentage_dm', '40nutrition_av_adf_percentage_dm',
#        '40nutrition_ndf_percentage_dm', '40nutrition_av_ndf_percentage_dm'],
#       dtype='object')

# %%
query_combined = """
SELECT
    s1n."40nutrition_no" as no,
    s1i."10_requisitioner" as requisitioner,
    s1i."10_ciat_lab_id" as id_lab,
    s1i."10_gene_bank_breeding_program_id" as id,
    s1i."10_order" as tax_order,
    s1i."10_family" as family,
    s1i."10_genus" as genus,
    s1i."10_species" as species,
    s1i."10_tax_name" as tax_name,
    s1i."10_functional_group" as functional_group,
    s1n."40nutrition_set_ciat" as set_ciat,
    s1n."40nutrition_dm_percentage" as dm_percentage,
    s1n."40nutrition_ash_dm" as ash_dm,
    s1n."40nutrition_om_percentage" as om_percentage,
    s1n."40nutrition_pc_percentage_dm" as pc_percentage_dm,
    s1n."40nutrition_adf_percentage_dm" as adf_percentage_dm,
    s1n."40nutrition_ndf_percentage_dm" as ndf_percentage_dm



FROM
    subset_1_information_samples AS s1i
JOIN
    subset_1_nutrition AS s1n
ON
    s1i."10_ciat_lab_id" = s1n."40nutrition_sample_id"
ORDER BY
    CAST(no AS INTEGER) ASC
"""

subset_1_nutrition_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_1_nutrition_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#       no requisitioner    id_lab         id tax_order    family         genus  \
# 0      1  Genetic bank  F24-3416    ABC-705   Fabales  Fabaceae    Indigofera
# 1      2  Genetic bank  F24-3416    ABC-705   Fabales  Fabaceae    Indigofera
# 2      3  Genetic bank  F24-3417    ABC-707   Fabales  Fabaceae   Alysicarpus
# 3      4  Genetic bank  F24-3417    ABC-707   Fabales  Fabaceae   Alysicarpus
# 4      5  Genetic bank  F24-3418    ABC-712   Fabales  Fabaceae      Clitoria
# ..   ...           ...       ...        ...       ...       ...           ...
# 465  376  Genetic bank  F24-3533  ABC-32246   Fabales  Fabaceae  Chamaecrista
# 466  377  Genetic bank  F24-3534  ABC-32365   Fabales  Fabaceae    Desmanthus
# 467  378  Genetic bank  F24-3534  ABC-32365   Fabales  Fabaceae    Desmanthus
# 468  379  Genetic bank  F24-3535  ABC-32373   Fabales  Fabaceae    Desmanthus
# 469  380  Genetic bank  F24-3535  ABC-32373   Fabales  Fabaceae    Desmanthus
#
#           species                 tax_name    functional_group set_ciat  \
# 0    suffruticosa  Indigofera suffruticosa  Herbaceous_legumes        1
# 1    suffruticosa  Indigofera suffruticosa  Herbaceous_legumes        1
# 2     ovalifolius  Alysicarpus ovalifolius  Herbaceous_legumes        1
# 3     ovalifolius  Alysicarpus ovalifolius  Herbaceous_legumes        1
# 4        ternatea        Clitoria ternatea  Herbaceous_legumes        1
# ..            ...                      ...                 ...      ...
# 465     nictitans   Chamaecrista nictitans  Herbaceous_legumes       10
# 466      virgatus      Desmanthus virgatus         Shrub_Trees       10
# 467      virgatus      Desmanthus virgatus         Shrub_Trees       10
# 468     pubescens     Desmanthus pubescens         Shrub_Trees       10
# 469     pubescens     Desmanthus pubescens         Shrub_Trees       10
#
#     dm_percentage       ash_dm om_percentage pc_percentage_dm  \
# 0     91.93080692  12.72569067   87.27430933      33.01052157
# 1           92.01  12.62906206   87.37093794      33.01052157
# 2     90.64280716  11.91132679   88.08867321      25.39749175
# 3     89.54209158  12.23760607   87.76239393      25.39749175
# 4     91.25174965   7.71337789   92.28662211      31.19171324
# ..            ...          ...           ...              ...
# 465         91.56         8.03         91.97            26.83
# 466         90.87         7.56         92.44            30.19
# 467         90.98         7.45         92.55            30.19
# 468          92.3         8.61         91.39             28.4
# 469         92.37         8.71         91.29             28.4
#
#     adf_percentage_dm ndf_percentage_dm
# 0         28.48961421       45.21032889
# 1         27.61265655       45.23511907
# 2         26.19631971       54.55645373
# 3         24.68485778       53.66007735
# 4         26.67696802       55.20337963
# ..                ...               ...
# 465       26.85895517       81.72281094
# 466       28.08362098       77.86276485
# 467       29.38322659       73.65060102
# 468       20.16866025       76.26718922
# 469       19.81890361       79.50433545
#
# [470 rows x 17 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_1_nutrition_sorted_by_sql = subset_1_nutrition_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_1_nutrition_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_1_nutrition_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (388, 17)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab       id tax_order    family        genus  \
# 0  1  Genetic bank  F24-3416  ABC-705   Fabales  Fabaceae   Indigofera
# 1  2  Genetic bank  F24-3416  ABC-705   Fabales  Fabaceae   Indigofera
# 2  3  Genetic bank  F24-3417  ABC-707   Fabales  Fabaceae  Alysicarpus
# 3  4  Genetic bank  F24-3417  ABC-707   Fabales  Fabaceae  Alysicarpus
# 4  5  Genetic bank  F24-3418  ABC-712   Fabales  Fabaceae     Clitoria
#
#         species                 tax_name    functional_group set_ciat  \
# 0  suffruticosa  Indigofera suffruticosa  Herbaceous_legumes        1
# 1  suffruticosa  Indigofera suffruticosa  Herbaceous_legumes        1
# 2   ovalifolius  Alysicarpus ovalifolius  Herbaceous_legumes        1
# 3   ovalifolius  Alysicarpus ovalifolius  Herbaceous_legumes        1
# 4      ternatea        Clitoria ternatea  Herbaceous_legumes        1
#
#   dm_percentage       ash_dm om_percentage pc_percentage_dm adf_percentage_dm  \
# 0   91.93080692  12.72569067   87.27430933      33.01052157       28.48961421
# 1         92.01  12.62906206   87.37093794      33.01052157       27.61265655
# 2   90.64280716  11.91132679   88.08867321      25.39749175       26.19631971
# 3   89.54209158  12.23760607   87.76239393      25.39749175       24.68485778
# 4   91.25174965   7.71337789   92.28662211      31.19171324       26.67696802
#
#   ndf_percentage_dm
# 0       45.21032889
# 1       45.23511907
# 2       54.55645373
# 3       53.66007735
# 4       55.20337963

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 1
subset_1_nutrition_sorted_by_sql.insert(0, 'subset', 1)

print("DataFrame with new 'subset' column:")
display(subset_1_nutrition_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab       id tax_order    family  \
# 0       1  1  Genetic bank  F24-3416  ABC-705   Fabales  Fabaceae
# 1       1  2  Genetic bank  F24-3416  ABC-705   Fabales  Fabaceae
# 2       1  3  Genetic bank  F24-3417  ABC-707   Fabales  Fabaceae
# 3       1  4  Genetic bank  F24-3417  ABC-707   Fabales  Fabaceae
# 4       1  5  Genetic bank  F24-3418  ABC-712   Fabales  Fabaceae
#
#          genus       species                 tax_name    functional_group  \
# 0   Indigofera  suffruticosa  Indigofera suffruticosa  Herbaceous_legumes
# 1   Indigofera  suffruticosa  Indigofera suffruticosa  Herbaceous_legumes
# 2  Alysicarpus   ovalifolius  Alysicarpus ovalifolius  Herbaceous_legumes
# 3  Alysicarpus   ovalifolius  Alysicarpus ovalifolius  Herbaceous_legumes
# 4     Clitoria      ternatea        Clitoria ternatea  Herbaceous_legumes
#
#   set_ciat dm_percentage       ash_dm om_percentage pc_percentage_dm  \
# 0        1   91.93080692  12.72569067   87.27430933      33.01052157
# 1        1         92.01  12.62906206   87.37093794      33.01052157
# 2        1   90.64280716  11.91132679   88.08867321      25.39749175
# 3        1   89.54209158  12.23760607   87.76239393      25.39749175
# 4        1   91.25174965   7.71337789   92.28662211      31.19171324
#
#   adf_percentage_dm ndf_percentage_dm
# 0       28.48961421       45.21032889
# 1       27.61265655       45.23511907
# 2       26.19631971       54.55645373
# 3       24.68485778       53.66007735
# 4       26.67696802       55.20337963

# %%
subset_1_nutrition_sorted_by_sql.to_csv("/content/drive/MyDrive/lmf/output/04_15_2026_sql_data_frame_creation/subset_1_nutrition_sorted_by_sql.csv", index=None)

# %% [markdown]
# # 2. Subset 2

# %% [markdown]
# ## 2.1. Loading data

# %%
# Load the CSVs from Drive into pandas DataFrames
subset_2_information_samples = pd.read_csv('/content/drive/MyDrive/lmf/data/04_15_2026_sql_data_frame_creation/subset_2/csv/10_information_samples.csv', encoding='latin1')
subset_2_gas_prod = pd.read_csv('/content/drive/MyDrive/lmf/data/04_15_2026_sql_data_frame_creation/subset_2/csv/31_gas_prod.csv', encoding='latin1')
subset_2_nutrition = pd.read_csv('/content/drive/MyDrive/lmf/data/04_15_2026_sql_data_frame_creation/subset_2/csv/40_result_q_raw_data.csv', encoding='latin1')

# %% [markdown]
# ## 2.2. Cleaning and formatting dataframes

# %%
# Clean first row containing orignal column names from excel files
subset_2_information_samples = remove_first_row(subset_2_information_samples)
subset_2_gas_prod = remove_first_row(subset_2_gas_prod)
subset_2_nutrition = remove_first_row(subset_2_nutrition)

# Remove '-1' tail from id columns
subset_2_information_samples['10_gene_bank_breeding_program_id'] = remove_minus_one_suffix(subset_2_information_samples['10_gene_bank_breeding_program_id'])
subset_2_gas_prod['31_gene_bank_id'] = remove_minus_one_suffix(subset_2_gas_prod['31_gene_bank_id'])
subset_2_nutrition['40qraw_gene_bank_breeding_program_id'] = remove_minus_one_suffix(subset_2_nutrition['40qraw_gene_bank_breeding_program_id'])

# Add '-' to lab ids and ensure correct format FXX-XXXX
subset_2_information_samples['10_ciat_lab_id'] = clean_lab_ids(subset_2_information_samples['10_ciat_lab_id'])
subset_2_gas_prod['31_ciat_id'] = clean_lab_ids(subset_2_gas_prod['31_ciat_id'])
subset_2_nutrition['40qraw_sample_id'] = clean_lab_ids(subset_2_nutrition['40qraw_sample_id'])

# Clean and standardize gene bank and breeding program ids
subset_2_information_samples['10_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_2_information_samples['10_gene_bank_breeding_program_id'])
subset_2_gas_prod['31_gene_bank_id'] = clean_standardize_ids(subset_2_gas_prod['31_gene_bank_id'])
subset_2_nutrition['40qraw_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_2_nutrition['40qraw_gene_bank_breeding_program_id'])

# %%
# Check functional groups categories
subset_2_information_samples['10_functional_group'].unique()
# Out:
# array(['Shrub', 'Herbaceous', 'Climber', 'Forage', 'Concentrate',
#        'Grasses', 'Tree', 'grasses', nan], dtype=object)

# %%
# Define the mapping for functional groups
functional_group_mapping = {
    'Grasses': 'Grass',
    'grasses': 'Grass',
    'Shrub': 'Shrub_Trees',
    'Shrub/tree': 'Shrub_Trees',
    'Shrub/Tree': 'Shrub_Trees',
    'Shrub/Trees': 'Shrub_Trees',
    'Shrub_Trees': 'Shrub_Trees',
    'Tree': 'Shrub_Trees',
    'Arbustiva ': 'Shrub_Trees',
    'Herbáceas': 'Herbaceous_legumes',
    'Herbáceas ': 'Herbaceous_legumes',
    'Herbaceous': 'Herbaceous_legumes',
    'Herbaceous legume': 'Herbaceous_legumes',
    'Climber': 'Herbaceous_legumes',
    'Legume': 'Herbaceous_legumes'
}

# Apply the mapping to centers datt
subset_2_information_samples['10_functional_group'] = subset_2_information_samples['10_functional_group'].replace(functional_group_mapping)

print('Updated functional group counts for subset_2_information_samples:')
display(subset_2_information_samples['10_functional_group'].value_counts())
# Out:
# Updated functional group counts for subset_2_information_samples:
# 10_functional_group
# Grass                 122
# Herbaceous_legumes    109
# Shrub_Trees            29
# Concentrate             9
# Forage                  8
# Name: count, dtype: int64

# %% [markdown]
# ## 2.3. SQL query and dataframe creation

# %% [markdown]
# ### 2.3.1. Gas

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_2_information_samples.to_sql('subset_2_information_samples', conn_new, if_exists='replace', index=False)
subset_2_gas_prod.to_sql('subset_2_gas_prod', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_2_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner',
#        '10_requisitioner_2', '10_set_ciat', '10_ciat_lab_id',
#        '10_gene_bank_breeding_program_id', '10_genus', '10_species',
#        '10_tax_name', '10_family', '10_order', '10_functional_group',
#        '10_remarks', '10_id_lab', '10_remarks.1'],
#       dtype='object')

# %%
subset_2_gas_prod.columns
# Out:
# Index(['31_no', '31_date', '31_requisitioner', '31_gene_bank_id', '31_genus',
#        '31_species', '31_tax_name', '31_family', '31_order',
#        '31_functional_group', '31_ciat_id', '31_set_ciat', '31_batch',
#        '31_run', '31_replication', '31_syrange_no', '31_sample_weight_g',
#        '31_dm_incubated_mg', '31_digested_feed_mg', '31_time_0h',
#        '31_gas_0h_ml', '31_time_8h', '31_gas_8h_ml', '31_ch4_8h_percentage',
#        '31_v8_push_back_ml', '31_time_24h', '31_gas_24h_ml',
#        '31_ch4_24h_percentage', '31_remarks', '31_gp_8h_ml', '31_gp_8_24h_ml',
#        '31_net_gas_8h_ml', '31_net_gas_8_24h_ml2', '31_net_gas_24h_ml',
#        '31_ch4_8h_ml', '31_ch4_8_24h_ml', '31_ch4_24h_ml',
#        '31_gas_ml_g_dm_incubated_24h', '31_percentage_dmd_truly_digestibility',
#        '31_part_fact', '31_ch4_percentage_in_gas_8h',
#        '31_ch4_percentage_in_gas_24h', '31_ch4_ml_g_dm_incubated_24h',
#        '31_ch4_ml_g_dmd_24h', '31_ch4_ml_g_ndf_digested_in_24h',
#        '31_ch4_g_g_dm_incubated_24h', '31_ch4_g_g_dmd_24h'],
#       dtype='object')

# %%
query_combined = """
SELECT
    s2g."31_no" as no,
    s2i."10_requisitioner" as requisitioner,
    s2i."10_ciat_lab_id" as id_lab,
    s2i."10_gene_bank_breeding_program_id" as id,
    s2i."10_order" as tax_order,
    s2i."10_family" as family,
    s2i."10_genus" as genus,
    s2i."10_species" as species,
    s2i."10_tax_name" as tax_name,
    s2i."10_functional_group" as functional_group,
    s2g."31_set_ciat" as set_ciat,
    s2g."31_batch" as batch,
    s2g."31_run" as run,
    s2g."31_replication" as replication,
    s2g."31_syrange_no" as syrange,
    s2g."31_net_gas_8h_ml" as net_gas_8h_ml,
    s2g."31_net_gas_24h_ml" as net_gas_24h_ml,
    s2g."31_ch4_8h_ml" as ch4_8h_ml,
    s2g."31_ch4_24h_ml" as ch4_24h_ml,
    s2g."31_ch4_8h_percentage" as ch4_percentage_in_gas_8h,
    s2g."31_ch4_24h_percentage" as ch4_percentage_in_gas_24h,
    s2g."31_gas_ml_g_dm_incubated_24h" as gas_ml_g_dm_incubated_24h,
    s2g."31_ch4_ml_g_ndf_digested_in_24h" as ch4_ml_g_ndf_digested_24h,
    s2g."31_ch4_ml_g_dmd_24h" as methane_intensity,
    s2g."31_percentage_dmd_truly_digestibility" as tddm
FROM
    subset_2_information_samples AS s2i
JOIN
    subset_2_gas_prod AS s2g
ON
    s2i."10_ciat_lab_id" = s2g."31_ciat_id"
ORDER BY
    CAST(no AS INTEGER) ASC
"""

subset_2_gas_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_2_gas_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#         no requisitioner    id_lab         id tax_order    family       genus  \
# 0        3  Genetic bank  F24-3536  ABC-32379   Fabales  Fabaceae  Desmanthus
# 1        4  Genetic bank  F24-3536  ABC-32379   Fabales  Fabaceae  Desmanthus
# 2        5  Genetic bank  F24-3536  ABC-32379   Fabales  Fabaceae  Desmanthus
# 3        6  Genetic bank  F24-3537  ABC-32380   Fabales  Fabaceae  Desmanthus
# 4        7  Genetic bank  F24-3537  ABC-32380   Fabales  Fabaceae  Desmanthus
# ...    ...           ...       ...        ...       ...       ...         ...
# 4360  2704           LMF  F25-0008   Sample-8    Poales   Poaceae     Cynodon
# 4361  2704           LMF  F25-0008   Sample-8    Poales   Poaceae     Cynodon
# 4362  2704           LMF  F25-0008   Sample-8    Poales   Poaceae     Cynodon
# 4363  2704           LMF  F25-0008   Sample-8    Poales   Poaceae     Cynodon
# 4364  2704           LMF  F25-0008   Sample-8    Poales   Poaceae     Cynodon
#
#             species              tax_name functional_group  ... net_gas_8h_ml  \
# 0         pubescens  Desmanthus pubescens      Shrub_Trees  ...   0.885006756
# 1         pubescens  Desmanthus pubescens      Shrub_Trees  ...   28.46771732
# 2         pubescens  Desmanthus pubescens      Shrub_Trees  ...    28.9102207
# 3         pubescens  Desmanthus pubescens      Shrub_Trees  ...   24.48518692
# 4         pubescens  Desmanthus pubescens      Shrub_Trees  ...   26.25520043
# ...             ...                   ...              ...  ...           ...
# 4360   nlemfuensis   Cynodon nlemfuensis             Grass  ...   21.01891046
# 4361   nlemfuensis   Cynodon nlemfuensis             Grass  ...   21.01891046
# 4362   nlemfuensis   Cynodon nlemfuensis             Grass  ...   21.01891046
# 4363   nlemfuensis   Cynodon nlemfuensis             Grass  ...   21.01891046
# 4364   nlemfuensis   Cynodon nlemfuensis             Grass  ...   21.01891046
#
#      net_gas_24h_ml    ch4_8h_ml   ch4_24h_ml ch4_percentage_in_gas_8h  \
# 0       30.75398477  0.112395858  5.339467011                     12.7
# 1        59.2217021  3.814674121  9.442653335                     13.4
# 2       58.77919872  3.845059353  9.340951308                     13.3
# 3       52.14164805  3.403440982  8.602855674                     13.9
# 4       52.58415142  3.518196858  8.468039645                     13.4
# ...             ...          ...          ...                      ...
# 4360     59.4060785  2.984685285  9.011470668                     14.2
# 4361     59.4060785  2.984685285  9.011470668                     14.2
# 4362     59.4060785  2.984685285  9.011470668                     14.2
# 4363     59.4060785  2.984685285  9.011470668                     14.2
# 4364     59.4060785  2.984685285  9.011470668                     14.2
#
#      ch4_percentage_in_gas_24h gas_ml_g_dm_incubated_24h  \
# 0                         17.5               66.18029863
# 1                         18.3               127.4152359
# 2                         18.4               126.3873745
# 3                         18.8               111.7273306
# 4                         18.8               112.6304774
# ...                        ...                       ...
# 4360                      15.7               126.7080608
# 4361                      15.7               126.7080608
# 4362                      15.7               126.7080608
# 4363                      15.7               126.7080608
# 4364                      15.7               126.7080608
#
#      ch4_ml_g_ndf_digested_24h methane_intensity         tddm
# 0                  77.53634394       13.80420634  83.23649666
# 1                  34.55416842       39.70956133  51.16104819
# 2                  36.98492322       37.91405033  52.97499896
# 3                  22.38737036       46.96225419  39.25259478
# 4                  16.20638872       52.70349781  34.41474045
# ...                        ...               ...          ...
# 4360                      None       45.43396889  42.29621851
# 4361                      None       45.43396889  42.29621851
# 4362                      None       45.43396889  42.29621851
# 4363                      None       45.43396889  42.29621851
# 4364                      None       45.43396889  42.29621851
#
# [4365 rows x 25 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_2_gas_sorted_by_sql = subset_2_gas_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_2_gas_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_2_gas_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (2529, 25)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab         id tax_order    family       genus  \
# 0  3  Genetic bank  F24-3536  ABC-32379   Fabales  Fabaceae  Desmanthus
# 1  4  Genetic bank  F24-3536  ABC-32379   Fabales  Fabaceae  Desmanthus
# 2  5  Genetic bank  F24-3536  ABC-32379   Fabales  Fabaceae  Desmanthus
# 3  6  Genetic bank  F24-3537  ABC-32380   Fabales  Fabaceae  Desmanthus
# 4  7  Genetic bank  F24-3537  ABC-32380   Fabales  Fabaceae  Desmanthus
#
#      species              tax_name functional_group  ... net_gas_8h_ml  \
# 0  pubescens  Desmanthus pubescens      Shrub_Trees  ...   0.885006756
# 1  pubescens  Desmanthus pubescens      Shrub_Trees  ...   28.46771732
# 2  pubescens  Desmanthus pubescens      Shrub_Trees  ...    28.9102207
# 3  pubescens  Desmanthus pubescens      Shrub_Trees  ...   24.48518692
# 4  pubescens  Desmanthus pubescens      Shrub_Trees  ...   26.25520043
#
#   net_gas_24h_ml    ch4_8h_ml   ch4_24h_ml ch4_percentage_in_gas_8h  \
# 0    30.75398477  0.112395858  5.339467011                     12.7
# 1     59.2217021  3.814674121  9.442653335                     13.4
# 2    58.77919872  3.845059353  9.340951308                     13.3
# 3    52.14164805  3.403440982  8.602855674                     13.9
# 4    52.58415142  3.518196858  8.468039645                     13.4
#
#   ch4_percentage_in_gas_24h gas_ml_g_dm_incubated_24h  \
# 0                      17.5               66.18029863
# 1                      18.3               127.4152359
# 2                      18.4               126.3873745
# 3                      18.8               111.7273306
# 4                      18.8               112.6304774
#
#   ch4_ml_g_ndf_digested_24h methane_intensity         tddm
# 0               77.53634394       13.80420634  83.23649666
# 1               34.55416842       39.70956133  51.16104819
# 2               36.98492322       37.91405033  52.97499896
# 3               22.38737036       46.96225419  39.25259478
# 4               16.20638872       52.70349781  34.41474045
#
# [5 rows x 25 columns]

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 2
subset_2_gas_sorted_by_sql.insert(0, 'subset', 2)

print("DataFrame with new 'subset' column:")
display(subset_2_gas_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab         id tax_order    family  \
# 0       2  3  Genetic bank  F24-3536  ABC-32379   Fabales  Fabaceae
# 1       2  4  Genetic bank  F24-3536  ABC-32379   Fabales  Fabaceae
# 2       2  5  Genetic bank  F24-3536  ABC-32379   Fabales  Fabaceae
# 3       2  6  Genetic bank  F24-3537  ABC-32380   Fabales  Fabaceae
# 4       2  7  Genetic bank  F24-3537  ABC-32380   Fabales  Fabaceae
#
#         genus    species              tax_name  ... net_gas_8h_ml  \
# 0  Desmanthus  pubescens  Desmanthus pubescens  ...   0.885006756
# 1  Desmanthus  pubescens  Desmanthus pubescens  ...   28.46771732
# 2  Desmanthus  pubescens  Desmanthus pubescens  ...    28.9102207
# 3  Desmanthus  pubescens  Desmanthus pubescens  ...   24.48518692
# 4  Desmanthus  pubescens  Desmanthus pubescens  ...   26.25520043
#
#   net_gas_24h_ml    ch4_8h_ml   ch4_24h_ml ch4_percentage_in_gas_8h  \
# 0    30.75398477  0.112395858  5.339467011                     12.7
# 1     59.2217021  3.814674121  9.442653335                     13.4
# 2    58.77919872  3.845059353  9.340951308                     13.3
# 3    52.14164805  3.403440982  8.602855674                     13.9
# 4    52.58415142  3.518196858  8.468039645                     13.4
#
#   ch4_percentage_in_gas_24h gas_ml_g_dm_incubated_24h  \
# 0                      17.5               66.18029863
# 1                      18.3               127.4152359
# 2                      18.4               126.3873745
# 3                      18.8               111.7273306
# 4                      18.8               112.6304774
#
#   ch4_ml_g_ndf_digested_24h methane_intensity         tddm
# 0               77.53634394       13.80420634  83.23649666
# 1               34.55416842       39.70956133  51.16104819
# 2               36.98492322       37.91405033  52.97499896
# 3               22.38737036       46.96225419  39.25259478
# 4               16.20638872       52.70349781  34.41474045
#
# [5 rows x 26 columns]

# %%
#subset_2_gas_sorted_by_sql.to_csv("/content/drive/MyDrive/lmf/output/04_15_2026_sql_data_frame_creation/subset_2_gas_sorted_by_sql.csv", index=None)

# %% [markdown]
# ### 2.3.2. Nutrition

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_2_information_samples.to_sql('subset_2_information_samples', conn_new, if_exists='replace', index=False)
subset_2_nutrition.to_sql('subset_2_nutrition', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_2_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner',
#        '10_requisitioner_2', '10_set_ciat', '10_ciat_lab_id',
#        '10_gene_bank_breeding_program_id', '10_genus', '10_species',
#        '10_tax_name', '10_family', '10_order', '10_functional_group',
#        '10_remarks', '10_id_lab', '10_remarks.1'],
#       dtype='object')

# %%
subset_2_nutrition.columns
# Out:
# Index(['40qraw_no', '40qraw_set_ciat', '40qraw_sample_id',
#        '40qraw_gene_bank_breeding_program_id', '40qraw_genus',
#        '40qraw_species', '40qraw_tax_name', '40qraw_family', '40qraw_order',
#        '40qraw_functional_group', '40qraw_replication_dm_percentage',
#        '40qraw_dm_percentage', '40qraw_av_dm_105', '40qraw_ash_dm',
#        '40qraw_av_ash_percentage', '40qraw_om_percentage',
#        '40qraw_om_percentage.1', '40qraw_pc_percentage_dm',
#        '40qraw_av_pc_percentage', '40qraw_adf_percentage_dm',
#        '40qraw_av_adf_percentage_dm', '40qraw_ndf_percentage_dm',
#        '40qraw_av_ndf_percentage_dm'],
#       dtype='object')

# %%
query_combined = """
SELECT
    s2n."40qraw_no" as no,
    s2i."10_requisitioner" as requisitioner,
    s2i."10_ciat_lab_id" as id_lab,
    s2i."10_gene_bank_breeding_program_id" as id,
    s2i."10_order" as tax_order,
    s2i."10_family" as family,
    s2i."10_genus" as genus,
    s2i."10_species" as species,
    s2i."10_tax_name" as tax_name,
    s2i."10_functional_group" as functional_group,
    s2i."10_set_ciat" as set_ciat,
    s2n."40qraw_dm_percentage" as dm_percentage,
    s2n."40qraw_ash_dm" as ash_dm,
    s2n."40qraw_om_percentage" as om_percentage,
    s2n."40qraw_pc_percentage_dm" as pc_percentage_dm,
    s2n."40qraw_adf_percentage_dm" as adf_percentage_dm,
    s2n."40qraw_ndf_percentage_dm" as ndf_percentage_dm



FROM
    subset_2_information_samples AS s2i
JOIN
    subset_2_nutrition AS s2n
ON
    s2i."10_ciat_lab_id" = s2n."40qraw_sample_id"
ORDER BY
    CAST(no AS INTEGER) ASC NULLS LAST
"""

subset_2_nutrition_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_2_nutrition_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#        no requisitioner    id_lab                     id    tax_order  \
# 0       1  Genetic bank  F24-3536              ABC-32379      Fabales
# 1       2  Genetic bank  F24-3536              ABC-32379      Fabales
# 2       3  Genetic bank  F24-3537              ABC-32380      Fabales
# 3       4  Genetic bank  F24-3537              ABC-32380      Fabales
# 4       5  Genetic bank  F24-3538              ABC-33249      Fabales
# ..    ...           ...       ...                    ...          ...
# 877  None           LMF  F25-0008               Sample-8       Poales
# 878  None           LMF  F25-0018  Homenheim-Concentrate  Concentrate
# 879  None           LMF  F25-0018  Homenheim-Concentrate  Concentrate
# 880  None           LMF  F25-0008               Sample-8       Poales
# 881  None           LMF  F25-0008               Sample-8       Poales
#
#           family       genus        species               tax_name  \
# 0       Fabaceae  Desmanthus      pubescens   Desmanthus pubescens
# 1       Fabaceae  Desmanthus      pubescens   Desmanthus pubescens
# 2       Fabaceae  Desmanthus      pubescens   Desmanthus pubescens
# 3       Fabaceae  Desmanthus      pubescens   Desmanthus pubescens
# 4       Fabaceae   Desmodium      velutinum    Desmodium velutinum
# ..           ...         ...            ...                    ...
# 877      Poaceae     Cynodon   nlemfuensis    Cynodon nlemfuensis
# 878  Concentrate   Homenheim    Concentrate  Homenheim Concentrate
# 879  Concentrate   Homenheim    Concentrate  Homenheim Concentrate
# 880      Poaceae     Cynodon   nlemfuensis    Cynodon nlemfuensis
# 881      Poaceae     Cynodon   nlemfuensis    Cynodon nlemfuensis
#
#     functional_group set_ciat dm_percentage       ash_dm om_percentage  \
# 0        Shrub_Trees       14         92.91         8.21         91.79
# 1        Shrub_Trees       14         92.97         8.28         91.72
# 2        Shrub_Trees       14         93.26          8.8          91.2
# 3        Shrub_Trees       14         93.34         8.73         91.27
# 4        Shrub_Trees       14         93.06          9.7          90.3
# ..               ...      ...           ...          ...           ...
# 877            Grass       21   93.82123575  11.49829497   88.50170503
# 878      Concentrate       22   89.65413834  5.886943918   94.11305608
# 879      Concentrate       22   89.73205359  6.183844011   93.81615599
# 880            Grass       22   93.64063594  11.32941805   88.67058195
# 881            Grass       22   93.82123575  11.49829497   88.50170503
#
#     pc_percentage_dm adf_percentage_dm ndf_percentage_dm
# 0              27.65              19.6             75.23
# 1              27.65              18.3             74.02
# 2              29.33             31.17             77.81
# 3              29.33             30.62             78.73
# 4              16.48             42.74             76.85
# ..               ...               ...               ...
# 877                0                 0                 0
# 878                0                 0                 0
# 879                0                 0                 0
# 880                0                 0                 0
# 881                0                 0                 0
#
# [882 rows x 17 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_2_nutrition_sorted_by_sql = subset_2_nutrition_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_2_nutrition_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_2_nutrition_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (882, 17)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab         id tax_order    family       genus  \
# 0  1  Genetic bank  F24-3536  ABC-32379   Fabales  Fabaceae  Desmanthus
# 1  2  Genetic bank  F24-3536  ABC-32379   Fabales  Fabaceae  Desmanthus
# 2  3  Genetic bank  F24-3537  ABC-32380   Fabales  Fabaceae  Desmanthus
# 3  4  Genetic bank  F24-3537  ABC-32380   Fabales  Fabaceae  Desmanthus
# 4  5  Genetic bank  F24-3538  ABC-33249   Fabales  Fabaceae   Desmodium
#
#      species              tax_name functional_group set_ciat dm_percentage  \
# 0  pubescens  Desmanthus pubescens      Shrub_Trees       14         92.91
# 1  pubescens  Desmanthus pubescens      Shrub_Trees       14         92.97
# 2  pubescens  Desmanthus pubescens      Shrub_Trees       14         93.26
# 3  pubescens  Desmanthus pubescens      Shrub_Trees       14         93.34
# 4  velutinum   Desmodium velutinum      Shrub_Trees       14         93.06
#
#   ash_dm om_percentage pc_percentage_dm adf_percentage_dm ndf_percentage_dm
# 0   8.21         91.79            27.65              19.6             75.23
# 1   8.28         91.72            27.65              18.3             74.02
# 2    8.8          91.2            29.33             31.17             77.81
# 3   8.73         91.27            29.33             30.62             78.73
# 4    9.7          90.3            16.48             42.74             76.85

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 2
subset_2_nutrition_sorted_by_sql.insert(0, 'subset', 2)

print("DataFrame with new 'subset' column:")
display(subset_2_nutrition_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab         id tax_order    family  \
# 0       2  1  Genetic bank  F24-3536  ABC-32379   Fabales  Fabaceae
# 1       2  2  Genetic bank  F24-3536  ABC-32379   Fabales  Fabaceae
# 2       2  3  Genetic bank  F24-3537  ABC-32380   Fabales  Fabaceae
# 3       2  4  Genetic bank  F24-3537  ABC-32380   Fabales  Fabaceae
# 4       2  5  Genetic bank  F24-3538  ABC-33249   Fabales  Fabaceae
#
#         genus    species              tax_name functional_group set_ciat  \
# 0  Desmanthus  pubescens  Desmanthus pubescens      Shrub_Trees       14
# 1  Desmanthus  pubescens  Desmanthus pubescens      Shrub_Trees       14
# 2  Desmanthus  pubescens  Desmanthus pubescens      Shrub_Trees       14
# 3  Desmanthus  pubescens  Desmanthus pubescens      Shrub_Trees       14
# 4   Desmodium  velutinum   Desmodium velutinum      Shrub_Trees       14
#
#   dm_percentage ash_dm om_percentage pc_percentage_dm adf_percentage_dm  \
# 0         92.91   8.21         91.79            27.65              19.6
# 1         92.97   8.28         91.72            27.65              18.3
# 2         93.26    8.8          91.2            29.33             31.17
# 3         93.34   8.73         91.27            29.33             30.62
# 4         93.06    9.7          90.3            16.48             42.74
#
#   ndf_percentage_dm
# 0             75.23
# 1             74.02
# 2             77.81
# 3             78.73
# 4             76.85

# %%
#subset_2_nutrition_sorted_by_sql.to_csv('/content/drive/MyDrive/lmf/output/04_15_2026_sql_data_frame_creation/subset_2_nutrition_sorted_by_sql.csv', index=False)

# %% [markdown]
# # 3. Subset 3

# %% [markdown]
# ## 3.1. Loading data

# %%
# Load the CSVs from Drive into pandas DataFrames
subset_3_information_samples = pd.read_csv('/content/drive/MyDrive/lmf/data/04_15_2026_sql_data_frame_creation/subset_3/csv/10_information_samples.csv', encoding='latin1')
subset_3_gas_prod = pd.read_csv('/content/drive/MyDrive/lmf/data/04_15_2026_sql_data_frame_creation/subset_3/csv/31_gas_prod.csv', encoding='latin1')
# For this Subset there is there is not nutrition file, we should make the nutriotional dataframe from the begining
subset_3_dm = pd.read_csv('/content/drive/MyDrive/lmf/data/04_15_2026_sql_data_frame_creation/subset_3/csv/21_dm.csv', encoding='latin1')
subset_3_protein = pd.read_csv('/content/drive/MyDrive/lmf/data/04_15_2026_sql_data_frame_creation/subset_3/csv/22_protein.csv', encoding='latin1')
subset_3_adf = pd.read_csv('/content/drive/MyDrive/lmf/data/04_15_2026_sql_data_frame_creation/subset_3/csv/23_adf.csv', encoding='latin1')
subset_3_ndf = pd.read_csv('/content/drive/MyDrive/lmf/data/04_15_2026_sql_data_frame_creation/subset_3/csv/24_ndf.csv', encoding='latin1')

# %% [markdown]
# ## 3.2. Cleaning and formatting dataframes

# %%
# Clean first row containing orignal column names from excel files
subset_3_information_samples = remove_first_row(subset_3_information_samples)
subset_3_gas_prod = remove_first_row(subset_3_gas_prod)
subset_3_dm = remove_first_row(subset_3_dm)
subset_3_protein = remove_first_row(subset_3_protein)
subset_3_adf = remove_first_row(subset_3_adf)
subset_3_ndf = remove_first_row(subset_3_ndf)

# Remove '-1' tail from id columns
subset_3_information_samples['10_gene_bank_breeding_program_id'] = remove_minus_one_suffix(subset_3_information_samples['10_gene_bank_breeding_program_id'])
subset_3_gas_prod['31_gene_bank'] = remove_minus_one_suffix(subset_3_gas_prod['31_gene_bank'])
subset_3_dm['21_gene_bank_breeding_program_id'] = remove_minus_one_suffix(subset_3_dm['21_gene_bank_breeding_program_id'])
subset_3_protein['22_gene_bank_breeding_program_id'] = remove_minus_one_suffix(subset_3_protein['22_gene_bank_breeding_program_id'])
subset_3_adf['23_gene_bank_breeding_program_id'] = remove_minus_one_suffix(subset_3_adf['23_gene_bank_breeding_program_id'])
subset_3_ndf['24_gene_bank_breeding_program_id'] = remove_minus_one_suffix(subset_3_ndf['24_gene_bank_breeding_program_id'])

# Add '-' to lab ids and ensure correct format FXX-XXXX
subset_3_information_samples['10_ciat_lab_id'] = clean_lab_ids(subset_3_information_samples['10_ciat_lab_id'])
subset_3_gas_prod['31_ciat_id'] = clean_lab_ids(subset_3_gas_prod['31_ciat_id'])
subset_3_dm['21_ciat_lab_id'] = clean_lab_ids(subset_3_dm['21_ciat_lab_id'])
subset_3_protein['22_ciat_lab_id'] = clean_lab_ids(subset_3_protein['22_ciat_lab_id'])
subset_3_adf['23_ciat_lab_id'] = clean_lab_ids(subset_3_adf['23_ciat_lab_id'])
subset_3_ndf['24_ciat_lab_id'] = clean_lab_ids(subset_3_ndf['24_ciat_lab_id'])

# Clean and standardize gene bank and breeding program ids
subset_3_information_samples['10_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_3_information_samples['10_gene_bank_breeding_program_id'])
subset_3_gas_prod['31_gene_bank'] = clean_standardize_ids(subset_3_gas_prod['31_gene_bank'])
subset_3_dm['21_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_3_dm['21_gene_bank_breeding_program_id'])
subset_3_protein['22_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_3_protein['22_gene_bank_breeding_program_id'])
subset_3_adf['23_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_3_adf['23_gene_bank_breeding_program_id'])
subset_3_ndf['24_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_3_ndf['24_gene_bank_breeding_program_id'])

# %%
# Check functional groups categories
subset_3_information_samples['10_functional_group'].unique()
# Out:
# array(['Herbaceous', 'Shrub', 'Climber', 'grasses', nan, 'Herbáceas ',
#        'Arbustiva '], dtype=object)

# %%
# Define the mapping for functional groups
functional_group_mapping = {
    'Grasses': 'Grass',
    'grasses': 'Grass',
    'Shrub': 'Shrub_Trees',
    'Shrub/tree': 'Shrub_Trees',
    'Shrub/Tree': 'Shrub_Trees',
    'Shrub/Trees': 'Shrub_Trees',
    'Shrub_Trees': 'Shrub_Trees',
    'Tree': 'Shrub_Trees',
    'Arbustiva ': 'Shrub_Trees',
    'Herbáceas': 'Herbaceous_legumes',
    'Herbáceas ': 'Herbaceous_legumes',
    'Herbaceous': 'Herbaceous_legumes',
    'Herbaceous legume': 'Herbaceous_legumes',
    'Climber': 'Herbaceous_legumes',
    'Legume': 'Herbaceous_legumes'
}

# Apply the mapping to centers datt
subset_3_information_samples['10_functional_group'] = subset_3_information_samples['10_functional_group'].replace(functional_group_mapping)

print('Updated functional group counts for subset_3_information_samples:')
display(subset_3_information_samples['10_functional_group'].value_counts())
# Out:
# Updated functional group counts for subset_3_information_samples:
# 10_functional_group
# Herbaceous_legumes    81
# Shrub_Trees           21
# Grass                 20
# Name: count, dtype: int64

# %% [markdown]
# ## 3.3. SQL query and dataframe creation

# %% [markdown]
# ### 3.3.1. Gas

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_3_information_samples.to_sql('subset_3_information_samples', conn_new, if_exists='replace', index=False)
subset_3_gas_prod.to_sql('subset_3_gas_prod', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_3_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner',
#        '10_requisitioner_2', '10_set_ciat', '10_ciat_lab_id',
#        '10_gene_bank_breeding_program_id', '10_genus', '10_species',
#        '10_tax_name', '10_family', '10_order', '10_functional_group',
#        '10_remarks', '10_id_lab', '10_remarks_2'],
#       dtype='object')

# %%
subset_3_gas_prod.columns
# Out:
# Index(['31_no', '31_date', '31_requisitioner', '31_gene_bank', '31_tax_name',
#        '31_family', '31_order', '31_genus2', '31_species3',
#        '31_functional_group', '31_ciat_id', '31_set_ciat', '31_batch',
#        '31_run', '31_replication', '31_syrange_no', '31_sample_weight_g',
#        '31_dm_incubated_dm', '31_digested_feed_mg', '31_time_0h',
#        '31_gas_0h_ml', '31_time_8h', '31_gas_8h_ml', '31_ch4_8h_percentage',
#        '31_v8_push_back_ml', '31_time_24h', '31_gas_24h_ml',
#        '31_ch4_24h_percentage', '31_remarks', '31_gp_8h_ml', '31_gp_8_24h_ml',
#        '31_net_gas_8h_ml', '31_net_gas_8_24h_ml2', '31_net_gas_24h_ml',
#        '31_ch4_8h_ml', '31_ch4_8_24h_ml', '31_ch4_24h_ml',
#        '31_gas_ml_g_dm_incubated_24h', '31_percentage_dmd_truly_digestibility',
#        '31_part_fact', '31_ch4_ml_in_gas_8h', '31_ch4_ml_in_gas_24h',
#        '31_ch4_ml_g_dm_incubated_24h', '31_ch4_ml_g_dmd_24h',
#        '31_ch4_ml_g_ndf_digested_in_24h', '31_ch4_g_g_dm_incubated_24h',
#        '31_ch4_g_g_dmd_24h', '31_column8', '31_column9'],
#       dtype='object')

# %%
query_combined = """
SELECT
    s3g."31_no" as no,
    s3i."10_requisitioner" as requisitioner,
    s3i."10_ciat_lab_id" as id_lab,
    s3i."10_gene_bank_breeding_program_id" as id,
    s3i."10_order" as tax_order,
    s3i."10_family" as family,
    s3i."10_genus" as genus,
    s3i."10_species" as species,
    s3i."10_tax_name" as tax_name,
    s3i."10_functional_group" as functional_group,
    s3g."31_set_ciat" as set_ciat,
    s3g."31_batch" as batch,
    s3g."31_run" as run,
    s3g."31_replication" as replication,
    s3g."31_syrange_no" as syrange,
    s3g."31_net_gas_8h_ml" as net_gas_8h_ml,
    s3g."31_net_gas_24h_ml" as net_gas_24h_ml,
    s3g."31_ch4_8h_ml" as ch4_8h_ml,
    s3g."31_ch4_24h_ml" as ch4_24h_ml,
    s3g."31_ch4_8h_percentage" as ch4_percentage_in_gas_8h,
    s3g."31_ch4_ml_in_gas_24h" as ch4_percentage_in_gas_24h,
    s3g."31_gas_ml_g_dm_incubated_24h" as gas_ml_g_dm_incubated_24h,
    s3g."31_ch4_ml_g_ndf_digested_in_24h" as ch4_ml_g_ndf_digested_24h,
    s3g."31_ch4_ml_g_dmd_24h" as methane_intensity,
    s3g."31_percentage_dmd_truly_digestibility" as tddm
FROM
    subset_3_information_samples AS s3i
JOIN
    subset_3_gas_prod AS s3g
ON
    s3i."10_ciat_lab_id" = s3g."31_ciat_id"
ORDER BY
    CAST(no AS INTEGER) ASC
"""

subset_3_gas_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_3_gas_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#         no requisitioner    id_lab                                      id  \
# 0        3  Genetic bank  F24-3540                                ABC-1467
# 1        4  Genetic bank  F24-3540                                ABC-1467
# 2        5  Genetic bank  F24-3540                                ABC-1467
# 3        6  Genetic bank  F24-3541                                ABC-1475
# 4        7  Genetic bank  F24-3541                                ABC-1475
# ...    ...           ...       ...                                     ...
# 1453  1281  Genetic bank  F24-3581                               ABC-12758
# 1454  1282  Genetic bank  F24-3581                               ABC-12758
# 1455  1283           LMF  F25-2134  Hohenheimer-Heustandard-IAG-2025/1-S-1
# 1456  1284           LMF  F25-2134  Hohenheimer-Heustandard-IAG-2025/1-S-1
# 1457  1285           LMF  F25-2134  Hohenheimer-Heustandard-IAG-2025/1-S-1
#
#         tax_order        family         genus      species  \
# 0         Fabales      Fabaceae  Stylosanthes       hamata
# 1         Fabales      Fabaceae  Stylosanthes       hamata
# 2         Fabales      Fabaceae  Stylosanthes       hamata
# 3         Fabales      Fabaceae  Stylosanthes       hamata
# 4         Fabales      Fabaceae  Stylosanthes       hamata
# ...           ...           ...           ...          ...
# 1453      Fabales      Fabaceae  Stylosanthes   guianensis
# 1454      Fabales      Fabaceae  Stylosanthes   guianensis
# 1455  Green meal    Heustandard   Hohenheimer  Heustandard
# 1456  Green meal    Heustandard   Hohenheimer  Heustandard
# 1457  Green meal    Heustandard   Hohenheimer  Heustandard
#
#                      tax_name    functional_group  ... net_gas_8h_ml  \
# 0         Stylosanthes hamata  Herbaceous_legumes  ...   50.91722647
# 1         Stylosanthes hamata  Herbaceous_legumes  ...   50.41722647
# 2         Stylosanthes hamata  Herbaceous_legumes  ...   51.91722647
# 3         Stylosanthes hamata  Herbaceous_legumes  ...   52.41722647
# 4         Stylosanthes hamata  Herbaceous_legumes  ...   51.41722647
# ...                       ...                 ...  ...           ...
# 1453  Stylosanthes guianensis  Herbaceous_legumes  ...   32.04997748
# 1454  Stylosanthes guianensis  Herbaceous_legumes  ...   31.54997748
# 1455  Hohenheimer Heustandard                None  ...   31.04997748
# 1456  Hohenheimer Heustandard                None  ...   29.04997748
# 1457  Hohenheimer Heustandard                None  ...   27.54997748
#
#      net_gas_24h_ml    ch4_8h_ml   ch4_24h_ml ch4_percentage_in_gas_8h  \
# 0         100.45095  6.466487761  14.39188353                     12.7
# 1          98.95095  6.755908346  14.66690528                     13.4
# 2         101.95095  6.956908346  15.06237156                     13.4
# 3          95.95095   6.97149112   14.1545555                     13.3
# 4          94.95095   6.83849112  14.15215667                     13.3
# ...             ...          ...          ...                      ...
# 1453    71.39932461  3.910097253  8.277874784                     12.2
# 1454    64.89932461   3.75444732  7.556272893                     11.9
# 1455    48.89932461  4.036497072   6.91024196                       13
# 1456    46.39932461  3.950796937  6.882836602                     13.6
# 1457    45.39932461  3.856996847  6.962783248                       14
#
#      ch4_percentage_in_gas_24h gas_ml_g_dm_incubated_24h  \
# 0                  14.32727468                216.921557
# 1                         None                      None
# 2                  14.77413556                220.072744
# 3                  14.75186593               211.3689834
# 4                  14.90470256               208.9571405
# ...                        ...                       ...
# 1453               11.59377183               156.1824098
# 1454               11.64306861               141.9639887
# 1455               14.13156933               214.1583332
# 1456               14.83391549               203.2093919
# 1457               15.33675513               198.8298154
#
#      ch4_ml_g_ndf_digested_24h methane_intensity         tddm
# 0                  221.0970237       50.84123828  61.12940668
# 1                         None              None         None
# 2                   205.795111       51.71448076  62.87183987
# 3                  265.7186313       56.40388724  55.28141866
# 4                  180.2243256       51.20099287   60.8278053
# ...                        ...               ...          ...
# 1453              -2315.870328       42.85647275  42.25133584
# 1454                314.509385       34.22946966  48.28869618
# 1455                   #DIV/0!       85.80678795  35.26985925
# 1456                   #DIV/0!       61.21745709   49.2407083
# 1457                   #DIV/0!       98.29916277  31.02167004
#
# [1458 rows x 25 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_3_gas_sorted_by_sql = subset_3_gas_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_3_gas_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_3_gas_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (1254, 25)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab        id tax_order    family         genus  \
# 0  3  Genetic bank  F24-3540  ABC-1467   Fabales  Fabaceae  Stylosanthes
# 1  4  Genetic bank  F24-3540  ABC-1467   Fabales  Fabaceae  Stylosanthes
# 2  5  Genetic bank  F24-3540  ABC-1467   Fabales  Fabaceae  Stylosanthes
# 3  6  Genetic bank  F24-3541  ABC-1475   Fabales  Fabaceae  Stylosanthes
# 4  7  Genetic bank  F24-3541  ABC-1475   Fabales  Fabaceae  Stylosanthes
#
#   species             tax_name    functional_group  ... net_gas_8h_ml  \
# 0  hamata  Stylosanthes hamata  Herbaceous_legumes  ...   50.91722647
# 1  hamata  Stylosanthes hamata  Herbaceous_legumes  ...   50.41722647
# 2  hamata  Stylosanthes hamata  Herbaceous_legumes  ...   51.91722647
# 3  hamata  Stylosanthes hamata  Herbaceous_legumes  ...   52.41722647
# 4  hamata  Stylosanthes hamata  Herbaceous_legumes  ...   51.41722647
#
#   net_gas_24h_ml    ch4_8h_ml   ch4_24h_ml ch4_percentage_in_gas_8h  \
# 0      100.45095  6.466487761  14.39188353                     12.7
# 1       98.95095  6.755908346  14.66690528                     13.4
# 2      101.95095  6.956908346  15.06237156                     13.4
# 3       95.95095   6.97149112   14.1545555                     13.3
# 4       94.95095   6.83849112  14.15215667                     13.3
#
#   ch4_percentage_in_gas_24h gas_ml_g_dm_incubated_24h  \
# 0               14.32727468                216.921557
# 1                      None                      None
# 2               14.77413556                220.072744
# 3               14.75186593               211.3689834
# 4               14.90470256               208.9571405
#
#   ch4_ml_g_ndf_digested_24h methane_intensity         tddm
# 0               221.0970237       50.84123828  61.12940668
# 1                      None              None         None
# 2                205.795111       51.71448076  62.87183987
# 3               265.7186313       56.40388724  55.28141866
# 4               180.2243256       51.20099287   60.8278053
#
# [5 rows x 25 columns]

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 3
subset_3_gas_sorted_by_sql.insert(0, 'subset', 3)

print("DataFrame with new 'subset' column:")
display(subset_3_gas_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab        id tax_order    family  \
# 0       3  3  Genetic bank  F24-3540  ABC-1467   Fabales  Fabaceae
# 1       3  4  Genetic bank  F24-3540  ABC-1467   Fabales  Fabaceae
# 2       3  5  Genetic bank  F24-3540  ABC-1467   Fabales  Fabaceae
# 3       3  6  Genetic bank  F24-3541  ABC-1475   Fabales  Fabaceae
# 4       3  7  Genetic bank  F24-3541  ABC-1475   Fabales  Fabaceae
#
#           genus species             tax_name  ... net_gas_8h_ml  \
# 0  Stylosanthes  hamata  Stylosanthes hamata  ...   50.91722647
# 1  Stylosanthes  hamata  Stylosanthes hamata  ...   50.41722647
# 2  Stylosanthes  hamata  Stylosanthes hamata  ...   51.91722647
# 3  Stylosanthes  hamata  Stylosanthes hamata  ...   52.41722647
# 4  Stylosanthes  hamata  Stylosanthes hamata  ...   51.41722647
#
#   net_gas_24h_ml    ch4_8h_ml   ch4_24h_ml ch4_percentage_in_gas_8h  \
# 0      100.45095  6.466487761  14.39188353                     12.7
# 1       98.95095  6.755908346  14.66690528                     13.4
# 2      101.95095  6.956908346  15.06237156                     13.4
# 3       95.95095   6.97149112   14.1545555                     13.3
# 4       94.95095   6.83849112  14.15215667                     13.3
#
#   ch4_percentage_in_gas_24h gas_ml_g_dm_incubated_24h  \
# 0               14.32727468                216.921557
# 1                      None                      None
# 2               14.77413556                220.072744
# 3               14.75186593               211.3689834
# 4               14.90470256               208.9571405
#
#   ch4_ml_g_ndf_digested_24h methane_intensity         tddm
# 0               221.0970237       50.84123828  61.12940668
# 1                      None              None         None
# 2                205.795111       51.71448076  62.87183987
# 3               265.7186313       56.40388724  55.28141866
# 4               180.2243256       51.20099287   60.8278053
#
# [5 rows x 26 columns]

# %%
#subset_3_gas_sorted_by_sql.to_csv("/content/drive/MyDrive/lmf/output/04_15_2026_sql_data_frame_creation/subset_3_gas_sorted_by_sql.csv", index=None)

# %% [markdown]
# ### 3.3.2. Nutrition (Left join with different queries)

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_3_information_samples.to_sql('subset_3_information_samples', conn_new, if_exists='replace', index=False)
subset_3_dm.to_sql('subset_3_dm', conn_new, if_exists='replace', index=False)
subset_3_protein.to_sql('subset_3_protein', conn_new, if_exists='replace', index=False)
subset_3_adf.to_sql('subset_3_adf', conn_new, if_exists='replace', index=False)
subset_3_ndf.to_sql('subset_3_ndf', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_3_information_samples.head(2)
# Out:
#   10_sample_serial_no 10_date 10_requisitioner  10_requisitioner_2  \
# 1                   1   45923     Genetic bank  Juan José Gonzalez
# 2                   2   45923     Genetic bank  Juan José Gonzalez
#
#   10_set_ciat 10_ciat_lab_id 10_gene_bank_breeding_program_id      10_genus  \
# 1          23       F24-3540                         ABC-1467  Stylosanthes
# 2          23       F24-3541                         ABC-1475  Stylosanthes
#
#   10_species          10_tax_name 10_family 10_order 10_functional_group  \
# 1     hamata  Stylosanthes hamata  Fabaceae  Fabales  Herbaceous_legumes
# 2     hamata  Stylosanthes hamata  Fabaceae  Fabales  Herbaceous_legumes
#
#   10_remarks 10_id_lab 10_remarks_2
# 1     OT-033       NaN          NaN
# 2     OT-033       NaN          NaN

# %%
subset_3_ndf.columns
# Out:
# Index(['24_no', '24_requisitioner', '24_set_ciat', '24_ciat_lab_id',
#        '24_gene_bank_breeding_program_id', '24_genus', '24_species',
#        '24_tax_name', '24_family', '24_order', '24_functional_group',
#        '24_replication', '24_ndf', '24_av_ndf_percentage_dm', 'Unnamed: 14'],
#       dtype='object')

# %%
query_combined = """
WITH nutrition AS (
    SELECT
        s3dm."21_gene_bank_breeding_program_id" as id,
        s3dm."21_ciat_lab_id" as lab_id,
        s3dm."21_replication" as replication,
        s3dm."21_no" as no,
        s3dm."21_dm_percentage" as dm_percentage,
        s3dm."21_ash_percentage" as ash_dm,
        s3dm."21_om_percentage" as om_percentage,
        s3p."22_dm_percentage" as pc_percentage_dm,
        s3a."23_dm_percentage" as adf_percentage_dm,
        s3n."24_ndf" as ndf_percentage_dm

    FROM subset_3_dm s3dm

    LEFT JOIN subset_3_protein s3p
    ON s3dm."21_ciat_lab_id" = s3p."22_ciat_lab_id"
    AND s3dm."21_replication" = s3p."22_replication"

    LEFT JOIN subset_3_adf s3a
    ON s3dm."21_ciat_lab_id" = s3a."23_ciat_lab_id"
    AND s3dm."21_replication" = s3a."23_replication"

    LEFT JOIN subset_3_ndf s3n
    ON s3dm."21_ciat_lab_id" = s3n."24_ciat_lab_id"
    AND s3dm."21_replication" = s3n."24_replication"
)

SELECT
    n.no,
    s3i."10_requisitioner" as requisitioner,
    s3i."10_ciat_lab_id" as id_lab,
    s3i."10_gene_bank_breeding_program_id" as id,
    s3i."10_order" as tax_order,
    s3i."10_family" as family,
    s3i."10_genus" as genus,
    s3i."10_species" as species,
    s3i."10_tax_name" as tax_name,
    s3i."10_functional_group" as functional_group,
    s3i."10_set_ciat" as set_ciat,
    n.dm_percentage,
    n.ash_dm,
    n.om_percentage,
    n.pc_percentage_dm,
    n.adf_percentage_dm,
    n.ndf_percentage_dm

FROM nutrition n

LEFT JOIN subset_3_information_samples s3i
ON n.lab_id = s3i."10_ciat_lab_id"

ORDER BY
    CAST(n.no AS INTEGER) ASC NULLS LAST;
"""

subset_3_nutrition_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_3_nutrition_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#        no requisitioner    id_lab                                      id  \
# 0       1  Genetic bank  F24-3540                                ABC-1467
# 1       2  Genetic bank  F24-3540                                ABC-1467
# 2       3  Genetic bank  F24-3541                                ABC-1475
# 3       4  Genetic bank  F24-3541                                ABC-1475
# 4       5  Genetic bank  F25-0954                               ABC-23326
# ...   ...           ...       ...                                     ...
# 3099  264  Genetic bank  F24-3580                               ABC-12710
# 3100  265  Genetic bank  F24-3581                               ABC-12758
# 3101  266  Genetic bank  F24-3581                               ABC-12758
# 3102  267           LMF  F25-2134  Hohenheimer-Heustandard-IAG-2025/1-S-1
# 3103  268           LMF  F25-2134  Hohenheimer-Heustandard-IAG-2025/1-S-1
#
#         tax_order        family         genus      species  \
# 0         Fabales      Fabaceae  Stylosanthes       hamata
# 1         Fabales      Fabaceae  Stylosanthes       hamata
# 2         Fabales      Fabaceae  Stylosanthes       hamata
# 3         Fabales      Fabaceae  Stylosanthes       hamata
# 4         Fabales      Fabaceae     Desmodium    velutinum
# ...           ...           ...           ...          ...
# 3099      Fabales      Fabaceae  Stylosanthes       scabra
# 3100      Fabales      Fabaceae  Stylosanthes   guianensis
# 3101      Fabales      Fabaceae  Stylosanthes   guianensis
# 3102  Green meal    Heustandard   Hohenheimer  Heustandard
# 3103  Green meal    Heustandard   Hohenheimer  Heustandard
#
#                      tax_name    functional_group set_ciat dm_percentage  \
# 0         Stylosanthes hamata  Herbaceous_legumes       23          92.5
# 1         Stylosanthes hamata  Herbaceous_legumes       23         92.73
# 2         Stylosanthes hamata  Herbaceous_legumes       23         90.62
# 3         Stylosanthes hamata  Herbaceous_legumes       23         90.96
# 4         Desmodium velutinum         Shrub_Trees       23         95.77
# ...                       ...                 ...      ...           ...
# 3099      Stylosanthes scabra  Herbaceous_legumes       26         91.77
# 3100  Stylosanthes guianensis  Herbaceous_legumes       26         91.36
# 3101  Stylosanthes guianensis  Herbaceous_legumes       26   91.39172166
# 3102  Hohenheimer Heustandard                None       26   91.34432784
# 3103  Hohenheimer Heustandard                None       26   91.32173565
#
#            ash_dm om_percentage pc_percentage_dm adf_percentage_dm  \
# 0            8.49         91.51            13.64             35.11
# 1            8.59         91.41            13.64             34.44
# 2             8.7          91.3            17.29             37.69
# 3            8.81         91.19            17.29             37.17
# 4           14.95         85.05            18.11             23.08
# ...           ...           ...              ...               ...
# 3099   11.6653039    88.3346961      11.49501692       37.90430417
# 3100  9.466395087   90.53360491      14.95347019       33.00440393
# 3101  9.573918397    90.4260816      14.95347019       35.21337701
# 3102  9.990152095    90.0098479             None              None
# 3103  10.12699803   89.87300197             None              None
#
#       ndf_percentage_dm
# 0             53.652397
# 1             52.202191
# 2             58.215864
# 3             54.690386
# 4             40.570000
# ...                 ...
# 3099          58.486156
# 3100          58.264698
# 3101          55.668862
# 3102                NaN
# 3103                NaN
#
# [3104 rows x 17 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_3_nutrition_sorted_by_sql = subset_3_nutrition_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_3_nutrition_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_3_nutrition_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (308, 17)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab         id tax_order    family         genus  \
# 0  1  Genetic bank  F24-3540   ABC-1467   Fabales  Fabaceae  Stylosanthes
# 1  2  Genetic bank  F24-3540   ABC-1467   Fabales  Fabaceae  Stylosanthes
# 2  3  Genetic bank  F24-3541   ABC-1475   Fabales  Fabaceae  Stylosanthes
# 3  4  Genetic bank  F24-3541   ABC-1475   Fabales  Fabaceae  Stylosanthes
# 4  5  Genetic bank  F25-0954  ABC-23326   Fabales  Fabaceae     Desmodium
#
#      species             tax_name    functional_group set_ciat dm_percentage  \
# 0     hamata  Stylosanthes hamata  Herbaceous_legumes       23          92.5
# 1     hamata  Stylosanthes hamata  Herbaceous_legumes       23         92.73
# 2     hamata  Stylosanthes hamata  Herbaceous_legumes       23         90.62
# 3     hamata  Stylosanthes hamata  Herbaceous_legumes       23         90.96
# 4  velutinum  Desmodium velutinum         Shrub_Trees       23         95.77
#
#   ash_dm om_percentage pc_percentage_dm adf_percentage_dm  ndf_percentage_dm
# 0   8.49         91.51            13.64             35.11          53.652397
# 1   8.59         91.41            13.64             34.44          52.202191
# 2    8.7          91.3            17.29             37.69          58.215864
# 3   8.81         91.19            17.29             37.17          54.690386
# 4  14.95         85.05            18.11             23.08          40.570000

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 2
subset_3_nutrition_sorted_by_sql.insert(0, 'subset', 3)

print("DataFrame with new 'subset' column:")
display(subset_3_nutrition_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab         id tax_order    family  \
# 0       3  1  Genetic bank  F24-3540   ABC-1467   Fabales  Fabaceae
# 1       3  2  Genetic bank  F24-3540   ABC-1467   Fabales  Fabaceae
# 2       3  3  Genetic bank  F24-3541   ABC-1475   Fabales  Fabaceae
# 3       3  4  Genetic bank  F24-3541   ABC-1475   Fabales  Fabaceae
# 4       3  5  Genetic bank  F25-0954  ABC-23326   Fabales  Fabaceae
#
#           genus    species             tax_name    functional_group set_ciat  \
# 0  Stylosanthes     hamata  Stylosanthes hamata  Herbaceous_legumes       23
# 1  Stylosanthes     hamata  Stylosanthes hamata  Herbaceous_legumes       23
# 2  Stylosanthes     hamata  Stylosanthes hamata  Herbaceous_legumes       23
# 3  Stylosanthes     hamata  Stylosanthes hamata  Herbaceous_legumes       23
# 4     Desmodium  velutinum  Desmodium velutinum         Shrub_Trees       23
#
#   dm_percentage ash_dm om_percentage pc_percentage_dm adf_percentage_dm  \
# 0          92.5   8.49         91.51            13.64             35.11
# 1         92.73   8.59         91.41            13.64             34.44
# 2         90.62    8.7          91.3            17.29             37.69
# 3         90.96   8.81         91.19            17.29             37.17
# 4         95.77  14.95         85.05            18.11             23.08
#
#    ndf_percentage_dm
# 0          53.652397
# 1          52.202191
# 2          58.215864
# 3          54.690386
# 4          40.570000

# %%
#subset_3_nutrition_sorted_by_sql.to_csv('/content/drive/MyDrive/lmf/output/04_15_2026_sql_data_frame_creation/subset_3_nutrition_sorted_by_sql.csv', index=False)

# %% [markdown]
# # 4. Subset 4

# %% [markdown]
# ## 4.1. Loading data

# %%
# Load the CSVs from Drive into pandas DataFrames
subset_4_information_samples = pd.read_csv('/content/drive/MyDrive/lmf/data/04_15_2026_sql_data_frame_creation/subset_4/csv/10_information_samples.csv', encoding='latin1')
subset_4_gas_prod = pd.read_csv('/content/drive/MyDrive/lmf/data/04_15_2026_sql_data_frame_creation/subset_4/csv/31_gas_prod_vf.csv', encoding='latin1')
subset_4_nutrition = pd.read_csv('/content/drive/MyDrive/lmf/data/04_15_2026_sql_data_frame_creation/subset_4/csv/40_result_q_raw_data.csv', encoding='latin1')

# %% [markdown]
# ## 4.2. Cleaning and formatting

# %%
# Clean first row containing orignal column names from excel files
subset_4_information_samples = remove_first_row(subset_4_information_samples)
subset_4_gas_prod = remove_first_row(subset_4_gas_prod)
subset_4_nutrition = remove_first_row(subset_4_nutrition)

# Remove '-1' tail from id columns
subset_4_information_samples['10_gene_bank_breeding_program_id'] = remove_minus_one_suffix(subset_4_information_samples['10_gene_bank_breeding_program_id'])
subset_4_gas_prod['31_gene_bank_id'] = remove_minus_one_suffix(subset_4_gas_prod['31_gene_bank_id'])
subset_4_nutrition['40_gene_bank_breeding_program_id'] = remove_minus_one_suffix(subset_4_nutrition['40_gene_bank_breeding_program_id'])

# Add '-' to lab ids and ensure correct format FXX-XXXX
subset_4_information_samples['10_ciat_lab_id'] = clean_lab_ids(subset_4_information_samples['10_ciat_lab_id'])
subset_4_gas_prod['31_ciat_id'] = clean_lab_ids(subset_4_gas_prod['31_ciat_id'])
subset_4_nutrition['40_ciat_lab_id'] = clean_lab_ids(subset_4_nutrition['40_ciat_lab_id'])

# Clean and standardize gene bank and breeding program ids
subset_4_information_samples['10_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_4_information_samples['10_gene_bank_breeding_program_id'])
subset_4_gas_prod['31_gene_bank_id'] = clean_standardize_ids(subset_4_gas_prod['31_gene_bank_id'])
subset_4_nutrition['40_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_4_nutrition['40_gene_bank_breeding_program_id'])

# %%
subset_4_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner', '10_set_ciat',
#        '10_ciat_lab_id', '10_gene_bank_breeding_program_id', '10_genus',
#        '10_species', '10_tax_name', '10_family', '10_order',
#        '10_functional_group', '10_batches_ciat', '10_id_lab',
#        '10_observaciones', 'Unnamed: 15'],
#       dtype='object')

# %%
# Check functional groups categories
subset_4_information_samples['10_functional_group'].unique()
# Out:
# array(['Tree', 'grasses', 'Arbustiva ', 'Herbaceous', 'Shurb_Tree',
#        'Shrub'], dtype=object)

# %%
# Define the mapping for functional groups
functional_group_mapping = {
    'Grasses': 'Grass',
    'grasses': 'Grass',
    'Shrub': 'Shrub_Trees',
    'Shrub/tree': 'Shrub_Trees',
    'Shrub/Tree': 'Shrub_Trees',
    'Shrub/Trees': 'Shrub_Trees',
    'Shrub_Trees': 'Shrub_Trees',
    'Shurb_Tree': 'Shrub_Trees',
    'Tree': 'Shrub_Trees',
    'Arbustiva ': 'Shrub_Trees',
    'Herbáceas': 'Herbaceous_legumes',
    'Herbáceas ': 'Herbaceous_legumes',
    'Herbaceous': 'Herbaceous_legumes',
    'Herbaceous legume': 'Herbaceous_legumes',
    'Climber': 'Herbaceous_legumes',
    'Legume': 'Herbaceous_legumes'
}

# Apply the mapping to centers datt
subset_4_information_samples['10_functional_group'] = subset_4_information_samples['10_functional_group'].replace(functional_group_mapping)

print('Updated functional group counts for subset_4_information_samples:')
display(subset_4_information_samples['10_functional_group'].value_counts())
# Out:
# Updated functional group counts for subset_4_information_samples:
# 10_functional_group
# Shrub_Trees           67
# Herbaceous_legumes    63
# Grass                 18
# Name: count, dtype: int64

# %% [markdown]
# ## 4.3. SQL query and dataframe creation

# %% [markdown]
# ### 4.3.1. Gas

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_4_information_samples.to_sql('subset_4_information_samples', conn_new, if_exists='replace', index=False)
subset_4_gas_prod.to_sql('subset_4_gas_prod', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_4_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner', '10_set_ciat',
#        '10_ciat_lab_id', '10_gene_bank_breeding_program_id', '10_genus',
#        '10_species', '10_tax_name', '10_family', '10_order',
#        '10_functional_group', '10_batches_ciat', '10_id_lab',
#        '10_observaciones', 'Unnamed: 15'],
#       dtype='object')

# %%
subset_4_gas_prod.columns
# Out:
# Index(['31_no', '31_date', '31_requisitioner', '31_gene_bank_id', '31_genus',
#        '31_species', '31_tax_name', '31_family', '31_order',
#        '31_functional_group', '31_ciat_id', '31_set_ciat', '31_batch',
#        '31_run', '31_replication', '31_syrange_no', '31_sample_weight_g',
#        '31_dm_incubated_mg', '31_digested_feed_mg', '31_time_0h',
#        '31_gas_0h_ml', '31_time_8h', '31_gas_8h_ml', '31_ch4_8h_percentage',
#        '31_v8_push_back_ml', '31_time_24h', '31_gas_24h_ml',
#        '31_ch4_24h_percentage', '31_remarks', '31_gp_8h_ml', '31_gp_8_24h',
#        '31_net_gas_8h_ml', '31_net_gas_8_24h_ml', '31_net_gas_24h_ml',
#        '31_ch4_8h_ml', '31_ch4_8_24h_ml', '31_ch4_24h_ml',
#        '31_gas_ml_g_dm_incubated_24h', '31_percentage_dmd_truly_digestibility',
#        '31_part_fact', '31_ch4_ml_in_gas_8h', '31_ch4_ml_in_gas_24h',
#        '31_ch4_ml_g_dm_incubated_24h', '31_ch4_ml_g_dmd_24h2',
#        '31_ch4_ml_g_ndf_digested_in_24h', '31_ch4_g_g_dm_incubated_24h',
#        '31_ch4_g_g_dmd_24h', '31_remarks.1'],
#       dtype='object')

# %%
query_combined = """
SELECT
    s4g."31_no" as no,
    s4i."10_requisitioner" as requisitioner,
    s4i."10_ciat_lab_id" as id_lab,
    s4i."10_gene_bank_breeding_program_id" as id,
    s4i."10_order" as tax_order,
    s4i."10_family" as family,
    s4i."10_genus" as genus,
    s4i."10_species" as species,
    s4i."10_tax_name" as tax_name,
    s4i."10_functional_group" as functional_group,
    s4g."31_set_ciat" as set_ciat,
    s4g."31_batch" as batch,
    s4g."31_run" as run,
    s4g."31_replication" as replication,
    s4g."31_syrange_no" as syrange,
    s4g."31_net_gas_8h_ml" as net_gas_8h_ml,
    s4g."31_net_gas_24h_ml" as net_gas_24h_ml,
    s4g."31_ch4_8h_ml" as ch4_8h_ml,
    s4g."31_ch4_24h_ml" as ch4_24h_ml,
    s4g."31_ch4_8h_percentage" as ch4_percentage_in_gas_8h,
    s4g."31_ch4_24h_percentage" as ch4_percentage_in_gas_24h,
    s4g."31_gas_ml_g_dm_incubated_24h" as gas_ml_g_dm_incubated_24h,
    s4g."31_ch4_ml_g_ndf_digested_in_24h" as ch4_ml_g_ndf_digested_24h,
    s4g."31_ch4_ml_g_dmd_24h2" as methane_intensity,
    s4g."31_percentage_dmd_truly_digestibility" as tddm
FROM
    subset_4_information_samples AS s4i
JOIN
    subset_4_gas_prod AS s4g
ON
    s4i."10_ciat_lab_id" = s4g."31_ciat_id"
ORDER BY
    CAST(no AS INTEGER) ASC
"""

subset_4_gas_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_4_gas_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#         no                     requisitioner    id_lab          id tax_order  \
# 0        3                           Genbank  F25-1728  CIAT-13262   Fabales
# 1        4                           Genbank  F25-1728  CIAT-13262   Fabales
# 2        5                           Genbank  F25-1728  CIAT-13262   Fabales
# 3        6                           Genbank  F25-1729  CIAT-13528   Fabales
# 4        7                           Genbank  F25-1729  CIAT-13528   Fabales
# ...    ...                               ...       ...         ...       ...
# 1283  1218   Jacobo Arango/Alejandro Montoya  F25-0008    Sample-8    Poales
# 1284  1218   Jacobo Arango/Alejandro Montoya  F25-0008    Sample-8    Poales
# 1285  1218  Jacobo Arango/ Alejandro Montoya  F25-0008    Sample-8    Poales
# 1286  1218  Jacobo Arango/ Alejandro Montoya  F25-0008    Sample-8    Poales
# 1287  1218  Jacobo Arango/ Alejandro Montoya  F25-0008    Sample-8    Poales
#
#         family         genus        species                  tax_name  \
# 0     Fabaceae  Dendrolobium    triangulare  Dendrolobium triangulare
# 1     Fabaceae  Dendrolobium    triangulare  Dendrolobium triangulare
# 2     Fabaceae  Dendrolobium    triangulare  Dendrolobium triangulare
# 3     Fabaceae  Dendrolobium    lanceolatum  Dendrolobium lanceolatum
# 4     Fabaceae  Dendrolobium    lanceolatum  Dendrolobium lanceolatum
# ...        ...           ...            ...                       ...
# 1283   Poaceae       Cynodon   nlemfuensis       Cynodon nlemfuensis
# 1284   Poaceae       Cynodon   nlemfuensis       Cynodon nlemfuensis
# 1285   Poaceae       Cynodon   nlemfuensis       Cynodon nlemfuensis
# 1286   Poaceae       Cynodon   nlemfuensis       Cynodon nlemfuensis
# 1287   Poaceae       Cynodon   nlemfuensis       Cynodon nlemfuensis
#
#      functional_group  ... net_gas_8h_ml net_gas_24h_ml    ch4_8h_ml  \
# 0         Shrub_Trees  ...   27.84497973    48.65745158  3.424932507
# 1         Shrub_Trees  ...          None           None         None
# 2         Shrub_Trees  ...   28.84497973    49.15745158  3.951762223
# 3         Shrub_Trees  ...   25.84497973    39.15745158  3.204777487
# 4         Shrub_Trees  ...   22.84497973    36.15745158  3.084072264
# ...               ...  ...           ...            ...          ...
# 1283            Grass  ...   26.53372354     68.7193156   4.27192949
# 1284            Grass  ...   26.53372354     68.7193156   4.27192949
# 1285            Grass  ...   26.53372354     68.7193156   4.27192949
# 1286            Grass  ...   26.53372354     68.7193156   4.27192949
# 1287            Grass  ...   26.53372354     68.7193156   4.27192949
#
#        ch4_24h_ml ch4_percentage_in_gas_8h ch4_percentage_in_gas_24h  \
# 0      6.94224025                     12.3                      16.9
# 1            None                     13.8                      17.7
# 2     7.567382212                     13.7                      17.8
# 3     5.414647814                     12.4                      16.6
# 4     5.293942591                     13.5                      16.6
# ...           ...                      ...                       ...
# 1283  11.27473777                     16.1                      16.6
# 1284  11.27473777                     16.1                      16.6
# 1285  11.27473777                     16.1                      16.6
# 1286  11.27473777                     16.1                      16.6
# 1287  11.27473777                     16.1                      16.6
#
#      gas_ml_g_dm_incubated_24h ch4_ml_g_ndf_digested_24h methane_intensity  \
# 0                  102.3664983              -0.478196663       47.37891768
# 1                         None                      None              None
# 2                  103.4597341              -0.301241039       65.21577414
# 3                  82.39706739              -0.129878029       58.70892202
# 4                  76.00830909              -0.159296905       45.95279388
# ...                        ...                       ...               ...
# 1283               146.6501056                0.93285091       72.69629761
# 1284               146.6501056                0.93285091       72.69629761
# 1285               146.6501056                0.93285091       72.69629761
# 1286               146.6501056                0.93285091       72.69629761
# 1287               146.6501056                0.93285091       72.69629761
#
#              tddm
# 0     30.82641294
# 1            None
# 2      24.4216506
# 3      19.4072251
# 4     24.21757002
# ...           ...
# 1283  33.09769209
# 1284  33.09769209
# 1285  33.09769209
# 1286  33.09769209
# 1287  33.09769209
#
# [1288 rows x 25 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_4_gas_sorted_by_sql = subset_4_gas_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_4_gas_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_4_gas_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (1183, 25)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab          id tax_order    family         genus  \
# 0  3       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae  Dendrolobium
# 1  4       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae  Dendrolobium
# 2  5       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae  Dendrolobium
# 3  6       Genbank  F25-1729  CIAT-13528   Fabales  Fabaceae  Dendrolobium
# 4  7       Genbank  F25-1729  CIAT-13528   Fabales  Fabaceae  Dendrolobium
#
#        species                  tax_name functional_group  ... net_gas_8h_ml  \
# 0  triangulare  Dendrolobium triangulare      Shrub_Trees  ...   27.84497973
# 1  triangulare  Dendrolobium triangulare      Shrub_Trees  ...          None
# 2  triangulare  Dendrolobium triangulare      Shrub_Trees  ...   28.84497973
# 3  lanceolatum  Dendrolobium lanceolatum      Shrub_Trees  ...   25.84497973
# 4  lanceolatum  Dendrolobium lanceolatum      Shrub_Trees  ...   22.84497973
#
#   net_gas_24h_ml    ch4_8h_ml   ch4_24h_ml ch4_percentage_in_gas_8h  \
# 0    48.65745158  3.424932507   6.94224025                     12.3
# 1           None         None         None                     13.8
# 2    49.15745158  3.951762223  7.567382212                     13.7
# 3    39.15745158  3.204777487  5.414647814                     12.4
# 4    36.15745158  3.084072264  5.293942591                     13.5
#
#   ch4_percentage_in_gas_24h gas_ml_g_dm_incubated_24h  \
# 0                      16.9               102.3664983
# 1                      17.7                      None
# 2                      17.8               103.4597341
# 3                      16.6               82.39706739
# 4                      16.6               76.00830909
#
#   ch4_ml_g_ndf_digested_24h methane_intensity         tddm
# 0              -0.478196663       47.37891768  30.82641294
# 1                      None              None         None
# 2              -0.301241039       65.21577414   24.4216506
# 3              -0.129878029       58.70892202   19.4072251
# 4              -0.159296905       45.95279388  24.21757002
#
# [5 rows x 25 columns]

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 2
subset_4_gas_sorted_by_sql.insert(0, 'subset', 4)

print("DataFrame with new 'subset' column:")
display(subset_4_gas_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab          id tax_order    family  \
# 0       4  3       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae
# 1       4  4       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae
# 2       4  5       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae
# 3       4  6       Genbank  F25-1729  CIAT-13528   Fabales  Fabaceae
# 4       4  7       Genbank  F25-1729  CIAT-13528   Fabales  Fabaceae
#
#           genus      species                  tax_name  ... net_gas_8h_ml  \
# 0  Dendrolobium  triangulare  Dendrolobium triangulare  ...   27.84497973
# 1  Dendrolobium  triangulare  Dendrolobium triangulare  ...          None
# 2  Dendrolobium  triangulare  Dendrolobium triangulare  ...   28.84497973
# 3  Dendrolobium  lanceolatum  Dendrolobium lanceolatum  ...   25.84497973
# 4  Dendrolobium  lanceolatum  Dendrolobium lanceolatum  ...   22.84497973
#
#   net_gas_24h_ml    ch4_8h_ml   ch4_24h_ml ch4_percentage_in_gas_8h  \
# 0    48.65745158  3.424932507   6.94224025                     12.3
# 1           None         None         None                     13.8
# 2    49.15745158  3.951762223  7.567382212                     13.7
# 3    39.15745158  3.204777487  5.414647814                     12.4
# 4    36.15745158  3.084072264  5.293942591                     13.5
#
#   ch4_percentage_in_gas_24h gas_ml_g_dm_incubated_24h  \
# 0                      16.9               102.3664983
# 1                      17.7                      None
# 2                      17.8               103.4597341
# 3                      16.6               82.39706739
# 4                      16.6               76.00830909
#
#   ch4_ml_g_ndf_digested_24h methane_intensity         tddm
# 0              -0.478196663       47.37891768  30.82641294
# 1                      None              None         None
# 2              -0.301241039       65.21577414   24.4216506
# 3              -0.129878029       58.70892202   19.4072251
# 4              -0.159296905       45.95279388  24.21757002
#
# [5 rows x 26 columns]

# %%
#subset_4_gas_sorted_by_sql.to_csv("/content/drive/MyDrive/lmf/output/04_15_2026_sql_data_frame_creation/subset_4_gas_sorted_by_sql.csv", index=None)

# %% [markdown]
# ### 4.3.2. Nutrition

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_4_information_samples.to_sql('subset_4_information_samples', conn_new, if_exists='replace', index=False)
subset_4_nutrition.to_sql('subset_4_nutrition', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_4_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner', '10_set_ciat',
#        '10_ciat_lab_id', '10_gene_bank_breeding_program_id', '10_genus',
#        '10_species', '10_tax_name', '10_family', '10_order',
#        '10_functional_group', '10_batches_ciat', '10_id_lab',
#        '10_observaciones', 'Unnamed: 15'],
#       dtype='object')

# %%
subset_4_nutrition.columns
# Out:
# Index(['40_sample_serial_no', '40_dat', '40_requisitioner', '40_set_ciat',
#        '40_ciat_lab_id', '40_gene_bank_breeding_program_id', '40_genus',
#        '40_species', '40_tax_name', '40_family', '40_order',
#        '40_functional_group', '40_dm_percentage', '40_av_dm_105', '40_ash_dm',
#        '40_av_ash_percentage', '40_om_percentage', '40_av_om_percentage',
#        '40_pc_percentage_dm', '40_av_pc_percentage', '40_adf_percentage_dm',
#        '40_av_adf_percentage_dm', '40_ndf_percentage_dm',
#        '40_av_ndf_percentage_dm'],
#       dtype='object')

# %%
query_combined = """
SELECT
    s4n."40_sample_serial_no" as no,
    s4i."10_requisitioner" as requisitioner,
    s4i."10_ciat_lab_id" as id_lab,
    s4i."10_gene_bank_breeding_program_id" as id,
    s4i."10_order" as tax_order,
    s4i."10_family" as family,
    s4i."10_genus" as genus,
    s4i."10_species" as species,
    s4i."10_tax_name" as tax_name,
    s4i."10_functional_group" as functional_group,
    s4i."10_set_ciat" as set_ciat,
    s4n."40_dm_percentage" as dm_percentage,
    s4n."40_ash_dm" as ash_dm,
    s4n."40_om_percentage" as om_percentage,
    s4n."40_pc_percentage_dm" as pc_percentage_dm,
    s4n."40_adf_percentage_dm" as adf_percentage_dm,
    s4n."40_ndf_percentage_dm" as ndf_percentage_dm



FROM
    subset_4_information_samples AS s4i
JOIN
    subset_4_nutrition AS s4n
ON
    s4i."10_ciat_lab_id" = s4n."40_ciat_lab_id"
ORDER BY
    CAST(no AS INTEGER) ASC NULLS LAST
"""

subset_4_nutrition_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_4_nutrition_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#        no                     requisitioner    id_lab               id  \
# 0       1                           Genbank  F25-1728       CIAT-13262
# 1       2                           Genbank  F25-1728       CIAT-13262
# 2       3                           Genbank  F25-1729       CIAT-13528
# 3       4                           Genbank  F25-1729       CIAT-13528
# 4       5                           Genbank  F25-1730       CIAT-13529
# ..    ...                               ...       ...              ...
# 331  None                          Breeding  F25-2104  CIAT-BR-06-1348
# 332  None                          Breeding  F25-2166  CIAT-BH-22-0528
# 333  None                          Breeding  F25-2166  CIAT-BH-22-0528
# 334  None  Jacobo Arango/ Alejandro Montoya  F25-0008         Sample-8
# 335  None  Jacobo Arango/ Alejandro Montoya  F25-0008         Sample-8
#
#     tax_order    family         genus          species  \
# 0     Fabales  Fabaceae  Dendrolobium      triangulare
# 1     Fabales  Fabaceae  Dendrolobium      triangulare
# 2     Fabales  Fabaceae  Dendrolobium      lanceolatum
# 3     Fabales  Fabaceae  Dendrolobium      lanceolatum
# 4     Fabales  Fabaceae  Dendrolobium      triangulare
# ..        ...       ...           ...              ...
# 331    Poales   Poaceae      Urochloa  interespecifico
# 332    Poales   Poaceae      Urochloa       humidicola
# 333    Poales   Poaceae      Urochloa       humidicola
# 334    Poales   Poaceae       Cynodon     nlemfuensis
# 335    Poales   Poaceae       Cynodon     nlemfuensis
#
#                        tax_name functional_group set_ciat dm_percentage  \
# 0      Dendrolobium triangulare      Shrub_Trees       27   94.90254873
# 1      Dendrolobium triangulare      Shrub_Trees       27   94.96201519
# 2      Dendrolobium lanceolatum      Shrub_Trees       27   95.00049995
# 3      Dendrolobium lanceolatum      Shrub_Trees       27    95.0909818
# 4      Dendrolobium triangulare      Shrub_Trees       27   94.30284858
# ..                          ...              ...      ...           ...
# 331  Brachiaria interespecifico            Grass       30         93.16
# 332         Urochloa humidicola            Grass       30          98.2
# 333         Urochloa humidicola            Grass       30         98.22
# 334        Cynodon nlemfuensis             Grass       30          93.6
# 335        Cynodon nlemfuensis             Grass       30          93.8
#
#           ash_dm om_percentage pc_percentage_dm adf_percentage_dm  \
# 0    8.675533642   91.32446636      18.98095108       47.87499326
# 1      8.7185193    91.2814807      18.98095108       47.17136086
# 2    7.585062735   92.41493727      16.89700161       48.31275422
# 3     7.58430438   92.41569562      16.89700161       48.41162026
# 4    6.715805626   93.28419437      18.17097604       44.49306584
# ..           ...           ...              ...               ...
# 331        14.68         85.32            12.18             25.85
# 332        12.48         87.52              8.8             36.63
# 333        15.08         84.92             8.73             36.96
# 334         11.3          88.7             13.1              37.8
# 335         11.5          88.5             13.1              37.8
#
#     ndf_percentage_dm
# 0         61.50467768
# 1         59.30403987
# 2         57.21705512
# 3         56.54204062
# 4         61.91582388
# ..                ...
# 331             60.28
# 332             73.37
# 333             73.74
# 334              76.1
# 335              76.1
#
# [336 rows x 17 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_4_nutrition_sorted_by_sql = subset_4_nutrition_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_4_nutrition_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_4_nutrition_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (336, 17)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab          id tax_order    family         genus  \
# 0  1       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae  Dendrolobium
# 1  2       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae  Dendrolobium
# 2  3       Genbank  F25-1729  CIAT-13528   Fabales  Fabaceae  Dendrolobium
# 3  4       Genbank  F25-1729  CIAT-13528   Fabales  Fabaceae  Dendrolobium
# 4  5       Genbank  F25-1730  CIAT-13529   Fabales  Fabaceae  Dendrolobium
#
#        species                  tax_name functional_group set_ciat  \
# 0  triangulare  Dendrolobium triangulare      Shrub_Trees       27
# 1  triangulare  Dendrolobium triangulare      Shrub_Trees       27
# 2  lanceolatum  Dendrolobium lanceolatum      Shrub_Trees       27
# 3  lanceolatum  Dendrolobium lanceolatum      Shrub_Trees       27
# 4  triangulare  Dendrolobium triangulare      Shrub_Trees       27
#
#   dm_percentage       ash_dm om_percentage pc_percentage_dm adf_percentage_dm  \
# 0   94.90254873  8.675533642   91.32446636      18.98095108       47.87499326
# 1   94.96201519    8.7185193    91.2814807      18.98095108       47.17136086
# 2   95.00049995  7.585062735   92.41493727      16.89700161       48.31275422
# 3    95.0909818   7.58430438   92.41569562      16.89700161       48.41162026
# 4   94.30284858  6.715805626   93.28419437      18.17097604       44.49306584
#
#   ndf_percentage_dm
# 0       61.50467768
# 1       59.30403987
# 2       57.21705512
# 3       56.54204062
# 4       61.91582388

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 4
subset_4_nutrition_sorted_by_sql.insert(0, 'subset', 4)

print("DataFrame with new 'subset' column:")
display(subset_4_nutrition_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab          id tax_order    family  \
# 0       4  1       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae
# 1       4  2       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae
# 2       4  3       Genbank  F25-1729  CIAT-13528   Fabales  Fabaceae
# 3       4  4       Genbank  F25-1729  CIAT-13528   Fabales  Fabaceae
# 4       4  5       Genbank  F25-1730  CIAT-13529   Fabales  Fabaceae
#
#           genus      species                  tax_name functional_group  \
# 0  Dendrolobium  triangulare  Dendrolobium triangulare      Shrub_Trees
# 1  Dendrolobium  triangulare  Dendrolobium triangulare      Shrub_Trees
# 2  Dendrolobium  lanceolatum  Dendrolobium lanceolatum      Shrub_Trees
# 3  Dendrolobium  lanceolatum  Dendrolobium lanceolatum      Shrub_Trees
# 4  Dendrolobium  triangulare  Dendrolobium triangulare      Shrub_Trees
#
#   set_ciat dm_percentage       ash_dm om_percentage pc_percentage_dm  \
# 0       27   94.90254873  8.675533642   91.32446636      18.98095108
# 1       27   94.96201519    8.7185193    91.2814807      18.98095108
# 2       27   95.00049995  7.585062735   92.41493727      16.89700161
# 3       27    95.0909818   7.58430438   92.41569562      16.89700161
# 4       27   94.30284858  6.715805626   93.28419437      18.17097604
#
#   adf_percentage_dm ndf_percentage_dm
# 0       47.87499326       61.50467768
# 1       47.17136086       59.30403987
# 2       48.31275422       57.21705512
# 3       48.41162026       56.54204062
# 4       44.49306584       61.91582388

# %%
#subset_4_nutrition_sorted_by_sql.to_csv('/content/drive/MyDrive/lmf/output/04_15_2026_sql_data_frame_creation/subset_4_nutrition_sorted_by_sql.csv', index=False)

# %% [markdown]
# # IV. Data frames compilation

# %% [markdown]
# ## IV.A. Gas compilation (all samples)

# %%
subsets_1_2_3_4_gas_sorted_by_sql = pd.concat([
    subset_1_gas_sorted_by_sql,
    subset_2_gas_sorted_by_sql,
    subset_3_gas_sorted_by_sql,
    subset_4_gas_sorted_by_sql
], ignore_index=True)

subsets_1_2_3_4_gas_sorted_by_sql.tail()
# Out:
#       subset    no                     requisitioner    id_lab  \
# 7238       4  1216                          Breeding  F25-2166
# 7239       4  1217   Jacobo Arango/Alejandro Montoya  F25-0008
# 7240       4  1217  Jacobo Arango/ Alejandro Montoya  F25-0008
# 7241       4  1218   Jacobo Arango/Alejandro Montoya  F25-0008
# 7242       4  1218  Jacobo Arango/ Alejandro Montoya  F25-0008
#
#                    id tax_order   family     genus        species  \
# 7238  CIAT-BH-22-0528    Poales  Poaceae  Urochloa     humidicola
# 7239         Sample-8    Poales  Poaceae   Cynodon   nlemfuensis
# 7240         Sample-8    Poales  Poaceae   Cynodon   nlemfuensis
# 7241         Sample-8    Poales  Poaceae   Cynodon   nlemfuensis
# 7242         Sample-8    Poales  Poaceae   Cynodon   nlemfuensis
#
#                   tax_name  ... net_gas_8h_ml net_gas_24h_ml    ch4_8h_ml  \
# 7238   Urochloa humidicola  ...   35.03372354     88.2193156  4.694518954
# 7239  Cynodon nlemfuensis   ...   28.03372354     69.2193156  4.429328319
# 7240  Cynodon nlemfuensis   ...   28.03372354     69.2193156  4.429328319
# 7241  Cynodon nlemfuensis   ...   26.53372354     68.7193156   4.27192949
# 7242  Cynodon nlemfuensis   ...   26.53372354     68.7193156   4.27192949
#
#        ch4_24h_ml ch4_percentage_in_gas_8h ch4_percentage_in_gas_24h  \
# 7238  13.04465691                     13.4                      15.7
# 7239  11.10139423                     15.8                      16.2
# 7240  11.10139423                     15.8                      16.2
# 7241  11.27473777                     16.1                      16.6
# 7242  11.27473777                     16.1                      16.6
#
#      gas_ml_g_dm_incubated_24h ch4_ml_g_ndf_digested_24h methane_intensity  \
# 7238               179.4391188                0.77427287       68.31835898
# 7239               147.6580767               0.709198924       66.12652784
# 7240               147.6580767               0.709198924       66.12652784
# 7241               146.6501056                0.93285091       72.69629761
# 7242               146.6501056                0.93285091       72.69629761
#
#              tddm
# 7238  38.83726861
# 7239  35.81225864
# 7240  35.81225864
# 7241  33.09769209
# 7242  33.09769209
#
# [5 rows x 26 columns]

# %%
#subsets_1_2_3_4_gas_sorted_by_sql.to_csv('/content/drive/MyDrive/lmf/output/04_15_2026_sql_data_frame_creation/subsets_1_2_3_4_gas_sorted_by_sql.csv', index = False)

# %% [markdown]
# ## IV.B. Nutrition compilation

# %%
subsets_1_2_3_4_nutrition_sorted_by_sql = pd.concat([
    subset_1_nutrition_sorted_by_sql,
    subset_2_nutrition_sorted_by_sql,
    subset_3_nutrition_sorted_by_sql,
    subset_4_nutrition_sorted_by_sql
], ignore_index=True)

subsets_1_2_3_4_nutrition_sorted_by_sql.tail()
# Out:
#       subset    no                     requisitioner    id_lab  \
# 1909       4  None                          Breeding  F25-2104
# 1910       4  None                          Breeding  F25-2166
# 1911       4  None                          Breeding  F25-2166
# 1912       4  None  Jacobo Arango/ Alejandro Montoya  F25-0008
# 1913       4  None  Jacobo Arango/ Alejandro Montoya  F25-0008
#
#                    id tax_order   family     genus          species  \
# 1909  CIAT-BR-06-1348    Poales  Poaceae  Urochloa  interespecifico
# 1910  CIAT-BH-22-0528    Poales  Poaceae  Urochloa       humidicola
# 1911  CIAT-BH-22-0528    Poales  Poaceae  Urochloa       humidicola
# 1912         Sample-8    Poales  Poaceae   Cynodon     nlemfuensis
# 1913         Sample-8    Poales  Poaceae   Cynodon     nlemfuensis
#
#                         tax_name functional_group set_ciat dm_percentage  \
# 1909  Brachiaria interespecifico            Grass       30         93.16
# 1910         Urochloa humidicola            Grass       30          98.2
# 1911         Urochloa humidicola            Grass       30         98.22
# 1912        Cynodon nlemfuensis             Grass       30          93.6
# 1913        Cynodon nlemfuensis             Grass       30          93.8
#
#      ash_dm om_percentage pc_percentage_dm adf_percentage_dm ndf_percentage_dm
# 1909  14.68         85.32            12.18             25.85             60.28
# 1910  12.48         87.52              8.8             36.63             73.37
# 1911  15.08         84.92             8.73             36.96             73.74
# 1912   11.3          88.7             13.1              37.8              76.1
# 1913   11.5          88.5             13.1              37.8              76.1

# %%
#subsets_1_2_3_4_nutrition_sorted_by_sql.to_csv('/content/drive/MyDrive/lmf/output/04_15_2026_sql_data_frame_creation/subsets_1_2_3_4_nutrition_sorted_by_sql.csv', index = False)

# %% [markdown]
# # V. Dashboards

# %% [markdown]
# ## V.A. Gas

# %%
#Columns processing

category_columns = ['subset', 'no', 'requisitioner', 'id_lab', 'id', 'tax_order', 'family',
       'genus', 'species', 'tax_name', 'functional_group', 'set_ciat', 'batch',
       'run', 'replication', 'syrange']
numeric_columns = ['net_gas_8h_ml', 'net_gas_24h_ml',
       'ch4_8h_ml', 'ch4_24h_ml', 'ch4_percentage_in_gas_8h',
       'ch4_percentage_in_gas_24h', 'gas_ml_g_dm_incubated_24h',
       'ch4_ml_g_ndf_digested_24h', 'methane_intensity', 'tddm']

for df in [subset_1_gas_sorted_by_sql, subset_2_gas_sorted_by_sql, subset_3_gas_sorted_by_sql, subset_4_gas_sorted_by_sql]:
    for col in category_columns:
        if col in df.columns:
            df[col] = df[col].astype('category')
    for col in numeric_columns:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
#Group by id and calculate columns average
subset_1_gas_sorted_by_sql_mean =  subset_1_gas_sorted_by_sql.groupby('id')[numeric_columns].mean().round(2)
subset_2_gas_sorted_by_sql_mean =  subset_2_gas_sorted_by_sql.groupby('id')[numeric_columns].mean().round(2)
subset_3_gas_sorted_by_sql_mean =  subset_3_gas_sorted_by_sql.groupby('id')[numeric_columns].mean().round(2)
subset_4_gas_sorted_by_sql_mean =  subset_4_gas_sorted_by_sql.groupby('id')[numeric_columns].mean().round(2)

#Reset indexes
subset_1_gas_sorted_by_sql_mean = subset_1_gas_sorted_by_sql_mean.reset_index()
subset_2_gas_sorted_by_sql_mean = subset_2_gas_sorted_by_sql_mean.reset_index()
subset_3_gas_sorted_by_sql_mean = subset_3_gas_sorted_by_sql_mean.reset_index()
subset_4_gas_sorted_by_sql_mean = subset_4_gas_sorted_by_sql_mean.reset_index()
# Out:
# /tmp/ipykernel_14411/2253817177.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   subset_1_gas_sorted_by_sql_mean =  subset_1_gas_sorted_by_sql.groupby('id')[numeric_columns].mean().round(2)
# /tmp/ipykernel_14411/2253817177.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   subset_2_gas_sorted_by_sql_mean =  subset_2_gas_sorted_by_sql.groupby('id')[numeric_columns].mean().round(2)
# /tmp/ipykernel_14411/2253817177.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   subset_3_gas_sorted_by_sql_mean =  subset_3_gas_sorted_by_sql.groupby('id')[numeric_columns].mean().round(2)
# /tmp/ipykernel_14411/2253817177.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   subset_4_gas_sorted_by_sql_mean =  subset_4_gas_sorted_by_sql.groupby('id')[numeric_columns].mean().round(2)

# %% [markdown]
# ### V.A.1. Complete

# %%
agg_functions_for_dashboard = {}
for col in category_columns:
    if col != 'id': # 'id' is the groupby key
        agg_functions_for_dashboard[col] = 'first' # Take the first occurrence for categorical columns
for col in numeric_columns:
    agg_functions_for_dashboard[col] = 'mean' # Calculate the mean for numeric columns

# Group by 'id' and apply the aggregation
# Using observed=False to ensure all categories are considered if 'id' was categorical itself,
# but it mainly affects the output type. For simple string/object IDs, it won't change behavior much.
subset_1_dashboard = subset_1_gas_sorted_by_sql.groupby('id', observed=False).agg(agg_functions_for_dashboard).round(2).reset_index()

# Reorder columns to place 'subset' first
cols = subset_1_dashboard.columns.tolist()
cols.remove('subset')
cols.remove('id')
new_column_order = ['subset', 'id'] + cols
subset_1_dashboard = subset_1_dashboard[new_column_order]

print("Dashboard with categorical columns maintained and 'subset' as the first column:")
display(subset_1_dashboard)
# Out:
# Dashboard with categorical columns maintained and 'subset' as the first column:
#     subset         id    no requisitioner    id_lab tax_order    family  \
# 0        1  ABC-10647  1057  Genetic bank  F24-3469   Fabales  Fabaceae
# 1        1  ABC-11194  1060  Genetic bank  F24-3470   Fabales  Fabaceae
# 2        1  ABC-11999  1179  Genetic bank  F24-3471   Fabales  Fabaceae
# 3        1  ABC-12318  1182  Genetic bank  F24-3472   Fabales  Fabaceae
# 4        1   ABC-1257   159  Genetic bank  F24-3427   Fabales  Fabaceae
# ..     ...        ...   ...           ...       ...       ...       ...
# 225      1   Sample-5  2288           LMF  F25-0005    Poales   Poaceae
# 226      1   Sample-6  2291           LMF  F25-0006    Poales   Poaceae
# 227      1   Sample-7  2294           LMF  F25-0007    Poales   Poaceae
# 228      1   Sample-8   677           LMF  F25-0019    Poales   Poaceae
# 229      1        nan   645      Breeding       nan       NaN       NaN
#
#             genus        species                 tax_name  ... net_gas_8h_ml  \
# 0    Stylosanthes         scabra      Stylosanthes scabra  ...         43.31
# 1    Stylosanthes         hamata      Stylosanthes hamata  ...         33.85
# 2    Stylosanthes     guianensis  Stylosanthes guianensis  ...         34.49
# 3    Stylosanthes         hamata      Stylosanthes hamata  ...         39.90
# 4    Stylosanthes         scabra      Stylosanthes scabra  ...         34.23
# ..            ...            ...                      ...  ...           ...
# 225       Cynodon   nlemfuensis      Cynodon nlemfuensis   ...         25.37
# 226       Cynodon   nlemfuensis      Cynodon nlemfuensis   ...         24.93
# 227       Cynodon   nlemfuensis      Cynodon nlemfuensis   ...         25.67
# 228       Cynodon   nlemfuensis      Cynodon nlemfuensis   ...         20.27
# 229           NaN            NaN                      NaN  ...           NaN
#
#     net_gas_24h_ml ch4_8h_ml ch4_24h_ml ch4_percentage_in_gas_8h  \
# 0            79.20      6.90      14.88                    15.90
# 1            70.41      5.14      12.69                    15.17
# 2            78.22      4.50      12.75                    12.98
# 3            82.40      5.58      14.01                    13.99
# 4            70.83      5.01      11.62                    14.53
# ..             ...       ...        ...                      ...
# 225          63.83      3.66       9.87                    14.43
# 226          64.72      3.59      10.10                    14.40
# 227          63.98      3.62       9.60                    14.10
# 228          48.17      3.27       8.44                    16.47
# 229            NaN       NaN        NaN                      NaN
#
#     ch4_percentage_in_gas_24h  gas_ml_g_dm_incubated_24h  \
# 0                       18.79                     170.35
# 1                       18.02                     151.51
# 2                       16.25                     167.21
# 3                       16.96                     175.02
# 4                       16.40                     152.70
# ..                        ...                        ...
# 225                     15.46                     140.48
# 226                     15.61                     142.39
# 227                     15.00                     140.76
# 228                     17.76                     119.28
# 229                       NaN                        NaN
#
#      ch4_ml_g_ndf_digested_24h  methane_intensity   tddm
# 0                       151.04              48.31  67.34
# 1                       184.66              46.12  59.25
# 2                       139.83              46.61  58.55
# 3                       259.42              52.27  56.88
# 4                        93.20              43.29  58.67
# ..                         ...                ...    ...
# 225                        NaN              69.12  33.18
# 226                        NaN              74.37  31.71
# 227                        NaN              78.40  28.74
# 228                        NaN              53.79  40.17
# 229                        NaN                NaN    NaN
#
# [230 rows x 26 columns]

# %%
# Group by 'id' and apply the aggregation for subset_3
subset_2_dashboard = subset_2_gas_sorted_by_sql.groupby('id', observed=False).agg(agg_functions_for_dashboard).round(2).reset_index()

# Reorder columns to place 'subset' first
cols = subset_2_dashboard.columns.tolist()
cols.remove('subset')
cols.remove('id')
new_column_order = ['subset', 'id'] + cols
subset_2_dashboard = subset_2_dashboard[new_column_order]

print("Dashboard for subset_2 with categorical columns maintained and 'subset' as the first column:")
display(subset_2_dashboard.head())
# Out:
# Dashboard for subset_2 with categorical columns maintained and 'subset' as the first column:
#   subset         id    no requisitioner    id_lab tax_order    family  \
# 0      2  ABC-11162    86  Genetic bank  F24-3636   Fabales  Fabaceae
# 1      2  ABC-11833  1355  Genetic bank  F25-0989   Fabales  Fabaceae
# 2      2  ABC-11998  1296  Genetic bank  F25-0970   Fabales  Fabaceae
# 3      2  ABC-13149  1299  Genetic bank  F25-0971   Fabales  Fabaceae
# 4      2  ABC-13268   954  Genetic bank  F25-0931   Fabales  Fabaceae
#
#           genus       species                 tax_name  ... net_gas_8h_ml  \
# 0  Stylosanthes        scabra      Stylosanthes scabra  ...         44.47
# 1  Stylosanthes    guianensis  Stylosanthes guianensis  ...         33.95
# 2  Stylosanthes    guianensis  Stylosanthes guianensis  ...         30.70
# 3     Desmodium  strigillosum   Desmodium strigillosum  ...         32.62
# 4      Tadehagi    triquetrum      Tadehagi triquetrum  ...         21.73
#
#   net_gas_24h_ml ch4_8h_ml ch4_24h_ml ch4_percentage_in_gas_8h  \
# 0          85.20      5.53      12.70                    12.44
# 1          63.44      3.95       8.36                    11.63
# 2          65.21      3.43       7.79                    11.18
# 3          57.39      4.35       8.26                    13.32
# 4          42.65      2.43       5.52                    11.21
#
#   ch4_percentage_in_gas_24h  gas_ml_g_dm_incubated_24h  \
# 0                     17.57                     186.22
# 1                     15.02                     133.53
# 2                     12.67                     137.81
# 3                     15.82                     122.36
# 4                     14.72                      90.50
#
#    ch4_ml_g_ndf_digested_24h  methane_intensity   tddm
# 0                       8.39              59.15  52.92
# 1                      -6.92              63.62  30.51
# 2                       7.28              44.53  41.13
# 3                     -50.93             108.91  25.02
# 4                     -20.50              30.90  38.94
#
# [5 rows x 26 columns]

# %%
# Group by 'id' and apply the aggregation for subset_3
subset_3_dashboard = subset_3_gas_sorted_by_sql.groupby('id', observed=False).agg(agg_functions_for_dashboard).round(2).reset_index()

# Reorder columns to place 'subset' first
cols = subset_3_dashboard.columns.tolist()
cols.remove('subset')
cols.remove('id')
new_column_order = ['subset', 'id'] + cols
subset_3_dashboard = subset_3_dashboard[new_column_order]

print("Dashboard for subset_3 with categorical columns maintained and 'subset' as the first column:")
display(subset_3_dashboard.head())
# Out:
# Dashboard for subset_3 with categorical columns maintained and 'subset' as the first column:
#   subset         id   no requisitioner    id_lab tax_order    family  \
# 0      3  ABC-10440  675  Genetic bank  F24-3549   Fabales  Fabaceae
# 1      3  ABC-10613  678  Genetic bank  F24-3550   Fabales  Fabaceae
# 2      3  ABC-10627  681  Genetic bank  F24-3551   Fabales  Fabaceae
# 3      3  ABC-10634  684  Genetic bank  F24-3552   Fabales  Fabaceae
# 4      3  ABC-10639  687  Genetic bank  F24-3553   Fabales  Fabaceae
#
#           genus  species              tax_name  ... net_gas_8h_ml  \
# 0  Stylosanthes  humilis  Stylosanthes humilis  ...         38.18
# 1  Stylosanthes   scabra   Stylosanthes scabra  ...         37.35
# 2  Stylosanthes   scabra   Stylosanthes scabra  ...         35.52
# 3  Stylosanthes   scabra   Stylosanthes scabra  ...         39.63
# 4  Stylosanthes   scabra   Stylosanthes scabra  ...         40.85
#
#   net_gas_24h_ml ch4_8h_ml ch4_24h_ml ch4_percentage_in_gas_8h  \
# 0          81.25      4.69      11.22                    12.24
# 1          79.09      4.58      10.97                    12.26
# 2          76.43      4.43      10.40                    12.49
# 3          88.53      4.97      12.00                    12.53
# 4          88.31      5.23      12.60                    12.80
#
#   ch4_percentage_in_gas_24h  gas_ml_g_dm_incubated_24h  \
# 0                     13.73                     179.98
# 1                     13.87                     170.29
# 2                     13.61                     163.60
# 3                     13.56                     190.25
# 4                     14.27                     189.43
#
#    ch4_ml_g_ndf_digested_24h  methane_intensity   tddm
# 0                     113.94              45.94  54.20
# 1                   -1263.13              63.05  39.50
# 2                     685.51              46.84  47.71
# 3                    -378.49              52.78  50.55
# 4                   -1213.70              52.70  51.87
#
# [5 rows x 26 columns]

# %%
# Group by 'id' and apply the aggregation for subset_3
subset_4_dashboard = subset_4_gas_sorted_by_sql.groupby('id', observed=False).agg(agg_functions_for_dashboard).round(2).reset_index()

# Reorder columns to place 'subset' first
cols = subset_3_dashboard.columns.tolist()
cols.remove('subset')
cols.remove('id')
new_column_order = ['subset', 'id'] + cols
subset_4_dashboard = subset_4_dashboard[new_column_order]

print("Dashboard for subset_4 with categorical columns maintained and 'subset' as the first column:")
display(subset_4_dashboard.head())
# Out:
# Dashboard for subset_4 with categorical columns maintained and 'subset' as the first column:
#   subset          id   no requisitioner    id_lab tax_order    family  \
# 0      4  CIAT-10026  440       Genbank  F25-2596   Fabales  Fabaceae
# 1      4  CIAT-12411  443       Genbank  F25-2597   Fabales  Fabaceae
# 2      4  CIAT-13258   86       Genbank  F25-1755   Fabales  Fabaceae
# 3      4  CIAT-13260   89       Genbank  F25-1756   Fabales  Fabaceae
# 4      4  CIAT-13262    3       Genbank  F25-1728   Fabales  Fabaceae
#
#           genus      species                  tax_name  ... net_gas_8h_ml  \
# 0  Stylosanthes     seabrana     Stylosanthes seabrana  ...         29.60
# 1  Stylosanthes  sympodialis  Stylosanthes sympodialis  ...         38.25
# 2  Dendrolobium  lanceolatum  Dendrolobium lanceolatum  ...         18.81
# 3  Dendrolobium  lanceolatum  Dendrolobium lanceolatum  ...         21.62
# 4  Dendrolobium  triangulare  Dendrolobium triangulare  ...         27.50
#
#   net_gas_24h_ml ch4_8h_ml ch4_24h_ml ch4_percentage_in_gas_8h  \
# 0          73.02      3.34       9.72                    11.25
# 1          82.87      4.27      11.12                    11.15
# 2          28.98      2.42       3.81                    12.89
# 3          33.98      2.93       4.92                    13.58
# 4          46.96      3.70       7.06                    13.54
#
#   ch4_percentage_in_gas_24h  gas_ml_g_dm_incubated_24h  \
# 0                     14.66                     157.39
# 1                     15.35                     180.65
# 2                     13.68                      61.24
# 3                     16.11                      72.20
# 4                     17.31                      98.84
#
#    ch4_ml_g_ndf_digested_24h  methane_intensity   tddm
# 0                       0.52              51.61  42.25
# 1                       0.49              44.51  55.06
# 2                      -0.14              41.85  19.80
# 3                      -0.25              60.35  18.90
# 4                      -0.82              48.87  31.33
#
# [5 rows x 26 columns]

# %%
subsets_1_2_3_4_gas_dashboard_complete = pd.concat([
    subset_1_dashboard,
    subset_2_dashboard,
    subset_3_dashboard,
    subset_4_dashboard
], ignore_index=True)

subsets_1_2_3_4_gas_dashboard_complete
# Out:
#      subset                 id    no                    requisitioner  \
# 0         1          ABC-10647  1057                     Genetic bank
# 1         1          ABC-11194  1060                     Genetic bank
# 2         1          ABC-11999  1179                     Genetic bank
# 3         1          ABC-12318  1182                     Genetic bank
# 4         1           ABC-1257   159                     Genetic bank
# ..      ...                ...   ...                              ...
# 743       4    CIAT-BH-22-3830   348                          Genbank
# 744       4    CIAT-BR-06-1348  1066                         Breeding
# 745       4  Cayman-Br-02-1752    95                    Isabel Molina
# 746       4           Sample-8   101  Jacobo Arango/Alejandro Montoya
# 747       4                nan    98                  Mauricio Sotelo
#
#        id_lab tax_order    family         genus          species  \
# 0    F24-3469   Fabales  Fabaceae  Stylosanthes           scabra
# 1    F24-3470   Fabales  Fabaceae  Stylosanthes           hamata
# 2    F24-3471   Fabales  Fabaceae  Stylosanthes       guianensis
# 3    F24-3472   Fabales  Fabaceae  Stylosanthes           hamata
# 4    F24-3427   Fabales  Fabaceae  Stylosanthes           scabra
# ..        ...       ...       ...           ...              ...
# 743  F25-2187    Poales   Poaceae      Urochloa       humidicola
# 744  F25-2104    Poales   Poaceae      Urochloa  interespecifico
# 745  F25-2640    Poales   Poaceae      Urochloa  interespecifico
# 746  F25-0008    Poales   Poaceae       Cynodon     nlemfuensis
# 747  F25-2641   Fabales  Fabaceae  Gliricidia             sepium
#
#                        tax_name  ... net_gas_8h_ml net_gas_24h_ml ch4_8h_ml  \
# 0           Stylosanthes scabra  ...         43.31          79.20      6.90
# 1           Stylosanthes hamata  ...         33.85          70.41      5.14
# 2       Stylosanthes guianensis  ...         34.49          78.22      4.50
# 3           Stylosanthes hamata  ...         39.90          82.40      5.58
# 4           Stylosanthes scabra  ...         34.23          70.83      5.01
# ..                          ...  ...           ...            ...       ...
# 743         Urochloa humidicola  ...         40.51          97.36      5.64
# 744  Brachiaria interespecifico  ...         39.30          89.04      5.29
# 745    Urochloa interespecifico  ...         39.43          88.29      5.11
# 746        Cynodon nlemfuensis   ...         22.26          59.62      3.34
# 747          Gliricidia sepium   ...         37.63          78.54      5.15
#
#     ch4_24h_ml ch4_percentage_in_gas_8h ch4_percentage_in_gas_24h  \
# 0        14.88                    15.90                     18.79
# 1        12.69                    15.17                     18.02
# 2        12.75                    12.98                     16.25
# 3        14.01                    13.99                     16.96
# 4        11.62                    14.53                     16.40
# ..         ...                      ...                       ...
# 743      14.42                    13.88                     15.44
# 744      12.99                    13.46                     15.49
# 745      11.80                    12.99                     13.71
# 746       9.43                    14.96                     16.26
# 747      11.77                    13.66                     16.15
#
#      gas_ml_g_dm_incubated_24h  ch4_ml_g_ndf_digested_24h  methane_intensity  \
# 0                       170.35                     151.04              48.31
# 1                       151.51                     184.66              46.12
# 2                       167.21                     139.83              46.61
# 3                       175.02                     259.42              52.27
# 4                       152.70                      93.20              43.29
# ..                         ...                        ...                ...
# 743                     202.78                       0.76              75.10
# 744                     191.18                       0.63              51.50
# 745                     181.98                      -4.20              50.17
# 746                     127.36                       0.46              86.08
# 747                     167.90                      -3.09              45.48
#
#       tddm
# 0    67.34
# 1    59.25
# 2    58.55
# 3    56.88
# 4    58.67
# ..     ...
# 743  40.80
# 744  54.58
# 745  50.22
# 746  27.04
# 747  55.91
#
# [748 rows x 26 columns]

# %%
#subsets_1_2_3_4_gas_dashboard_complete.to_csv('/content/drive/MyDrive/lmf/output/04_15_2026_sql_data_frame_creation/subsets_1_2_3_4_gas_dashboard_complete.csv', index = False)

# %% [markdown]
# ### V.A.2. Small

# %%
subsets_1_2_3_4_gas_dashboard_small = subsets_1_2_3_4_gas_dashboard_complete[['subset', 'id_lab', 'id', 'tax_name', 'functional_group', 'ch4_percentage_in_gas_8h',
       'ch4_percentage_in_gas_24h', 'methane_intensity', 'tddm']]
subsets_1_2_3_4_gas_dashboard_small
# Out:
#      subset    id_lab                 id                    tax_name  \
# 0         1  F24-3469          ABC-10647         Stylosanthes scabra
# 1         1  F24-3470          ABC-11194         Stylosanthes hamata
# 2         1  F24-3471          ABC-11999     Stylosanthes guianensis
# 3         1  F24-3472          ABC-12318         Stylosanthes hamata
# 4         1  F24-3427           ABC-1257         Stylosanthes scabra
# ..      ...       ...                ...                         ...
# 743       4  F25-2187    CIAT-BH-22-3830         Urochloa humidicola
# 744       4  F25-2104    CIAT-BR-06-1348  Brachiaria interespecifico
# 745       4  F25-2640  Cayman-Br-02-1752    Urochloa interespecifico
# 746       4  F25-0008           Sample-8        Cynodon nlemfuensis
# 747       4  F25-2641                nan          Gliricidia sepium
#
#        functional_group  ch4_percentage_in_gas_8h  ch4_percentage_in_gas_24h  \
# 0    Herbaceous_legumes                     15.90                      18.79
# 1    Herbaceous_legumes                     15.17                      18.02
# 2    Herbaceous_legumes                     12.98                      16.25
# 3    Herbaceous_legumes                     13.99                      16.96
# 4    Herbaceous_legumes                     14.53                      16.40
# ..                  ...                       ...                        ...
# 743               Grass                     13.88                      15.44
# 744               Grass                     13.46                      15.49
# 745               Grass                     12.99                      13.71
# 746               Grass                     14.96                      16.26
# 747         Shrub_Trees                     13.66                      16.15
#
#      methane_intensity   tddm
# 0                48.31  67.34
# 1                46.12  59.25
# 2                46.61  58.55
# 3                52.27  56.88
# 4                43.29  58.67
# ..                 ...    ...
# 743              75.10  40.80
# 744              51.50  54.58
# 745              50.17  50.22
# 746              86.08  27.04
# 747              45.48  55.91
#
# [748 rows x 9 columns]

# %%
#subsets_1_2_3_4_gas_dashboard_small.to_csv('/content/drive/MyDrive/lmf/output/04_15_2026_sql_data_frame_creation/subsets_1_2_3_4_gas_dashboard_small.csv', index = False)

# %% [markdown]
# ## V.B. Nutrition

# %%
subset_1_nutrition_sorted_by_sql.columns
# Out:
# Index(['subset', 'no', 'requisitioner', 'id_lab', 'id', 'tax_order', 'family',
#        'genus', 'species', 'tax_name', 'functional_group', 'set_ciat',
#        'dm_percentage', 'ash_dm', 'om_percentage', 'pc_percentage_dm',
#        'adf_percentage_dm', 'ndf_percentage_dm'],
#       dtype='object')

# %%
#Columns processing

category_columns = ['subset', 'no', 'requisitioner', 'id_lab', 'id', 'tax_order', 'family',
       'genus', 'species', 'tax_name', 'functional_group', 'set_ciat']
numeric_columns = ['dm_percentage', 'ash_dm', 'om_percentage', 'pc_percentage_dm',
       'adf_percentage_dm', 'ndf_percentage_dm']

for df in [subset_1_nutrition_sorted_by_sql, subset_2_nutrition_sorted_by_sql, subset_3_nutrition_sorted_by_sql, subset_4_nutrition_sorted_by_sql]:
    for col in category_columns:
        if col in df.columns:
            df[col] = df[col].astype('category')
    for col in numeric_columns:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
agg_functions_for_dashboard = {}
for col in category_columns:
    if col != 'id': # 'id' is the groupby key
        agg_functions_for_dashboard[col] = 'first' # Take the first occurrence for categorical columns
for col in numeric_columns:
    agg_functions_for_dashboard[col] = 'mean' # Calculate the mean for numeric columns

# Group by 'id' and apply the aggregation
# Using observed=False to ensure all categories are considered if 'id' was categorical itself,
# but it mainly affects the output type. For simple string/object IDs, it won't change behavior much.
subset_1_nutrition_dashboard = subset_1_nutrition_sorted_by_sql.groupby('id', observed=False).agg(agg_functions_for_dashboard).round(2).reset_index()

# Reorder columns to place 'subset' first
cols = subset_1_nutrition_dashboard.columns.tolist()
cols.remove('subset')
cols.remove('id')
new_column_order = ['subset', 'id'] + cols
subset_1_nutrition_dashboard = subset_1_nutrition_dashboard[new_column_order]

print("Dashboard with categorical columns maintained and 'subset' as the first column:")
display(subset_1_nutrition_dashboard)
# Out:
# Dashboard with categorical columns maintained and 'subset' as the first column:
#     subset              id   no requisitioner    id_lab tax_order    family  \
# 0        1       ABC-10647  197  Genetic bank  F24-3469   Fabales  Fabaceae
# 1        1       ABC-11194  199  Genetic bank  F24-3470   Fabales  Fabaceae
# 2        1       ABC-11999  201  Genetic bank  F24-3471   Fabales  Fabaceae
# 3        1       ABC-12318  203  Genetic bank  F24-3472   Fabales  Fabaceae
# 4        1        ABC-1257  113  Genetic bank  F24-3427   Fabales  Fabaceae
# ..     ...             ...  ...           ...       ...       ...       ...
# 167      1  ABC-PM-21-4449  289      Breeding  F25-1004    Poales   Poaceae
# 168      1  ABC-PM-21-6080  277      Breeding  F25-0998    Poales   Poaceae
# 169      1  ABC-PM-21-6529  295      Breeding  F25-1007    Poales   Poaceae
# 170      1  ABC-PM-21-6628   89      Breeding  F24-3601    Poales   Poaceae
# 171      1  ABC-PM-21-6638  285      Breeding  F25-1002    Poales   Poaceae
#
#             genus     species                 tax_name    functional_group  \
# 0    Stylosanthes      scabra      Stylosanthes scabra  Herbaceous_legumes
# 1    Stylosanthes      hamata      Stylosanthes hamata  Herbaceous_legumes
# 2    Stylosanthes  guianensis  Stylosanthes guianensis  Herbaceous_legumes
# 3    Stylosanthes      hamata      Stylosanthes hamata  Herbaceous_legumes
# 4    Stylosanthes      scabra      Stylosanthes scabra  Herbaceous_legumes
# ..            ...         ...                      ...                 ...
# 167  Megathyrsus      maximus      Megathyrsus maximus               Grass
# 168  Megathyrsus      maximus      Megathyrsus maximus               Grass
# 169  Megathyrsus      maximus      Megathyrsus maximus               Grass
# 170   Megathyrsus     maximus      Megathyrsus maximus               Grass
# 171  Megathyrsus      maximus      Megathyrsus maximus               Grass
#
#     set_ciat  dm_percentage  ash_dm  om_percentage  pc_percentage_dm  \
# 0          6          92.93    9.36          90.64             20.02
# 1          6          92.89    9.61          90.39             21.18
# 2          7          93.50   10.46          89.54             20.09
# 3          7          94.10   11.08          88.92             22.05
# 4          5          92.72    9.52          90.48             17.96
# ..       ...            ...     ...            ...               ...
# 167        9          96.14   12.80          87.20             14.54
# 168        9          96.35   15.44          84.56             18.29
# 169        9          96.56   14.92          85.08             12.68
# 170        5          95.22   14.10          85.90              9.98
# 171        9          95.67   16.65          83.35             14.24
#
#      adf_percentage_dm  ndf_percentage_dm
# 0                32.44              56.19
# 1                30.18              55.94
# 2                33.90              61.32
# 3                29.34              55.26
# 4                35.90              69.91
# ..                 ...                ...
# 167              32.67              70.18
# 168              31.99              67.47
# 169              30.15              68.18
# 170              29.83              64.96
# 171              34.54              67.34
#
# [172 rows x 18 columns]

# %%
agg_functions_for_dashboard = {}
for col in category_columns:
    if col != 'id': # 'id' is the groupby key
        agg_functions_for_dashboard[col] = 'first' # Take the first occurrence for categorical columns
for col in numeric_columns:
    agg_functions_for_dashboard[col] = 'mean' # Calculate the mean for numeric columns

# Group by 'id' and apply the aggregation
# Using observed=False to ensure all categories are considered if 'id' was categorical itself,
# but it mainly affects the output type. For simple string/object IDs, it won't change behavior much.
subset_2_nutrition_dashboard = subset_2_nutrition_sorted_by_sql.groupby('id', observed=False).agg(agg_functions_for_dashboard).round(2).reset_index()

# Reorder columns to place 'subset' first
cols = subset_2_nutrition_dashboard.columns.tolist()
cols.remove('subset')
cols.remove('id')
new_column_order = ['subset', 'id'] + cols
subset_2_nutrition_dashboard = subset_2_nutrition_dashboard[new_column_order]

print("Dashboard with categorical columns maintained and 'subset' as the first column:")
display(subset_2_nutrition_dashboard)
# Out:
# Dashboard with categorical columns maintained and 'subset' as the first column:
#     subset                       id   no requisitioner    id_lab    tax_order  \
# 0        2                ABC-11162   55  Genetic bank  F24-3636      Fabales
# 1        2                ABC-11833  323  Genetic bank  F25-0989      Fabales
# 2        2                ABC-11998  285  Genetic bank  F25-0970      Fabales
# 3        2                ABC-13149  287  Genetic bank  F25-0971      Fabales
# 4        2                ABC-13268  201  Genetic bank  F25-0931      Fabales
# ..     ...                      ...  ...           ...       ...          ...
# 248      2  Hohenheimer-Heustandard   61           LMF  F25-0017       Forage
# 249      2    Homenheim-Concentrate   63           LMF  F25-0018  Concentrate
# 250      2               ILRI-15551  187           LMF  F25-2076    \tFabales
# 251      2             Muestra-#-02  325    LMF-invivo  F25-2131       Poales
# 252      2                 Sample-8  331           LMF  F25-0008       Poales
#
#           family         genus        species                 tax_name  \
# 0       Fabaceae  Stylosanthes         scabra      Stylosanthes scabra
# 1       Fabaceae  Stylosanthes     guianensis  Stylosanthes guianensis
# 2       Fabaceae  Stylosanthes     guianensis  Stylosanthes guianensis
# 3       Fabaceae     Desmodium   strigillosum   Desmodium strigillosum
# 4       Fabaceae      Tadehagi     triquetrum      Tadehagi triquetrum
# ..           ...           ...            ...                      ...
# 248       Forage   Hohenheimer    Heustandard  Hohenheimer Heustandard
# 249  Concentrate     Homenheim    Concentrate    Homenheim Concentrate
# 250     Fabaceae      Leucaena   diversifolia    Leucaena diversifolia
# 251      Poaceae       Cynodon    nlenfuensis      Cynodon nlemfuensis
# 252      Poaceae       Cynodon   nlemfuensis      Cynodon nlemfuensis
#
#        functional_group set_ciat  dm_percentage  ash_dm  om_percentage  \
# 0    Herbaceous_legumes       14          91.46   22.30          77.69
# 1    Herbaceous_legumes       18          94.97    9.91          90.08
# 2    Herbaceous_legumes       18          94.60   12.78          87.22
# 3    Herbaceous_legumes       18          93.78    8.18          91.82
# 4    Herbaceous_legumes       17          94.21    7.54          92.46
# ..                  ...      ...            ...     ...            ...
# 248              Forage       14          91.33   10.06          89.94
# 249         Concentrate       14          89.69    6.04          93.96
# 250         Shrub_Trees       16          93.73    7.76          92.24
# 251               Grass       18          92.18    9.30          90.70
# 252               Grass       14          93.73   11.41          88.59
#
#      pc_percentage_dm  adf_percentage_dm  ndf_percentage_dm
# 0               17.11              23.00              51.40
# 1               13.53              41.13              65.00
# 2               14.22              33.38              63.50
# 3               13.45              35.33              49.68
# 4               14.85              42.80              50.67
# ..                ...                ...                ...
# 248              0.00               0.00               0.00
# 249              0.00               0.00               0.00
# 250             28.22              28.55              56.21
# 251              5.74              40.04              77.78
# 252              0.00               0.00               0.00
#
# [253 rows x 18 columns]

# %%
agg_functions_for_dashboard = {}
for col in category_columns:
    if col != 'id': # 'id' is the groupby key
        agg_functions_for_dashboard[col] = 'first' # Take the first occurrence for categorical columns
for col in numeric_columns:
    agg_functions_for_dashboard[col] = 'mean' # Calculate the mean for numeric columns

# Group by 'id' and apply the aggregation
# Using observed=False to ensure all categories are considered if 'id' was categorical itself,
# but it mainly affects the output type. For simple string/object IDs, it won't change behavior much.
subset_3_nutrition_dashboard = subset_3_nutrition_sorted_by_sql.groupby('id', observed=False).agg(agg_functions_for_dashboard).round(2).reset_index()

# Reorder columns to place 'subset' first
cols = subset_3_nutrition_dashboard.columns.tolist()
cols.remove('subset')
cols.remove('id')
new_column_order = ['subset', 'id'] + cols
subset_3_nutrition_dashboard = subset_3_nutrition_dashboard[new_column_order]

print("Dashboard with categorical columns maintained and 'subset' as the first column:")
display(subset_3_nutrition_dashboard)
# Out:
# Dashboard with categorical columns maintained and 'subset' as the first column:
#     subset                  id   no requisitioner    id_lab  tax_order  \
# 0        3           ABC-10440  155  Genetic bank  F24-3549    Fabales
# 1        3           ABC-10613  157  Genetic bank  F24-3550    Fabales
# 2        3           ABC-10627  159  Genetic bank  F24-3551    Fabales
# 3        3           ABC-10634  161  Genetic bank  F24-3552    Fabales
# 4        3           ABC-10639  163  Genetic bank  F24-3553    Fabales
# ..     ...                 ...  ...           ...       ...        ...
# 118      3        Muestra-#-02   57    LMF-invivo  F25-2131     Poales
# 119      3  Paja-Sabana-Madura  147     Benchmark  F25-2566     Poales
# 120      3      Sabana-Quemada  151     Benchmark  F25-2568     Poales
# 121      3            Sample-8   65           LMF  F25-0008        NaN
# 122      3                 nan  231      Breeding  F25-2638  Asterales
#
#          family         genus        species               tax_name  \
# 0      Fabaceae  Stylosanthes        humilis   Stylosanthes humilis
# 1      Fabaceae  Stylosanthes         scabra    Stylosanthes scabra
# 2      Fabaceae  Stylosanthes         scabra    Stylosanthes scabra
# 3      Fabaceae  Stylosanthes         scabra    Stylosanthes scabra
# 4      Fabaceae  Stylosanthes         scabra    Stylosanthes scabra
# ..          ...           ...            ...                    ...
# 118     Poaceae       Cynodon    nlenfuensis    Cynodon nlemfuensis
# 119     Poaceae           NaN            NaN                    NaN
# 120     Poaceae           NaN            NaN                    NaN
# 121         NaN       Cynodon   nlemfuensis    Cynodon nlemfuensis
# 122  Compositae     Tithonia   diversifolia   Tithonia diversifolia
#
#        functional_group set_ciat  dm_percentage  ash_dm  om_percentage  \
# 0    Herbaceous_legumes       25          90.24   11.91          88.09
# 1    Herbaceous_legumes       25          92.84    7.89          92.11
# 2    Herbaceous_legumes       25          93.39   13.71          86.29
# 3    Herbaceous_legumes       25          93.02   10.56          89.44
# 4    Herbaceous_legumes       25          93.20   11.08          88.92
# ..                  ...      ...            ...     ...            ...
# 118               Grass       23          92.18    9.30          90.70
# 119               Grass       25          92.41    7.33          92.67
# 120               Grass       25          93.62   11.39          88.61
# 121                 NaN       23          93.73   11.42          88.59
# 122         Shrub_Trees       26          90.58   14.26          85.74
#
#      pc_percentage_dm  adf_percentage_dm  ndf_percentage_dm
# 0               19.44              31.37              51.77
# 1               15.96              46.21              59.51
# 2               11.83              39.59              57.50
# 3               15.74              33.59              56.99
# 4               15.72              35.04              53.94
# ..                ...                ...                ...
# 118              5.74              40.04              77.78
# 119              6.02              46.15              77.96
# 120              4.07              49.66              77.83
# 121               NaN                NaN                NaN
# 122             19.53              23.96              41.50
#
# [123 rows x 18 columns]

# %%
agg_functions_for_dashboard = {}
for col in category_columns:
    if col != 'id': # 'id' is the groupby key
        agg_functions_for_dashboard[col] = 'first' # Take the first occurrence for categorical columns
for col in numeric_columns:
    agg_functions_for_dashboard[col] = 'mean' # Calculate the mean for numeric columns

# Group by 'id' and apply the aggregation
# Using observed=False to ensure all categories are considered if 'id' was categorical itself,
# but it mainly affects the output type. For simple string/object IDs, it won't change behavior much.
subset_4_nutrition_dashboard = subset_4_nutrition_sorted_by_sql.groupby('id', observed=False).agg(agg_functions_for_dashboard).round(2).reset_index()

# Reorder columns to place 'subset' first
cols = subset_4_nutrition_dashboard.columns.tolist()
cols.remove('subset')
cols.remove('id')
new_column_order = ['subset', 'id'] + cols
subset_4_nutrition_dashboard = subset_4_nutrition_dashboard[new_column_order]

print("Dashboard with categorical columns maintained and 'subset' as the first column:")
display(subset_4_nutrition_dashboard)
# Out:
# Dashboard with categorical columns maintained and 'subset' as the first column:
#     subset                 id   no                    requisitioner    id_lab  \
# 0        4         CIAT-10026  169                          Genbank  F25-2596
# 1        4         CIAT-12411  171                          Genbank  F25-2597
# 2        4         CIAT-13258   55                          Genbank  F25-1755
# 3        4         CIAT-13260   57                          Genbank  F25-1756
# 4        4         CIAT-13262    1                          Genbank  F25-1728
# ..     ...                ...  ...                              ...       ...
# 139      4    CIAT-BH-22-3830  109                          Genbank  F25-2187
# 140      4    CIAT-BR-06-1348  NaN                         Breeding  F25-2104
# 141      4  Cayman-Br-02-1752   61                    Isabel Molina  F25-2640
# 142      4           Sample-8   65  Jacobo Arango/Alejandro Montoya  F25-0008
# 143      4                nan   63                  Mauricio Sotelo  F25-2641
#
#     tax_order    family         genus          species  \
# 0     Fabales  Fabaceae  Stylosanthes         seabrana
# 1     Fabales  Fabaceae  Stylosanthes      sympodialis
# 2     Fabales  Fabaceae  Dendrolobium      lanceolatum
# 3     Fabales  Fabaceae  Dendrolobium      lanceolatum
# 4     Fabales  Fabaceae  Dendrolobium      triangulare
# ..        ...       ...           ...              ...
# 139    Poales   Poaceae      Urochloa       humidicola
# 140    Poales   Poaceae      Urochloa  interespecifico
# 141    Poales   Poaceae      Urochloa  interespecifico
# 142    Poales   Poaceae       Cynodon     nlemfuensis
# 143   Fabales  Fabaceae  Gliricidia             sepium
#
#                        tax_name    functional_group set_ciat  dm_percentage  \
# 0         Stylosanthes seabrana  Herbaceous_legumes       28          92.75
# 1      Stylosanthes sympodialis  Herbaceous_legumes       28          91.72
# 2      Dendrolobium lanceolatum         Shrub_Trees       27          94.60
# 3      Dendrolobium lanceolatum         Shrub_Trees       27          94.08
# 4      Dendrolobium triangulare         Shrub_Trees       27          94.93
# ..                          ...                 ...      ...            ...
# 139         Urochloa humidicola               Grass       28          95.96
# 140  Brachiaria interespecifico               Grass       30          93.09
# 141    Urochloa interespecifico               Grass       27          97.00
# 142        Cynodon nlemfuensis                Grass       27          93.58
# 143          Gliricidia sepium          Shrub_Trees       27          93.50
#
#      ash_dm  om_percentage  pc_percentage_dm  adf_percentage_dm  \
# 0      9.97          90.03             16.29              34.49
# 1     11.78          88.22             17.94              34.30
# 2     14.87          85.13             15.55              54.96
# 3     12.08          87.92             15.81              57.39
# 4      8.70          91.30             18.98              47.52
# ..      ...            ...               ...                ...
# 139   10.19          89.81              8.04              32.62
# 140   14.48          85.52             12.22              25.64
# 141    9.65          90.35              8.05              26.24
# 142   11.40          88.60              2.62               7.56
# 143    9.41          90.59             22.38              21.94
#
#      ndf_percentage_dm
# 0                57.25
# 1                61.11
# 2                61.80
# 3                65.19
# 4                60.40
# ..                 ...
# 139              67.43
# 140              59.76
# 141              62.13
# 142              76.10
# 143              47.20
#
# [144 rows x 18 columns]

# %%
subsets_1_2_3_4_nutrition_dashboard_complete = pd.concat([
    subset_1_nutrition_dashboard,
    subset_2_nutrition_dashboard,
    subset_3_nutrition_dashboard,
    subset_4_nutrition_dashboard
], ignore_index=True)

subsets_1_2_3_4_nutrition_dashboard_complete
# Out:
#      subset                 id   no                    requisitioner  \
# 0         1          ABC-10647  197                     Genetic bank
# 1         1          ABC-11194  199                     Genetic bank
# 2         1          ABC-11999  201                     Genetic bank
# 3         1          ABC-12318  203                     Genetic bank
# 4         1           ABC-1257  113                     Genetic bank
# ..      ...                ...  ...                              ...
# 687       4    CIAT-BH-22-3830  109                          Genbank
# 688       4    CIAT-BR-06-1348  NaN                         Breeding
# 689       4  Cayman-Br-02-1752   61                    Isabel Molina
# 690       4           Sample-8   65  Jacobo Arango/Alejandro Montoya
# 691       4                nan   63                  Mauricio Sotelo
#
#        id_lab tax_order    family         genus          species  \
# 0    F24-3469   Fabales  Fabaceae  Stylosanthes           scabra
# 1    F24-3470   Fabales  Fabaceae  Stylosanthes           hamata
# 2    F24-3471   Fabales  Fabaceae  Stylosanthes       guianensis
# 3    F24-3472   Fabales  Fabaceae  Stylosanthes           hamata
# 4    F24-3427   Fabales  Fabaceae  Stylosanthes           scabra
# ..        ...       ...       ...           ...              ...
# 687  F25-2187    Poales   Poaceae      Urochloa       humidicola
# 688  F25-2104    Poales   Poaceae      Urochloa  interespecifico
# 689  F25-2640    Poales   Poaceae      Urochloa  interespecifico
# 690  F25-0008    Poales   Poaceae       Cynodon     nlemfuensis
# 691  F25-2641   Fabales  Fabaceae  Gliricidia             sepium
#
#                        tax_name    functional_group set_ciat  dm_percentage  \
# 0           Stylosanthes scabra  Herbaceous_legumes        6          92.93
# 1           Stylosanthes hamata  Herbaceous_legumes        6          92.89
# 2       Stylosanthes guianensis  Herbaceous_legumes        7          93.50
# 3           Stylosanthes hamata  Herbaceous_legumes        7          94.10
# 4           Stylosanthes scabra  Herbaceous_legumes        5          92.72
# ..                          ...                 ...      ...            ...
# 687         Urochloa humidicola               Grass       28          95.96
# 688  Brachiaria interespecifico               Grass       30          93.09
# 689    Urochloa interespecifico               Grass       27          97.00
# 690        Cynodon nlemfuensis                Grass       27          93.58
# 691          Gliricidia sepium          Shrub_Trees       27          93.50
#
#      ash_dm  om_percentage  pc_percentage_dm  adf_percentage_dm  \
# 0      9.36          90.64             20.02              32.44
# 1      9.61          90.39             21.18              30.18
# 2     10.46          89.54             20.09              33.90
# 3     11.08          88.92             22.05              29.34
# 4      9.52          90.48             17.96              35.90
# ..      ...            ...               ...                ...
# 687   10.19          89.81              8.04              32.62
# 688   14.48          85.52             12.22              25.64
# 689    9.65          90.35              8.05              26.24
# 690   11.40          88.60              2.62               7.56
# 691    9.41          90.59             22.38              21.94
#
#      ndf_percentage_dm
# 0                56.19
# 1                55.94
# 2                61.32
# 3                55.26
# 4                69.91
# ..                 ...
# 687              67.43
# 688              59.76
# 689              62.13
# 690              76.10
# 691              47.20
#
# [692 rows x 18 columns]

# %%
#subsets_1_2_3_4_nutrition_dashboard_complete.to_csv('/content/drive/MyDrive/lmf/output/04_15_2026_sql_data_frame_creation/subsets_1_2_3_4_nutrition_dashboard_complete.csv', index = False)
