# %% [markdown]
# # 1.0 Connect with drive

# %%
pkgs = c("googledrive", "httpuv", "R.utils", "httr")
install.packages(pkgs)
library(googledrive)
drive_auth(use_oob=TRUE, cache=FALSE)
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Please point your browser to the following url:
#
# https://accounts.google.com/o/oauth2/v2/auth?client_id=603366585132-frjlouoa3s2ono25d2l9ukvhlsrlnr7k.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email&redirect_uri=https%3A%2F%2Fwww.tidyverse.org%2Fgoogle-callback%2F&response_type=code&state=e821f9cadc9c61cff793bd58db334adf&access_type=offline&prompt=consent
# Enter authorization code: eyJjb2RlIjoiNC8wQVhFUXhJQjZ2OFhTQkg3bEdZcG51ZHNYbHdwYmVIdUpfWGxqMXVfQWc0X0tadkZFdkFjUGN6MjkzY1QzVmpnckU3VllRZyIsInN0YXRlIjoiZTgyMWY5Y2FkYzljNjFjZmY3OTNiZDU4ZGIzMzRhZGYifQ==

# %%
install.packages("shiny")   # Solo si no está instalado
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(googledrive)
library(shiny)

# %%
file_id <- "1pw69PhBQtAhfj_poYBryeCIY_3vl9gv3"

# Buscar el archivo
f <- drive_get(as_id(file_id))

# Descargarlo
drive_download(
  file = f,
  path = "app.R",
  overwrite = TRUE
)
# Out:
# File downloaded:
#
# • lmf_selection_index_dashboard.R <id: 1pw69PhBQtAhfj_poYBryeCIY_3vl9gv3>
#
# Saved locally as:
#
# • app.R

# %%
list.files()
# Out:
# [1] "app.R"       "sample_data"

# %%
runApp("app.R")
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘rbibutils’, ‘crosstalk’, ‘colourpicker’, ‘lazyeval’, ‘Rdpack’, ‘minqa’, ‘nloptr’, ‘reformulas’, ‘RcppEigen’, ‘estimability’, ‘mvtnorm’, ‘numDeriv’
#
#
#
# Attaching package: ‘shinyjs’
#
#
# The following object is masked from ‘package:shiny’:
#
#     runExample
#
#
# The following objects are masked from ‘package:methods’:
#
#     removeClass, show
#
#
#
# Attaching package: ‘bslib’
#
#
# The following object is masked from ‘package:utils’:
#
#     page
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘openxlsx2’
#
#
# The following object is masked from ‘package:readxl’:
#
#     read_xlsx
#
#
#
# Attaching package: ‘DT’
#
#
# ...
