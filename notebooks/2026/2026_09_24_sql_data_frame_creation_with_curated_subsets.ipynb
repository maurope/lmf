# %% [markdown]
# #I. Notebook Description: Data Processing and Dashboard Creation for Feedstuff Analysis
#
# This notebook details the comprehensive process of loading, cleaning, and preparing feedstuff analysis data from four distinct subsets, followed by the compilation of aggregated dashboards for both gas production and nutritional values. Initially, data from CSV files for information samples, gas production, and nutrition are loaded into pandas DataFrames. A series of cleaning functions are then applied to standardize data, including removing header duplicates, normalizing ID suffixes (e.g., `-1`), enforcing consistent lab ID formats (e.g., FXX-XXXX), and mapping functional groups to a unified taxonomy (e.g., 'Grass', 'Shrub_Trees', 'Herbaceous_legumes'). SQL queries are used to join the cleaned information samples with gas production and nutrition data, generating sorted and consolidated DataFrames (e.g., `subset_X_gas_sorted_by_sql`, `subset_X_nutrition_sorted_by_sql`). These subset-specific DataFrames are subsequently concatenated into master DataFrames (e.g., `subsets_1_2_3_4_gas_sorted_by_sql`, `subsets_1_2_3_4_nutrition_sorted_by_sql`). Finally, dashboard-ready DataFrames are created by converting relevant columns to appropriate types and aggregating numerical features by `id` (calculating mean values) and retaining the first occurrence for categorical features, resulting in summarized datasets such as `subsets_1_2_3_4_gas_dashboard_complete` and `subsets_1_2_3_4_nutrition_dashboard_complete`.

# %% [markdown]
# # II. Libraries

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import sqlite3

# %% [markdown]
# # III. Cleaning functions

# %%
# Function to remove the first row (duplicated original column names)
def remove_first_row(df):
    return df.iloc[1:, :].copy()

# Usage:
# subset_1_information_samples = remove_first_row(subset_1_information_samples)

# %%
# Function to clean and standardize lab/sample IDs to FXX-XXXX format
def clean_lab_ids(series):
    return (
        series
        .astype(str)
        .str.replace(r'\s+', '-', regex=True)                 # Replace spaces with -
        .str.replace(r'^(F\d{2})(\d+)', r'\1-\2', regex=True) # Format FXX-XXXX
    )


# Usage:
# subset_1_information_samples['10_ciat_lab_id'] = clean_lab_ids(subset_1_information_samples['10_ciat_lab_id'])

# %%
# Function to clean and standardize Gene Bank - Breeding program IDs
def clean_standardize_ids(series):
    return (
        series
        .astype(str)
        .str.replace(r'-1$', '', regex=True)                   # Remove trailing -1
        .str.strip()                                           # Remove leading/trailing spaces
        .str.replace(r'[_\s]+', '-', regex=True)               # Replace spaces/underscores with -
        .str.replace(r'([A-Za-z])(\d)', r'\1-\2', regex=True)  # Letter followed by number
        .str.replace(r'(\d)([A-Za-z])', r'\1-\2', regex=True)  # Number followed by letter
        .str.replace(r'-+', '-', regex=True)                   # Remove repeated -
        .str.replace(r'^-|-$', '', regex=True)                 # Remove leading/trailing -
        .str.replace('ABC-', 'CIAT-', regex=False)             # Replace id's strings 'ABC' with 'CIAT'
    )

    # subset_1_information_samples['10_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_1_information_samples['10_gene_bank_breeding_program_id'])

# %%
# Define the mapping for functional groups
functional_group_mapping = {
    'Grasses': 'Grass',
    'grasses': 'Grass',
    'Shrub': 'Shrub_Trees',
    'Shrub/tree': 'Shrub_Trees',
    'Shurb_tree': 'Shrub_Trees',
    'Shrub/Tree': 'Shrub_Trees',
    'Shrub/Trees': 'Shrub_Trees',
    'Shrub_Trees': 'Shrub_Trees',
    'Shurb_Tree': 'Shrub_Trees',
    'Tree': 'Shrub_Trees',
    'Arbustiva ': 'Shrub_Trees',
    'Arbustivas': 'Shrub_Trees',
    'Herbáceas': 'Herbaceous_legumes',
    'Herbáceas ': 'Herbaceous_legumes',
    'Herbaceous': 'Herbaceous_legumes',
    'Trepadoras': 'Herbaceous_legumes',
    'Herbaceous legume': 'Herbaceous_legumes',
    'Herbaceous_climber': 'Herbaceous_legumes',
    'Climber': 'Herbaceous_legumes',
    'Legume': 'Herbaceous_legumes'
}

## Usage:
#subset_6_information_samples['10_functional_group'] = subset_6_information_samples['10_functional_group'].replace(functional_group_mapping)

#print('Updated functional group counts for subset_6_information_samples:')
#display(subset_6_information_samples['10_functional_group'].value_counts())

# %% [markdown]
# # 1. Subset 1

# %% [markdown]
# ## 1.1. Loading data

# %%
# Load the CSVs from Drive into pandas DataFrames
subset_1_information_samples = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_1/csv/10_information_samples.csv')
subset_1_gas_prod = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_1/csv/40g_result_gp_data_vf.csv')
subset_1_gas_ori = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_1/csv/31_gas_prod.csv')
subset_1_nutrition = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_1/csv/40n_result_nutrition_raw_data_vf.csv')
subset_1_digest = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_1/csv/32_digest.csv')

# %%
subset_1_gas_prod.to_csv('subset_1_gas_prod.csv')

# %% [markdown]
# ## 1.2. Cleaning and formatting dataframes

# %%
# Clean first row containing orignal column names from excel files
subset_1_information_samples = remove_first_row(subset_1_information_samples)
subset_1_gas_prod = remove_first_row(subset_1_gas_prod)
subset_1_gas_ori = remove_first_row(subset_1_gas_ori)
subset_1_nutrition = remove_first_row(subset_1_nutrition)
subset_1_digest = remove_first_row(subset_1_digest)

# Add '-' to lab ids and ensure correct format FXX-XXXX
subset_1_information_samples['10_ciat_lab_id'] = clean_lab_ids(subset_1_information_samples['10_ciat_lab_id'])
subset_1_gas_prod['40g_ciat_id'] = clean_lab_ids(subset_1_gas_prod['40g_ciat_id'])
subset_1_gas_ori['31_ciat_id'] = clean_lab_ids(subset_1_gas_ori['31_ciat_id'])
subset_1_nutrition['40n_sample_id'] = clean_lab_ids(subset_1_nutrition['40n_sample_id'])
subset_1_digest['32_ciat_id'] = clean_lab_ids(subset_1_digest['32_ciat_id'])


# Clean and standardize gene bank and breeding program ids
subset_1_information_samples['10_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_1_information_samples['10_gene_bank_breeding_program_id'])
subset_1_gas_prod['40g_gene_bank_id'] = clean_standardize_ids(subset_1_gas_prod['40g_gene_bank_id'])
subset_1_gas_ori['31_gene_bank_id'] = clean_standardize_ids(subset_1_gas_ori['31_gene_bank_id'])
subset_1_nutrition['40n_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_1_nutrition['40n_gene_bank_breeding_program_id'])
subset_1_digest['32_gene_bank_id'] = clean_standardize_ids(subset_1_digest['32_gene_bank_id'])

# %%
# Check functional groups categories
subset_1_information_samples['10_functional_group'].unique()
# Out:
# array(['Herbaceous', 'Climber', 'Shrub', 'Tree', 'Grass', 'FAO', 'Legume',
#        'Browse', 'Forage', 'Concentrate', 'Grasses', nan], dtype=object)

# %%
# Apply the mapping to centers datt
subset_1_information_samples['10_functional_group'] = subset_1_information_samples['10_functional_group'].replace(functional_group_mapping)

print('Updated functional group counts for subset_1_information_samples:')
display(subset_1_information_samples['10_functional_group'].value_counts())
# Out:
# Updated functional group counts for subset_1_information_samples:
# 10_functional_group
# Herbaceous_legumes    145
# Grass                  72
# Shrub_Trees            31
# Concentrate             7
# Forage                  6
# Browse                  4
# FAO                     1
# Name: count, dtype: int64

# %% [markdown]
# ## 1.3. SQL query and dataframe creation

# %% [markdown]
# ### 1.3.1. Gas

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_1_information_samples.to_sql('subset_1_information_samples', conn_new, if_exists='replace', index=False)
subset_1_gas_prod.to_sql('subset_1_gas_prod', conn_new, if_exists='replace', index=False)
subset_1_gas_ori.to_sql('subset_1_gas_ori', conn_new, if_exists='replace', index=False)
subset_1_digest.to_sql('subset_1_digest', conn_new, if_exists='replace', index=False)
print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_1_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date  ', '10_requisitioner', '10_set_ciat',
#        '10_ciat_lab_id', '10_gene_bank_breeding_program_id', '10_genus',
#        '10_species', '10_tax_name', '10_family', '10_order',
#        '10_functional_group', '10_remarks_1', '10_remarks_2'],
#       dtype='object')

# %%
subset_1_digest.columns
# Out:
# Index(['32_no', '32_date', '32_gene_bank_id', '32_name', '32_ciat_id',
#        '32_set_ciat', '32_batch', '32_run', '32_replication', '32_syrange_no',
#        '32_bag_weight_g', '32_digested_weight_g', '32_remarks_1',
#        '32_undigested_dm_g', '32_digested_feed_mg',
#        '32_percentage_dmd_truly_digestibility', '32_ndf_incubated_mg',
#        '32_ndf_digestibility_mg', '32_percentage_ndf_digestibility_in_24h',
#        '32_remarks_2', 'Unnamed: 20', 'Unnamed: 21'],
#       dtype='object')

# %%
subset_1_gas_prod.columns
# Out:
# Index(['40g_no', '40g_requisitioner', '40g_gene_bank_id', '40g_genus',
#        '40g_species', '40g_tax_name', '40g_family', '40g_order',
#        '40g_functional_group', '40g_ciat_id', '40g_set_ciat', '40g_batch',
#        '40g_run', '40g_replication', '40g_ch4_8h_percentage',
#        '40g_ch4_24h_percentage', '40g_net_gas_8h_ml', '40g_net_gas_24h_ml',
#        '40g_gas_ml_g_dm_incubated_24h',
#        '40g_percentage_dmd_truly_digestibility', '40g_part_fact',
#        '40g_ch4_percentage_in_gas_8h', '40g_ch4_percentage_in_gas_24h',
#        '40g_ch4_ml_g_dm_incubated_24h', '40g_ch4_ml_g_dmd_24h',
#        '40g_ch4_ml_g_ndf_digested_in_24h', '40g_ch4_g_g_dm_incubated_24h',
#        '40g_ch4_g_g_dmd_24h', '40g_remarks_1', '40g_remarks_2'],
#       dtype='object')

# %%
subset_1_gas_ori.columns
# Out:
# Index(['31_no', '31_date', '31_requisitioner', '31_gene_bank_id', '31_genus',
#        '31_species', '31_tax_name', '31_family', '31_order',
#        '31_functional_group', '31_ciat_id', '31_set_ciat', '31_batch',
#        '31_run', '31_replication', '31_syrange_no', '31_sample_weight_g',
#        '31_dm_incubated_mg', '31_digested_feed_mg', '31_time_0h',
#        '31_gas_0h_ml', '31_time_8h', '31_gas_8h_ml', '31_ch4_8h_percentage',
#        '31_v8_push_back_ml', '31_time_24h', '31_gas_24h_ml',
#        '31_ch4_24h_percentage', '31_remarks_1', '31_gp_8h_ml', '31_gp_8_24_ml',
#        '31_net_gas_8h_ml', '31_net_gas_8_24h_ml2', '31_net_gas_24h_ml',
#        '31_ch4_8h_ml', '31_ch4_8_24h_ml', '31_ch4_24h_ml',
#        '31_gas_ml_g_dm_incubated_24h', '31_percentage_dmd_truly_digestibility',
#        '31_part_fact', '31_ch4_ml_in_gas_8h', '31_ch4_ml_in_gas_24h',
#        '31_ch4_ml_g_dm_incubated_24h', '31_ch4_ml_g_dmd_24h',
#        '31_ch4_ml_g_ndf_digested_in_24h', '31_ch4_g_g_dm_incubated_24h',
#        '31_ch4_g_g_dmd_24h'],
#       dtype='object')

# %%
query_combined = """
SELECT
    s1gc."40g_no" as no,
    s1i."10_requisitioner" as requisitioner,
    s1i."10_ciat_lab_id" as id_lab,
    s1i."10_gene_bank_breeding_program_id" as id,
    s1i."10_order" as tax_order,
    s1i."10_family" as family,
    s1i."10_genus" as genus,
    s1i."10_species" as species,
    s1i."10_tax_name" as tax_name,
    s1i."10_functional_group" as functional_group,

    s1gc."40g_set_ciat" as set_ciat,
    s1gc."40g_batch" as batch,
    s1gc."40g_run" as run,
    s1gc."40g_replication" as replication,
    s1gc."40g_replication" as syrange,

    s1go."31_sample_weight_g" as sample_weight_g,
    s1d."32_undigested_dm_g" as undigested_dm_g,
    s1go."31_dm_incubated_mg" as dm_incubated,
    s1go."31_digested_feed_mg" as digested_feed_mg,

    s1gc."40g_net_gas_8h_ml" as net_gas_8h_ml,
    s1gc."40g_net_gas_24h_ml" as net_gas_24h_ml,
    s1go."31_ch4_8h_ml" as ch4_8h_ml,
    s1go."31_ch4_24h_ml" as ch4_24h_ml,
    s1gc."40g_ch4_percentage_in_gas_8h" as ch4_percentage_in_gas_8h,
    s1gc."40g_ch4_percentage_in_gas_24h" as ch4_percentage_in_gas_24h,

    s1gc."40g_gas_ml_g_dm_incubated_24h" as gas_ml_g_dm_incubated_24h,
    s1gc."40g_part_fact" as part_fact,

    s1gc."40g_ch4_ml_g_dm_incubated_24h" as ch4_ml_g_dm_incubated_24h,
    s1gc."40g_ch4_ml_g_ndf_digested_in_24h" as ch4_ml_g_ndf_digested_24h,
    s1gc."40g_ch4_ml_g_dmd_24h" as methane_intensity,
    s1gc."40g_percentage_dmd_truly_digestibility" as tddm,

    s1i."10_remarks_1" as information_remarks_1,
    s1i."10_remarks_2" as information_remarks_2,
    s1gc."40g_remarks_1" as gas_remarks_1,
    s1gc."40g_remarks_2" as gas_remarks_2,
    s1d."32_remarks_1" as digest_remarks_1,
    s1d."32_remarks_2" as digest_remarks_2

FROM
    subset_1_information_samples AS s1i
JOIN
    subset_1_gas_ori AS s1go
ON s1i."10_ciat_lab_id" = s1go."31_ciat_id"

JOIN subset_1_gas_prod AS s1gc
ON s1go."31_gene_bank_id" = s1gc."40g_gene_bank_id"
AND s1go."31_batch" = s1gc."40g_batch"
AND s1go."31_replication" = s1gc."40g_replication"

LEFT JOIN subset_1_digest AS s1d
ON s1go."31_ciat_id" = s1d."32_ciat_id"
AND s1go."31_batch" = s1d."32_batch"
AND s1go."31_replication" = s1d."32_replication"


ORDER BY
    CAST(no AS INTEGER) ASC

"""

subset_1_gas_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_1_gas_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#          no requisitioner    id_lab                       id    tax_order  \
# 0     #REF!           LMF  F25-0017  Hohenheimer-Heustandard       Forage
# 1     #REF!           LMF  F25-0017  Hohenheimer-Heustandard       Forage
# 2     #REF!           LMF  F25-0017  Hohenheimer-Heustandard       Forage
# 3     #REF!           LMF  F25-0018    Homenheim-Concentrate  Concentrate
# 4     #REF!           LMF  F25-0018    Homenheim-Concentrate  Concentrate
# ...     ...           ...       ...                      ...          ...
# 2179   1629           LMF  F25-0019                 Sample-8       Poales
# 2180   1629           LMF  F25-0019                 Sample-8       Poales
# 2181   1629           LMF  F25-0019                 Sample-8       Poales
# 2182   1629           LMF  F25-0019                 Sample-8       Poales
# 2183   1629           LMF  F25-0019                 Sample-8       Poales
#
#            family        genus        species                 tax_name  \
# 0          Forage  Hohenheimer    Heustandard  Hohenheimer Heustandard
# 1          Forage  Hohenheimer    Heustandard  Hohenheimer Heustandard
# 2          Forage  Hohenheimer    Heustandard  Hohenheimer Heustandard
# 3     Concentrate    Homenheim    Concentrate    Homenheim Concentrate
# 4     Concentrate    Homenheim    Concentrate    Homenheim Concentrate
# ...           ...          ...            ...                      ...
# 2179      Poaceae      Cynodon   nlemfuensis      Cynodon nlemfuensis
# 2180      Poaceae      Cynodon   nlemfuensis      Cynodon nlemfuensis
# 2181      Poaceae      Cynodon   nlemfuensis      Cynodon nlemfuensis
# 2182      Poaceae      Cynodon   nlemfuensis      Cynodon nlemfuensis
# 2183      Poaceae      Cynodon   nlemfuensis      Cynodon nlemfuensis
#
#      functional_group  ... ch4_ml_g_dm_incubated_24h  \
# 0              Forage  ...               33.24064574
# 1              Forage  ...               32.48546917
# 2              Forage  ...               33.70505251
# 3         Concentrate  ...                 44.140303
# 4         Concentrate  ...               42.17957456
# ...               ...  ...                       ...
# 2179            Grass  ...               16.20936672
# 2180            Grass  ...               16.20936672
# 2181            Grass  ...               16.20936672
# 2182            Grass  ...               16.20936672
# 2183            Grass  ...               16.20936672
#
#      ch4_ml_g_ndf_digested_24h methane_intensity         tddm  \
# 0                            0       95.43754089  34.82973831
# 1                            0       89.75200777  36.19469912
# 2                            0       59.21398025  56.92076832
# 3                            0       70.13200392  62.93888743
# 4                            0       70.45327289  59.86886462
# ...                        ...               ...          ...
# 2179                         0       49.48351384  32.75710527
# 2180                         0       49.48351384  32.75710527
# 2181                         0       49.48351384  32.75710527
# 2182                         0       49.48351384  32.75710527
# 2183                         0       49.48351384  32.75710527
#
#      information_remarks_1 information_remarks_2 gas_remarks_1 gas_remarks_2  \
# 0                  Standar                  None          None          None
# 1                  Standar                  None          None          None
# 2                  Standar                  None          None          None
# 3                  Standar                  None          None          None
# 4                  Standar                  None          None          None
# ...                    ...                   ...           ...           ...
# 2179               Standar                  None          None          None
# 2180               Standar                  None          None          None
# 2181               Standar                  None          None          None
# 2182               Standar                  None          None          None
# 2183               Standar                OT-002          None          None
#
#      digest_remarks_1 digest_remarks_2
# 0                None             None
# 1                None             None
# 2                None             None
# 3                None             None
# 4                None             None
# ...               ...              ...
# 2179             None             None
# 2180             None             None
# 2181             None             None
# 2182             None             None
# 2183             None             None
#
# [2184 rows x 37 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_1_gas_sorted_by_sql = subset_1_gas_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_1_gas_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_1_gas_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (1938, 37)
# First 5 rows of DataFrame without duplicates (keeping first):
#       no requisitioner    id_lab                       id    tax_order  \
# 0  #REF!           LMF  F25-0017  Hohenheimer-Heustandard       Forage
# 1  #REF!           LMF  F25-0017  Hohenheimer-Heustandard       Forage
# 2  #REF!           LMF  F25-0017  Hohenheimer-Heustandard       Forage
# 3  #REF!           LMF  F25-0018    Homenheim-Concentrate  Concentrate
# 4  #REF!           LMF  F25-0018    Homenheim-Concentrate  Concentrate
#
#         family        genus       species                 tax_name  \
# 0       Forage  Hohenheimer   Heustandard  Hohenheimer Heustandard
# 1       Forage  Hohenheimer   Heustandard  Hohenheimer Heustandard
# 2       Forage  Hohenheimer   Heustandard  Hohenheimer Heustandard
# 3  Concentrate    Homenheim   Concentrate    Homenheim Concentrate
# 4  Concentrate    Homenheim   Concentrate    Homenheim Concentrate
#
#   functional_group  ... ch4_ml_g_dm_incubated_24h ch4_ml_g_ndf_digested_24h  \
# 0           Forage  ...               33.24064574                         0
# 1           Forage  ...               32.48546917                         0
# 2           Forage  ...               33.70505251                         0
# 3      Concentrate  ...                 44.140303                         0
# 4      Concentrate  ...               42.17957456                         0
#
#   methane_intensity         tddm information_remarks_1 information_remarks_2  \
# 0       95.43754089  34.82973831               Standar                  None
# 1       89.75200777  36.19469912               Standar                  None
# 2       59.21398025  56.92076832               Standar                  None
# 3       70.13200392  62.93888743               Standar                  None
# 4       70.45327289  59.86886462               Standar                  None
#
#   gas_remarks_1 gas_remarks_2 digest_remarks_1 digest_remarks_2
# 0          None          None             None             None
# 1          None          None             None             None
# 2          None          None             None             None
# 3          None          None             None             None
# 4          None          None             None             None
#
# [5 rows x 37 columns]

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 1
subset_1_gas_sorted_by_sql.insert(0, 'subset', 1)

print("DataFrame with new 'subset' column:")
display(subset_1_gas_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset     no requisitioner    id_lab                       id  \
# 0       1  #REF!           LMF  F25-0017  Hohenheimer-Heustandard
# 1       1  #REF!           LMF  F25-0017  Hohenheimer-Heustandard
# 2       1  #REF!           LMF  F25-0017  Hohenheimer-Heustandard
# 3       1  #REF!           LMF  F25-0018    Homenheim-Concentrate
# 4       1  #REF!           LMF  F25-0018    Homenheim-Concentrate
#
#      tax_order       family        genus       species  \
# 0       Forage       Forage  Hohenheimer   Heustandard
# 1       Forage       Forage  Hohenheimer   Heustandard
# 2       Forage       Forage  Hohenheimer   Heustandard
# 3  Concentrate  Concentrate    Homenheim   Concentrate
# 4  Concentrate  Concentrate    Homenheim   Concentrate
#
#                   tax_name  ... ch4_ml_g_dm_incubated_24h  \
# 0  Hohenheimer Heustandard  ...               33.24064574
# 1  Hohenheimer Heustandard  ...               32.48546917
# 2  Hohenheimer Heustandard  ...               33.70505251
# 3    Homenheim Concentrate  ...                 44.140303
# 4    Homenheim Concentrate  ...               42.17957456
#
#   ch4_ml_g_ndf_digested_24h methane_intensity         tddm  \
# 0                         0       95.43754089  34.82973831
# 1                         0       89.75200777  36.19469912
# 2                         0       59.21398025  56.92076832
# 3                         0       70.13200392  62.93888743
# 4                         0       70.45327289  59.86886462
#
#   information_remarks_1 information_remarks_2 gas_remarks_1 gas_remarks_2  \
# 0               Standar                  None          None          None
# 1               Standar                  None          None          None
# 2               Standar                  None          None          None
# 3               Standar                  None          None          None
# 4               Standar                  None          None          None
#
#   digest_remarks_1 digest_remarks_2
# 0             None             None
# 1             None             None
# 2             None             None
# 3             None             None
# 4             None             None
#
# [5 rows x 38 columns]

# %%
subset_1_gas_sorted_by_sql.to_csv('gas1.csv', index=None)

# %% [markdown]
# ### 1.3.2. Nutrition

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_1_information_samples.to_sql('subset_1_information_samples', conn_new, if_exists='replace', index=False)
subset_1_nutrition.to_sql('subset_1_nutrition', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_1_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date  ', '10_requisitioner', '10_set_ciat',
#        '10_ciat_lab_id', '10_gene_bank_breeding_program_id', '10_genus',
#        '10_species', '10_tax_name', '10_family', '10_order',
#        '10_functional_group', '10_remarks_1', '10_remarks_2'],
#       dtype='object')

# %%
subset_1_nutrition.columns
# Out:
# Index(['40n_no', '40n_date', '40n_requisitioner', '40n_set_ciat',
#        '40n_sample_id', '40n_gene_bank_breeding_program_id', '40n_genus',
#        '40n_species', '40n_tax_name', '40n_dm_percentage', '40n_av_dm_105',
#        '40n_ash_dm', '40n_av_ash_percentage', '40n_om_percentage',
#        '40n_om_percentage.1', '40n_pc_percentage_dm', '40n_av_pc_percentage',
#        '40n_adf_percentage_dm', '40n_av_adf_percentage_dm',
#        '40n_ndf_percentage_dm', '40n_av_ndf_percentage_dm'],
#       dtype='object')

# %%
query_combined = """
SELECT
    s1n."40n_no" as no,
    s1i."10_requisitioner" as requisitioner,
    s1i."10_ciat_lab_id" as id_lab,
    s1i."10_gene_bank_breeding_program_id" as id,
    s1i."10_order" as tax_order,
    s1i."10_family" as family,
    s1i."10_genus" as genus,
    s1i."10_species" as species,
    s1i."10_tax_name" as tax_name,
    s1i."10_functional_group" as functional_group,
    s1n."40n_set_ciat" as set_ciat,
    s1n."40n_dm_percentage" as dm_percentage,
    s1n."40n_ash_dm" as ash_dm,
    s1n."40n_om_percentage" as om_percentage,
    s1n."40n_pc_percentage_dm" as pc_percentage_dm,
    s1n."40n_adf_percentage_dm" as adf_percentage_dm,
    s1n."40n_ndf_percentage_dm" as ndf_percentage_dm



FROM
    subset_1_information_samples AS s1i
JOIN
    subset_1_nutrition AS s1n
ON
    s1i."10_ciat_lab_id" = s1n."40n_sample_id"
ORDER BY
    CAST(no AS INTEGER) ASC
"""

subset_1_nutrition_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_1_nutrition_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#       no requisitioner    id_lab          id tax_order    family  \
# 0      1  Genetic bank  F24-3416    CIAT-705   Fabales  Fabaceae
# 1      2  Genetic bank  F24-3416    CIAT-705   Fabales  Fabaceae
# 2      3  Genetic bank  F24-3417    CIAT-707   Fabales  Fabaceae
# 3      4  Genetic bank  F24-3417    CIAT-707   Fabales  Fabaceae
# 4      5  Genetic bank  F24-3418    CIAT-712   Fabales  Fabaceae
# ..   ...           ...       ...         ...       ...       ...
# 465  376  Genetic bank  F24-3533  CIAT-32246   Fabales  Fabaceae
# 466  377  Genetic bank  F24-3534  CIAT-32365   Fabales  Fabaceae
# 467  378  Genetic bank  F24-3534  CIAT-32365   Fabales  Fabaceae
# 468  379  Genetic bank  F24-3535  CIAT-32373   Fabales  Fabaceae
# 469  380  Genetic bank  F24-3535  CIAT-32373   Fabales  Fabaceae
#
#             genus       species                 tax_name    functional_group  \
# 0      Indigofera  suffruticosa  Indigofera suffruticosa  Herbaceous_legumes
# 1      Indigofera  suffruticosa  Indigofera suffruticosa  Herbaceous_legumes
# 2     Alysicarpus   ovalifolius  Alysicarpus ovalifolius  Herbaceous_legumes
# 3     Alysicarpus   ovalifolius  Alysicarpus ovalifolius  Herbaceous_legumes
# 4        Clitoria      ternatea        Clitoria ternatea  Herbaceous_legumes
# ..            ...           ...                      ...                 ...
# 465  Chamaecrista     nictitans   Chamaecrista nictitans  Herbaceous_legumes
# 466    Desmanthus      virgatus      Desmanthus virgatus         Shrub_Trees
# 467    Desmanthus      virgatus      Desmanthus virgatus         Shrub_Trees
# 468    Desmanthus     pubescens     Desmanthus pubescens         Shrub_Trees
# 469    Desmanthus     pubescens     Desmanthus pubescens         Shrub_Trees
#
#     set_ciat dm_percentage       ash_dm om_percentage pc_percentage_dm  \
# 0          1   91.93080692  12.72569067   87.27430933      33.01052157
# 1          1         92.01  12.62906206   87.37093794      33.01052157
# 2          1   90.64280716  11.91132679   88.08867321      25.39749175
# 3          1   89.54209158  12.23760607   87.76239393      25.39749175
# 4          1   91.25174965   7.71337789   92.28662211      31.19171324
# ..       ...           ...          ...           ...              ...
# 465       10         91.56         8.03         91.97            26.83
# 466       10         90.87         7.56         92.44            30.19
# 467       10         90.98         7.45         92.55            30.19
# 468       10          92.3         8.61         91.39             28.4
# 469       10         92.37         8.71         91.29             28.4
#
#     adf_percentage_dm ndf_percentage_dm
# 0         28.48961421       45.21032889
# 1         27.61265655       45.23511907
# 2         26.19631971       54.55645373
# 3         24.68485778       53.66007735
# 4         26.67696802       55.20337963
# ..                ...               ...
# 465       26.85895517       81.72281094
# 466       28.08362098       77.86276485
# 467       29.38322659       73.65060102
# 468       20.16866025       76.26718922
# 469       19.81890361       79.50433545
#
# [470 rows x 17 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_1_nutrition_sorted_by_sql = subset_1_nutrition_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_1_nutrition_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_1_nutrition_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (388, 17)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab        id tax_order    family        genus  \
# 0  1  Genetic bank  F24-3416  CIAT-705   Fabales  Fabaceae   Indigofera
# 1  2  Genetic bank  F24-3416  CIAT-705   Fabales  Fabaceae   Indigofera
# 2  3  Genetic bank  F24-3417  CIAT-707   Fabales  Fabaceae  Alysicarpus
# 3  4  Genetic bank  F24-3417  CIAT-707   Fabales  Fabaceae  Alysicarpus
# 4  5  Genetic bank  F24-3418  CIAT-712   Fabales  Fabaceae     Clitoria
#
#         species                 tax_name    functional_group set_ciat  \
# 0  suffruticosa  Indigofera suffruticosa  Herbaceous_legumes        1
# 1  suffruticosa  Indigofera suffruticosa  Herbaceous_legumes        1
# 2   ovalifolius  Alysicarpus ovalifolius  Herbaceous_legumes        1
# 3   ovalifolius  Alysicarpus ovalifolius  Herbaceous_legumes        1
# 4      ternatea        Clitoria ternatea  Herbaceous_legumes        1
#
#   dm_percentage       ash_dm om_percentage pc_percentage_dm adf_percentage_dm  \
# 0   91.93080692  12.72569067   87.27430933      33.01052157       28.48961421
# 1         92.01  12.62906206   87.37093794      33.01052157       27.61265655
# 2   90.64280716  11.91132679   88.08867321      25.39749175       26.19631971
# 3   89.54209158  12.23760607   87.76239393      25.39749175       24.68485778
# 4   91.25174965   7.71337789   92.28662211      31.19171324       26.67696802
#
#   ndf_percentage_dm
# 0       45.21032889
# 1       45.23511907
# 2       54.55645373
# 3       53.66007735
# 4       55.20337963

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 1
subset_1_nutrition_sorted_by_sql.insert(0, 'subset', 1)

print("DataFrame with new 'subset' column:")
display(subset_1_nutrition_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab        id tax_order    family  \
# 0       1  1  Genetic bank  F24-3416  CIAT-705   Fabales  Fabaceae
# 1       1  2  Genetic bank  F24-3416  CIAT-705   Fabales  Fabaceae
# 2       1  3  Genetic bank  F24-3417  CIAT-707   Fabales  Fabaceae
# 3       1  4  Genetic bank  F24-3417  CIAT-707   Fabales  Fabaceae
# 4       1  5  Genetic bank  F24-3418  CIAT-712   Fabales  Fabaceae
#
#          genus       species                 tax_name    functional_group  \
# 0   Indigofera  suffruticosa  Indigofera suffruticosa  Herbaceous_legumes
# 1   Indigofera  suffruticosa  Indigofera suffruticosa  Herbaceous_legumes
# 2  Alysicarpus   ovalifolius  Alysicarpus ovalifolius  Herbaceous_legumes
# 3  Alysicarpus   ovalifolius  Alysicarpus ovalifolius  Herbaceous_legumes
# 4     Clitoria      ternatea        Clitoria ternatea  Herbaceous_legumes
#
#   set_ciat dm_percentage       ash_dm om_percentage pc_percentage_dm  \
# 0        1   91.93080692  12.72569067   87.27430933      33.01052157
# 1        1         92.01  12.62906206   87.37093794      33.01052157
# 2        1   90.64280716  11.91132679   88.08867321      25.39749175
# 3        1   89.54209158  12.23760607   87.76239393      25.39749175
# 4        1   91.25174965   7.71337789   92.28662211      31.19171324
#
#   adf_percentage_dm ndf_percentage_dm
# 0       28.48961421       45.21032889
# 1       27.61265655       45.23511907
# 2       26.19631971       54.55645373
# 3       24.68485778       53.66007735
# 4       26.67696802       55.20337963

# %% [markdown]
# # 2. Subset 2
#
# NOTE: For this subset data from /content/drive/MyDrive/lmf/data/2026_05_29_sql_data_frame_creation_for_methane_intensity_and_tddm_estimations/subset_2/ was used because the updated files do not contain the complete information

# %% [markdown]
# ## 2.1. Loading data

# %%
# Load the CSVs from Drive into pandas DataFrames
subset_2_information_samples = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_2/csv/10_information_samples.csv')
subset_2_gas_original = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_2/csv/31_gas_prod.csv')
subset_2_gas_curated = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_2/csv/40g_result_gas_prod_data_vf.csv')
subset_2_nutrition = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_2/csv/40n_result_q_raw_data.csv')
subset_2_digest = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_2/csv/32_digest.csv')

# %% [markdown]
# ## 2.2. Cleaning and formatting dataframes

# %%
# Clean first row containing orignal column names from excel files
subset_2_information_samples = remove_first_row(subset_2_information_samples)
subset_2_gas_original = remove_first_row(subset_2_gas_original)
subset_2_gas_curated = remove_first_row(subset_2_gas_curated)
subset_2_nutrition = remove_first_row(subset_2_nutrition)
subset_2_digest = remove_first_row(subset_2_digest)

# Add '-' to lab ids and ensure correct format FXX-XXXX
subset_2_information_samples['10_ciat_lab_id'] = clean_lab_ids(subset_2_information_samples['10_ciat_lab_id'])
subset_2_gas_original['31_ciat_id'] = clean_lab_ids(subset_2_gas_original['31_ciat_id'])
subset_2_gas_curated['40g_ciat_id'] = clean_lab_ids(subset_2_gas_curated['40g_ciat_id'])
subset_2_nutrition['40n_sample_id'] = clean_lab_ids(subset_2_nutrition['40n_sample_id'])
subset_2_digest['32_ciat_id'] = clean_lab_ids(subset_2_digest['32_ciat_id'])

# Clean and standardize gene bank and breeding program ids
subset_2_information_samples['10_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_2_information_samples['10_gene_bank_breeding_program_id'])
subset_2_gas_original['31_gene_bank_id'] = clean_standardize_ids(subset_2_gas_original['31_gene_bank_id'])
subset_2_gas_curated['40g_gene_bank_id'] = clean_standardize_ids(subset_2_gas_curated['40g_gene_bank_id'])
subset_2_nutrition['40n_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_2_nutrition['40n_gene_bank_breeding_program_id'])
subset_2_digest['32_gene_bank_id'] = clean_standardize_ids(subset_2_digest['32_gene_bank_id'])

# %%
# Check functional groups categories
subset_2_information_samples['10_functional_group'].unique()
# Out:
# array(['Shrub', 'Herbaceous', 'Climber', 'Forage', 'Concentrate',
#        'Grasses', 'Tree', 'grasses', nan], dtype=object)

# %%
# Apply the mapping to centers datt
subset_2_information_samples['10_functional_group'] = subset_2_information_samples['10_functional_group'].replace(functional_group_mapping)

print('Updated functional group counts for subset_2_information_samples:')
display(subset_2_information_samples['10_functional_group'].value_counts())
# Out:
# Updated functional group counts for subset_2_information_samples:
# 10_functional_group
# Grass                 122
# Herbaceous_legumes    109
# Shrub_Trees            29
# Concentrate             9
# Forage                  8
# Name: count, dtype: int64

# %% [markdown]
# ## 2.3. SQL query and dataframe creation

# %% [markdown]
# ### 2.3.1. Gas

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_2_information_samples.to_sql('subset_2_information_samples', conn_new, if_exists='replace', index=False)
subset_2_gas_original.to_sql('subset_2_gas_original', conn_new, if_exists='replace', index=False)
subset_2_gas_curated.to_sql('subset_2_gas_curated', conn_new, if_exists='replace', index=False)
subset_2_digest.to_sql('subset_2_digest', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_2_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner',
#        '10_requisitioner_2', '10_set_ciat', '10_ciat_lab_id',
#        '10_gene_bank_breeding_program_id', '10_genus', '10_species',
#        '10_tax_name', '10_family', '10_order', '10_functional_group',
#        '10_remarks_1', '10_id_lab', '10_remarks_2'],
#       dtype='object')

# %%
subset_2_digest.columns
# Out:
# Index(['32_no', '32_date', '32_requisitioner', '32_gene_bank_id', '32_genus',
#        '32_species', '32_tax_name', '32_family', '32_order',
#        '32_functional_group', '32_ciat_id', '32_set_ciat', '32_batch',
#        '32_run', '32_replication', '32_syrange_no', '32_bag_weight_g',
#        '32_digested_weight_g', '32_remarks_1', '32_undigested_dm_g',
#        '32_digested_feed_mg', '32_percentage_dmd_truly_digestibility',
#        '32_ndf_incubated_mg', '32_ndf_digestibility_mg',
#        '32_percentage_ndf_digestibility_in_24h', '32_remarks_2'],
#       dtype='object')

# %%
subset_2_gas_original.columns
# Out:
# Index(['31_no', '31_date', '31_requisitioner', '31_gene_bank_id', '31_genus',
#        '31_species', '31_tax_name', '31_family', '31_order',
#        '31_functional_group', '31_ciat_id', '31_set_ciat', '31_batch',
#        '31_run', '31_replication', '31_syrange_no', '31_sample_weight_g',
#        '31_dm_incubated_mg', '31_digested_feed_mg', '31_time_0h',
#        '31_gas_0h_ml', '31_time_8h', '31_gas_8h_ml', '31_ch4_8h_percentage',
#        '31_v8_push_back_ml', '31_time_24h', '31_gas_24h_ml',
#        '31_ch4_24h_percentage', '31_remarks_1', '31_gp_8h_ml', '31_gp_8_24h',
#        '31_net_gas_8h_ml', '31_net_gas_8_24h_ml2', '31_net_gas_24h_ml',
#        '31_ch4_8h_ml', '31_ch4_8_24h_ml', '31_ch4_24h_ml',
#        '31_gas_ml_g_dm_incubated_24h', '31_percentage_dmd_truly_digestibility',
#        '31_part_fact', '31_ch4_percentage_in_gas_8h',
#        '31_ch4_percentage_in_gas_24h', '31_ch4_ml_g_dm_incubated_24h',
#        '31_ch4_ml_g_dmd_24h', '31_ch4_ml_g_ndf_digested_in_24h',
#        '31_ch4_g_g_dm_incubated_24h', '31_ch4_g_g_dmd_24h'],
#       dtype='object')

# %%
subset_2_gas_curated.columns
# Out:
# Index(['40g_no', '40g_date', '40g_requisitioner', '40g_gene_bank_id',
#        '40g_genus', '40g_species', '40g_tax_name', '40g_family', '40g_order',
#        '40g_functional_group', '40g_ciat_id', '40g_set_ciat', '40g_batch',
#        '40g_run', '40g_replication', '40g_syrange_no', '40g_ch4_8h_percentage',
#        '40g_ch4_24h_percentage', '40g_net_gas_8h_ml', '40g_net_gas_24h_ml',
#        '40g_gas_ml_g_dm_incubated_24h',
#        '40g_percentage_dmd_truly_digestibility', '40g_part_fact',
#        '40g_ch4_percentage_in_gas_8h', '40g_ch4_percentage_in_gas_24h',
#        '40g_ch4_ml_g_dm_incubated_24h', '40g_ch4_ml_g_dmd_24h',
#        '40g_ch4_ml_g_ndf_digested_in_24h', '40g_ch4_g_g_dm_incubated_24h',
#        '40g_ch4_g_g_dmd_24h', '40g_remarks2', '40g_remarks_1'],
#       dtype='object')

# %%
query_combined = """
SELECT
    s2gc."40g_no" as no,
    s2i."10_requisitioner" as requisitioner,
    s2i."10_ciat_lab_id" as id_lab,
    s2i."10_gene_bank_breeding_program_id" as id,
    s2i."10_order" as tax_order,
    s2i."10_family" as family,
    s2i."10_genus" as genus,
    s2i."10_species" as species,
    s2i."10_tax_name" as tax_name,
    s2i."10_functional_group" as functional_group,

    s2gc."40g_set_ciat" as set_ciat,
    s2gc."40g_batch" as batch,
    s2gc."40g_run" as run,
    s2gc."40g_replication" as replication,
    s2gc."40g_syrange_no" as syrange,

    s2go."31_sample_weight_g" as sample_weight_g,
    s2d."32_undigested_dm_g" as undigested_dm_g,
    s2go."31_dm_incubated_mg" as dm_incubated,
    s2go."31_digested_feed_mg" as digested_feed_mg,

    s2gc."40g_net_gas_8h_ml" as net_gas_8h_ml,
    s2gc."40g_net_gas_24h_ml" as net_gas_24h_ml,
    s2go."31_ch4_8h_ml" as ch4_8h_ml,
    s2go."31_ch4_24h_ml" as ch4_24h_ml,
    s2gc."40g_ch4_percentage_in_gas_8h" as ch4_percentage_in_gas_8h,
    s2gc."40g_ch4_percentage_in_gas_24h" as ch4_percentage_in_gas_24h,

    s2gc."40g_gas_ml_g_dm_incubated_24h" as gas_ml_g_dm_incubated_24h,
    s2gc."40g_part_fact" as part_fact,

    s2gc."40g_ch4_ml_g_dm_incubated_24h" as ch4_ml_g_dm_incubated_24h,
    s2gc."40g_ch4_ml_g_ndf_digested_in_24h" as ch4_ml_g_ndf_digested_24h,
    s2gc."40g_ch4_ml_g_dmd_24h" as methane_intensity,
    s2gc."40g_percentage_dmd_truly_digestibility" as tddm,

    s2i."10_remarks_1" as information_remarks_1,
    s2i."10_remarks_2" as information_remarks_2,
    s2gc."40g_remarks_1" as gas_remarks_1,
    s2gc."40g_remarks2" as gas_remarks_2,
    s2d."32_remarks_1" as digest_remarks_1,
    s2d."32_remarks_2" as digest_remarks_2

FROM
    subset_2_information_samples AS s2i
JOIN
    subset_2_gas_original AS s2go
ON s2i."10_ciat_lab_id" = s2go."31_ciat_id"

JOIN subset_2_gas_curated AS s2gc
ON s2go."31_gene_bank_id" = s2gc."40g_gene_bank_id"
AND s2go."31_no" = s2gc."40g_no"
AND s2go."31_replication" = s2gc."40g_replication"
AND s2go."31_syrange_no" = s2gc."40g_syrange_no"


LEFT JOIN subset_2_digest AS s2d
ON s2go."31_ciat_id" = s2d."32_ciat_id"
AND s2go."31_no" = s2d."32_no"
AND s2go."31_replication" = s2d."32_replication"
AND s2go."31_syrange_no" = s2d."32_syrange_no"

ORDER BY
    CAST(no AS INTEGER) ASC

"""

subset_2_gas_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_2_gas_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#         no requisitioner    id_lab          id tax_order    family  \
# 0        3  Genetic bank  F24-3536  CIAT-32379   Fabales  Fabaceae
# 1        4  Genetic bank  F24-3536  CIAT-32379   Fabales  Fabaceae
# 2        5  Genetic bank  F24-3536  CIAT-32379   Fabales  Fabaceae
# 3        6  Genetic bank  F24-3537  CIAT-32380   Fabales  Fabaceae
# 4        7  Genetic bank  F24-3537  CIAT-32380   Fabales  Fabaceae
# ...    ...           ...       ...         ...       ...       ...
# 4287  2704           LMF  F25-0008    Sample-8    Poales   Poaceae
# 4288  2704           LMF  F25-0008    Sample-8    Poales   Poaceae
# 4289  2704           LMF  F25-0008    Sample-8    Poales   Poaceae
# 4290  2704           LMF  F25-0008    Sample-8    Poales   Poaceae
# 4291  2704           LMF  F25-0008    Sample-8    Poales   Poaceae
#
#            genus        species              tax_name functional_group  ...  \
# 0     Desmanthus      pubescens  Desmanthus pubescens      Shrub_Trees  ...
# 1     Desmanthus      pubescens  Desmanthus pubescens      Shrub_Trees  ...
# 2     Desmanthus      pubescens  Desmanthus pubescens      Shrub_Trees  ...
# 3     Desmanthus      pubescens  Desmanthus pubescens      Shrub_Trees  ...
# 4     Desmanthus      pubescens  Desmanthus pubescens      Shrub_Trees  ...
# ...          ...            ...                   ...              ...  ...
# 4287     Cynodon   nlemfuensis   Cynodon nlemfuensis             Grass  ...
# 4288     Cynodon   nlemfuensis   Cynodon nlemfuensis             Grass  ...
# 4289     Cynodon   nlemfuensis   Cynodon nlemfuensis             Grass  ...
# 4290     Cynodon   nlemfuensis   Cynodon nlemfuensis             Grass  ...
# 4291     Cynodon   nlemfuensis   Cynodon nlemfuensis             Grass  ...
#
#      ch4_ml_g_dm_incubated_24h ch4_ml_g_ndf_digested_24h methane_intensity  \
# 0                         None                      None              None
# 1                  20.31582781                273.271034       39.70956133
# 2                  20.08496777               252.5610572       37.91405033
# 3                  18.43390334               384.2727187       46.96225419
# 4                  18.13777198               522.5124359       52.70349781
# ...                        ...                       ...               ...
# 4287               19.22069259                   #DIV/0!       45.43396889
# 4288               19.22069259                   #DIV/0!       45.43396889
# 4289               19.22069259                   #DIV/0!       45.43396889
# 4290               19.22069259                   #DIV/0!       45.43396889
# 4291               19.22069259                   #DIV/0!       45.43396889
#
#              tddm information_remarks_1 information_remarks_2 gas_remarks_1  \
# 0            None                  None                  None          None
# 1     51.16104819                  None                  None          None
# 2     52.97499896                  None                  None          None
# 3     39.25259478                  None                  None          None
# 4     34.41474045                  None                  None          None
# ...           ...                   ...                   ...           ...
# 4287  42.29621851                  None              33,34,35          None
# 4288  42.29621851                  None              36,37,38          None
# 4289  42.29621851                  None              36,37,38          None
# 4290  42.29621851                  None              42,43,47          None
# 4291  42.29621851                  None              45,46,47          None
#
#      gas_remarks_2                   digest_remarks_1 digest_remarks_2
# 0             None  Bolsa abierta, perdida de muestra          Eliminó
# 1             None                               None             None
# 2             None                               None             None
# 3             None                               None             None
# 4             None                               None             None
# ...            ...                                ...              ...
# 4287          None                               None             None
# 4288          None                               None             None
# 4289          None                               None             None
# 4290          None                               None             None
# 4291          None                               None             None
#
# [4292 rows x 37 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_2_gas_sorted_by_sql = subset_2_gas_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_2_gas_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_2_gas_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (3583, 37)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab          id tax_order    family       genus  \
# 0  3  Genetic bank  F24-3536  CIAT-32379   Fabales  Fabaceae  Desmanthus
# 1  4  Genetic bank  F24-3536  CIAT-32379   Fabales  Fabaceae  Desmanthus
# 2  5  Genetic bank  F24-3536  CIAT-32379   Fabales  Fabaceae  Desmanthus
# 3  6  Genetic bank  F24-3537  CIAT-32380   Fabales  Fabaceae  Desmanthus
# 4  7  Genetic bank  F24-3537  CIAT-32380   Fabales  Fabaceae  Desmanthus
#
#      species              tax_name functional_group  ...  \
# 0  pubescens  Desmanthus pubescens      Shrub_Trees  ...
# 1  pubescens  Desmanthus pubescens      Shrub_Trees  ...
# 2  pubescens  Desmanthus pubescens      Shrub_Trees  ...
# 3  pubescens  Desmanthus pubescens      Shrub_Trees  ...
# 4  pubescens  Desmanthus pubescens      Shrub_Trees  ...
#
#   ch4_ml_g_dm_incubated_24h ch4_ml_g_ndf_digested_24h methane_intensity  \
# 0                      None                      None              None
# 1               20.31582781                273.271034       39.70956133
# 2               20.08496777               252.5610572       37.91405033
# 3               18.43390334               384.2727187       46.96225419
# 4               18.13777198               522.5124359       52.70349781
#
#           tddm information_remarks_1 information_remarks_2 gas_remarks_1  \
# 0         None                  None                  None          None
# 1  51.16104819                  None                  None          None
# 2  52.97499896                  None                  None          None
# 3  39.25259478                  None                  None          None
# 4  34.41474045                  None                  None          None
#
#   gas_remarks_2                   digest_remarks_1 digest_remarks_2
# 0          None  Bolsa abierta, perdida de muestra          Eliminó
# 1          None                               None             None
# 2          None                               None             None
# 3          None                               None             None
# 4          None                               None             None
#
# [5 rows x 37 columns]

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 2
subset_2_gas_sorted_by_sql.insert(0, 'subset', 2)

print("DataFrame with new 'subset' column:")
display(subset_2_gas_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab          id tax_order    family  \
# 0       2  3  Genetic bank  F24-3536  CIAT-32379   Fabales  Fabaceae
# 1       2  4  Genetic bank  F24-3536  CIAT-32379   Fabales  Fabaceae
# 2       2  5  Genetic bank  F24-3536  CIAT-32379   Fabales  Fabaceae
# 3       2  6  Genetic bank  F24-3537  CIAT-32380   Fabales  Fabaceae
# 4       2  7  Genetic bank  F24-3537  CIAT-32380   Fabales  Fabaceae
#
#         genus    species              tax_name  ... ch4_ml_g_dm_incubated_24h  \
# 0  Desmanthus  pubescens  Desmanthus pubescens  ...                      None
# 1  Desmanthus  pubescens  Desmanthus pubescens  ...               20.31582781
# 2  Desmanthus  pubescens  Desmanthus pubescens  ...               20.08496777
# 3  Desmanthus  pubescens  Desmanthus pubescens  ...               18.43390334
# 4  Desmanthus  pubescens  Desmanthus pubescens  ...               18.13777198
#
#   ch4_ml_g_ndf_digested_24h methane_intensity         tddm  \
# 0                      None              None         None
# 1                273.271034       39.70956133  51.16104819
# 2               252.5610572       37.91405033  52.97499896
# 3               384.2727187       46.96225419  39.25259478
# 4               522.5124359       52.70349781  34.41474045
#
#   information_remarks_1 information_remarks_2 gas_remarks_1 gas_remarks_2  \
# 0                  None                  None          None          None
# 1                  None                  None          None          None
# 2                  None                  None          None          None
# 3                  None                  None          None          None
# 4                  None                  None          None          None
#
#                     digest_remarks_1 digest_remarks_2
# 0  Bolsa abierta, perdida de muestra          Eliminó
# 1                               None             None
# 2                               None             None
# 3                               None             None
# 4                               None             None
#
# [5 rows x 38 columns]

# %%
subset_2_gas_sorted_by_sql.to_csv('gas2.csv', index=None)

# %% [markdown]
# ### 2.3.2. Nutrition

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_2_information_samples.to_sql('subset_2_information_samples', conn_new, if_exists='replace', index=False)
subset_2_nutrition.to_sql('subset_2_nutrition', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_2_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner',
#        '10_requisitioner_2', '10_set_ciat', '10_ciat_lab_id',
#        '10_gene_bank_breeding_program_id', '10_genus', '10_species',
#        '10_tax_name', '10_family', '10_order', '10_functional_group',
#        '10_remarks_1', '10_id_lab', '10_remarks_2'],
#       dtype='object')

# %%
query_combined = """
SELECT
    s2n."40n_no" as no,
    s2i."10_requisitioner" as requisitioner,
    s2i."10_ciat_lab_id" as id_lab,
    s2i."10_gene_bank_breeding_program_id" as id,
    s2i."10_order" as tax_order,
    s2i."10_family" as family,
    s2i."10_genus" as genus,
    s2i."10_species" as species,
    s2i."10_tax_name" as tax_name,
    s2i."10_functional_group" as functional_group,
    s2i."10_set_ciat" as set_ciat,
    s2n."40n_dm_percentage" as dm_percentage,
    s2n."40n_ash_dm" as ash_dm,
    s2n."40n_om_percentage" as om_percentage,
    s2n."40n_pc_percentage_dm" as pc_percentage_dm,
    s2n."40n_adf_percentage_dm" as adf_percentage_dm,
    s2n."40n_ndf_percentage_dm" as ndf_percentage_dm



FROM
    subset_2_information_samples AS s2i
JOIN
    subset_2_nutrition AS s2n
ON
    s2i."10_ciat_lab_id" = s2n."40n_sample_id"
ORDER BY
    CAST(no AS INTEGER) ASC NULLS LAST
"""

subset_2_nutrition_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_2_nutrition_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#        no requisitioner    id_lab                     id    tax_order  \
# 0       1  Genetic bank  F24-3536             CIAT-32379      Fabales
# 1       2  Genetic bank  F24-3536             CIAT-32379      Fabales
# 2       3  Genetic bank  F24-3537             CIAT-32380      Fabales
# 3       4  Genetic bank  F24-3537             CIAT-32380      Fabales
# 4       5  Genetic bank  F24-3538             CIAT-33249      Fabales
# ..    ...           ...       ...                    ...          ...
# 877  None           LMF  F25-0008               Sample-8       Poales
# 878  None           LMF  F25-0018  Homenheim-Concentrate  Concentrate
# 879  None           LMF  F25-0018  Homenheim-Concentrate  Concentrate
# 880  None           LMF  F25-0008               Sample-8       Poales
# 881  None           LMF  F25-0008               Sample-8       Poales
#
#           family       genus        species               tax_name  \
# 0       Fabaceae  Desmanthus      pubescens   Desmanthus pubescens
# 1       Fabaceae  Desmanthus      pubescens   Desmanthus pubescens
# 2       Fabaceae  Desmanthus      pubescens   Desmanthus pubescens
# 3       Fabaceae  Desmanthus      pubescens   Desmanthus pubescens
# 4       Fabaceae   Desmodium      velutinum    Desmodium velutinum
# ..           ...         ...            ...                    ...
# 877      Poaceae     Cynodon   nlemfuensis    Cynodon nlemfuensis
# 878  Concentrate   Homenheim    Concentrate  Homenheim Concentrate
# 879  Concentrate   Homenheim    Concentrate  Homenheim Concentrate
# 880      Poaceae     Cynodon   nlemfuensis    Cynodon nlemfuensis
# 881      Poaceae     Cynodon   nlemfuensis    Cynodon nlemfuensis
#
#     functional_group set_ciat dm_percentage       ash_dm om_percentage  \
# 0        Shrub_Trees       14         92.91         8.21         91.79
# 1        Shrub_Trees       14         92.97         8.28         91.72
# 2        Shrub_Trees       14         93.26          8.8          91.2
# 3        Shrub_Trees       14         93.34         8.73         91.27
# 4        Shrub_Trees       14         93.06          9.7          90.3
# ..               ...      ...           ...          ...           ...
# 877            Grass       21   93.82123575  11.49829497   88.50170503
# 878      Concentrate       22   89.65413834  5.886943918   94.11305608
# 879      Concentrate       22   89.73205359  6.183844011   93.81615599
# 880            Grass       22   93.64063594  11.32941805   88.67058195
# 881            Grass       22   93.82123575  11.49829497   88.50170503
#
#     pc_percentage_dm adf_percentage_dm ndf_percentage_dm
# 0              27.65              19.6             75.23
# 1              27.65              18.3             74.02
# 2              29.33             31.17             77.81
# 3              29.33             30.62             78.73
# 4              16.48             42.74             76.85
# ..               ...               ...               ...
# 877                0                 0                 0
# 878                0                 0                 0
# 879                0                 0                 0
# 880                0                 0                 0
# 881                0                 0                 0
#
# [882 rows x 17 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_2_nutrition_sorted_by_sql = subset_2_nutrition_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_2_nutrition_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_2_nutrition_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (882, 17)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab          id tax_order    family       genus  \
# 0  1  Genetic bank  F24-3536  CIAT-32379   Fabales  Fabaceae  Desmanthus
# 1  2  Genetic bank  F24-3536  CIAT-32379   Fabales  Fabaceae  Desmanthus
# 2  3  Genetic bank  F24-3537  CIAT-32380   Fabales  Fabaceae  Desmanthus
# 3  4  Genetic bank  F24-3537  CIAT-32380   Fabales  Fabaceae  Desmanthus
# 4  5  Genetic bank  F24-3538  CIAT-33249   Fabales  Fabaceae   Desmodium
#
#      species              tax_name functional_group set_ciat dm_percentage  \
# 0  pubescens  Desmanthus pubescens      Shrub_Trees       14         92.91
# 1  pubescens  Desmanthus pubescens      Shrub_Trees       14         92.97
# 2  pubescens  Desmanthus pubescens      Shrub_Trees       14         93.26
# 3  pubescens  Desmanthus pubescens      Shrub_Trees       14         93.34
# 4  velutinum   Desmodium velutinum      Shrub_Trees       14         93.06
#
#   ash_dm om_percentage pc_percentage_dm adf_percentage_dm ndf_percentage_dm
# 0   8.21         91.79            27.65              19.6             75.23
# 1   8.28         91.72            27.65              18.3             74.02
# 2    8.8          91.2            29.33             31.17             77.81
# 3   8.73         91.27            29.33             30.62             78.73
# 4    9.7          90.3            16.48             42.74             76.85

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 2
subset_2_nutrition_sorted_by_sql.insert(0, 'subset', 2)

print("DataFrame with new 'subset' column:")
display(subset_2_nutrition_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab          id tax_order    family  \
# 0       2  1  Genetic bank  F24-3536  CIAT-32379   Fabales  Fabaceae
# 1       2  2  Genetic bank  F24-3536  CIAT-32379   Fabales  Fabaceae
# 2       2  3  Genetic bank  F24-3537  CIAT-32380   Fabales  Fabaceae
# 3       2  4  Genetic bank  F24-3537  CIAT-32380   Fabales  Fabaceae
# 4       2  5  Genetic bank  F24-3538  CIAT-33249   Fabales  Fabaceae
#
#         genus    species              tax_name functional_group set_ciat  \
# 0  Desmanthus  pubescens  Desmanthus pubescens      Shrub_Trees       14
# 1  Desmanthus  pubescens  Desmanthus pubescens      Shrub_Trees       14
# 2  Desmanthus  pubescens  Desmanthus pubescens      Shrub_Trees       14
# 3  Desmanthus  pubescens  Desmanthus pubescens      Shrub_Trees       14
# 4   Desmodium  velutinum   Desmodium velutinum      Shrub_Trees       14
#
#   dm_percentage ash_dm om_percentage pc_percentage_dm adf_percentage_dm  \
# 0         92.91   8.21         91.79            27.65              19.6
# 1         92.97   8.28         91.72            27.65              18.3
# 2         93.26    8.8          91.2            29.33             31.17
# 3         93.34   8.73         91.27            29.33             30.62
# 4         93.06    9.7          90.3            16.48             42.74
#
#   ndf_percentage_dm
# 0             75.23
# 1             74.02
# 2             77.81
# 3             78.73
# 4             76.85

# %% [markdown]
# # 3. Subset 3

# %% [markdown]
# ## 3.1. Loading data

# %%
# Load the CSVs from Drive into pandas DataFrames
subset_3_information_samples = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_3/csv/10_information_samples.csv')
subset_3_gas_prod = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_3/csv/40_result_gp_corrected_alejandra.csv')
subset_3_gas_ori = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_3/csv/31_gas_prod_corrected_alejandra.csv')
subset_3_nutrition = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_3/csv/40n_result_q_raw_data_vf.csv')
subset_3_digest = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_3/csv/32_digest.csv')

# %%
subset_3_digest.iloc[:5,:15]
# Out:
#   32_no 32_date 32_date_2 32_gene_bank_id          32_tax_name     32_family  \
# 0    No    Date      Date    Gene Bank ID             Tax Name        Family
# 1     1   45630     45923      BLANK 24 H           BLANK 24 H    BLANK 24 H
# 2     2   45630     45923      ABC-1467-1  Stylosanthes hamata  Stylosanthes
# 3     3   45630     45923      ABC-1467-1  Stylosanthes hamata  Stylosanthes
# 4     4   45630     45923      ABC-1467-1  Stylosanthes hamata  Stylosanthes
#
#      32_order  32_genus_2 32_species_3 32_functional_group  32_ciat_id  \
# 0       Order      Genus2     Species3    Functional Group     CIAT ID
# 1  BLANK 24 H  BLANK 24 H   BLANK 24 H          BLANK 24 H  BLANK 24 H
# 2      hamata    Fabaceae      Fabales          Herbaceous    F24 3540
# 3      hamata    Fabaceae      Fabales          Herbaceous    F24 3540
# 4      hamata    Fabaceae      Fabales          Herbaceous    F24 3540
#
#   32_set_ciat 32_batch 32_run 32_replication
# 0    Set CIAT    Batch    Run    Replication
# 1          23       46      1              2
# 2          23       46      1              1
# 3          23       46      1              2
# 4          23       46      1              3

# %% [markdown]
# ## 3.2. Cleaning and formatting dataframes

# %%
# Clean first row containing orignal column names from excel files
subset_3_information_samples = remove_first_row(subset_3_information_samples)
subset_3_gas_prod = remove_first_row(subset_3_gas_prod)
subset_3_gas_ori= remove_first_row(subset_3_gas_ori)
subset_3_nutrition = remove_first_row(subset_3_nutrition)
subset_3_digest = remove_first_row(subset_3_digest)

# Add '-' to lab ids and ensure correct format FXX-XXXX
subset_3_information_samples['10_ciat_lab_id'] = clean_lab_ids(subset_3_information_samples['10_ciat_lab_id'])
subset_3_gas_prod['40g_ciat_id'] = clean_lab_ids(subset_3_gas_prod['40g_ciat_id'])
subset_3_gas_ori['31_ciat_id'] = clean_lab_ids(subset_3_gas_ori['31_ciat_id'])
subset_3_nutrition['40n_sample_id'] = clean_lab_ids(subset_3_nutrition['40n_sample_id'])
subset_3_digest['32_ciat_id'] = clean_lab_ids(subset_3_digest['32_ciat_id'])

# Clean and standardize gene bank and breeding program ids
subset_3_information_samples['10_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_3_information_samples['10_gene_bank_breeding_program_id'])
subset_3_gas_prod['40g_gene_bank_id'] = clean_standardize_ids(subset_3_gas_prod['40g_gene_bank_id'])
subset_3_gas_ori['31_gene_bank_id'] = clean_standardize_ids(subset_3_gas_ori['31_gene_bank_id'])
subset_3_nutrition['40n_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_3_nutrition['40n_gene_bank_breeding_program_id'])
subset_3_digest['32_gene_bank_id'] = clean_standardize_ids(subset_3_digest['32_gene_bank_id'])

# %%
# Check functional groups categories
subset_3_information_samples['10_functional_group'].unique()
# Out:
# array(['Herbaceous', 'Shrub', 'Climber', 'grasses', nan, 'Herbáceas ',
#        'Arbustiva '], dtype=object)

# %%
# Apply the mapping to centers datt
subset_3_information_samples['10_functional_group'] = subset_3_information_samples['10_functional_group'].replace(functional_group_mapping)

print('Updated functional group counts for subset_3_information_samples:')
display(subset_3_information_samples['10_functional_group'].value_counts())
# Out:
# Updated functional group counts for subset_3_information_samples:
# 10_functional_group
# Herbaceous_legumes    81
# Shrub_Trees           21
# Grass                 20
# Name: count, dtype: int64

# %% [markdown]
# ## 3.3. SQL query and dataframe creation

# %% [markdown]
# ### 3.3.1. Gas

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_3_information_samples.to_sql('subset_3_information_samples', conn_new, if_exists='replace', index=False)
subset_3_gas_prod.to_sql('subset_3_gas_prod', conn_new, if_exists='replace', index=False)
subset_3_gas_ori.to_sql('subset_3_gas_ori', conn_new, if_exists='replace', index=False)
subset_3_digest.to_sql('subset_3_digest', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_3_digest.columns
# Out:
# Index(['32_no', '32_date', '32_date_2', '32_gene_bank_id', '32_tax_name',
#        '32_family', '32_order', '32_genus_2', '32_species_3',
#        '32_functional_group', '32_ciat_id', '32_set_ciat', '32_batch',
#        '32_run', '32_replication', '32_syrange_no', '32_bag_weight_g',
#        '32_bag_digested_weight_g', '32_remarks_1', '32_undigested_dm_g',
#        '32_digested_feed_mg', '32_percentage_dmd_truly_digestibility',
#        '32_ndf_incubated_mg', '32_ndf_digestibility_mg',
#        '32_percentage_ndf_digestibility_in_24h', '32_remarks_2'],
#       dtype='object')

# %%
subset_3_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner',
#        '10_requisitioner_2', '10_set_ciat', '10_ciat_lab_id',
#        '10_gene_bank_breeding_program_id', '10_genus', '10_species',
#        '10_tax_name', '10_family', '10_order', '10_functional_group',
#        '10_remarks_1', '10_id_lab', '10_remarks_2'],
#       dtype='object')

# %%
subset_3_gas_prod.columns
# Out:
# Index(['40g_no', '40g_no.1', '40g_requisitioner', '40g_gene_bank_id',
#        '40g_tax_name', '40g_family', '40g_order', '40g_genus2',
#        '40g_species_3', '40g_functional_group', '40g_ciat_id', '40g_set_ciat',
#        '40g_batch', '40g_run', '40g_replication', '40g_syrange_no',
#        '40g_net_gas_8h_ml', '40g_net_gas_8_24h_ml2', '40g_net_gas_24h_ml',
#        '40g_ch4_8h_ml', '40g_ch4_8_24h_ml', '40g_ch4_24h_ml',
#        '40g_gas_ml_g_dm_incubated_24h',
#        '40g_percentage_dmd_truly_digestibility', '40g_part_fact',
#        '40g_ch4_ml_in_gas_8h', '40g_ch4_ml_in_gas_24h',
#        '40g_ch4_ml_g_dm_incubated_24h', '40g_ch4_ml_g_dmd_24h',
#        '40g_ch4_ml_g_ndf_digested_in_24_h', '40g_ch4_g_g_dm_incubated_24h',
#        '40g_ch4_g_g_dmd_24h', '40g_remarks_1', '40g_remarks_2'],
#       dtype='object')

# %%
subset_3_gas_ori.columns
# Out:
# Index(['31_no', '31_date', '31_requisitioner', '31_gene_bank_id',
#        '31_tax_name', '31_family', '31_order', '31_genus2', '31_species3',
#        '31_functional_group', '31_ciat_id', '31_set_ciat', '31_batch',
#        '31_run', '31_replication', '31_syrangue_no', '31_sample_weight_g',
#        '31_dm_incubated_mg', '31_digested_feed_mg', '31_time_0h',
#        '31_gas_0h_ml', '31_time_8h', '31_gas_8h_ml', '31_ch4_8h_percentage',
#        '31_v8_push_back_ml', '31_time_24h', '31_gas_24h_ml',
#        '31_ch4_24h_percentage', '31_remarks_1', '31_gp_8h_ml',
#        '31_gp_8_24h_ml', '31_net_gas_8h_ml', '31_net_gas_8_24h_ml2',
#        '31_net_gas_24h_ml', '31_ch4_8h_ml', '31_ch4_8_24h_ml', '31_ch4_24h_ml',
#        '31_gas_ml_g_dm_incubated_24h', '31_percentage_dmd_truly_digestibility',
#        '31_part_fact', '31_ch4_ml_in_gas_8h', '31_ch4_ml_in_gas_24h',
#        '31_ch4_ml_g_dm_incubated_24h', '31_ch4_ml_g_dmd_24h',
#        '31_ch4_ml_g_ndf_digested_in_24h', '31_ch4_g_g_dm_incubated_24h',
#        '31_ch4_g_g_dmd_24h', '31_column8'],
#       dtype='object')

# %%
# Note: For this subset the columns names '40g_ch4_ml_in_gas_8h', '40g_ch4_ml_in_gas_24h' are incorrect, since they refer to percentages in gas!!!!
query_combined = """
SELECT
    s3g."40g_no" as no,
    s3i."10_requisitioner" as requisitioner,
    s3i."10_ciat_lab_id" as id_lab,
    s3i."10_gene_bank_breeding_program_id" as id,
    s3i."10_order" as tax_order,
    s3i."10_family" as family,
    s3i."10_genus" as genus,
    s3i."10_species" as species,
    s3i."10_tax_name" as tax_name,
    s3i."10_functional_group" as functional_group,

    s3g."40g_set_ciat" as set_ciat,
    s3g."40g_batch" as batch,
    s3g."40g_run" as run,
    s3g."40g_replication" as replication,
    s3g."40g_syrange_no" as syrange,

    s3go."31_sample_weight_g" as sample_weight_g,
    s3d."32_undigested_dm_g" as undigested_dm_g,
    s3go."31_dm_incubated_mg" as dm_incubated,
    s3go."31_digested_feed_mg" as digested_feed_mg,

    s3g."40g_net_gas_8h_ml" as net_gas_8h_ml,
    s3g."40g_net_gas_24h_ml" as net_gas_24h_ml,
    s3g."40g_ch4_8h_ml" as ch4_8h_ml,
    s3g."40g_ch4_24h_ml" as ch4_24h_ml,
    s3g."40g_ch4_ml_in_gas_8h" as ch4_percentage_in_gas_8h,
    s3g."40g_ch4_ml_in_gas_24h" as ch4_percentage_in_gas_24h,

    s3g."40g_gas_ml_g_dm_incubated_24h" as gas_ml_g_dm_incubated_24h,
    s3g."40g_part_fact" as part_fact,

    s3g."40g_ch4_ml_g_dm_incubated_24h" as ch4_ml_g_dm_incubated_24h,
    s3g."40g_ch4_ml_g_ndf_digested_in_24_h" as ch4_ml_g_ndf_digested_24h,
    s3g."40g_ch4_ml_g_dmd_24h" as methane_intensity,
    s3g."40g_percentage_dmd_truly_digestibility" as tddm,

    s3i."10_remarks_1" as information_remarks_1,
    s3i."10_remarks_2" as information_remarks_2,
    s3g."40g_remarks_1" as gas_remarks_1,
    s3g."40g_remarks_2" as gas_remarks_2,
    s3d."32_remarks_1" as digest_remarks_1,
    s3d."32_remarks_2" as digest_remarks_2

FROM subset_3_information_samples AS s3i

JOIN subset_3_gas_prod AS s3g
ON s3i."10_ciat_lab_id" = s3g."40g_ciat_id"


LEFT JOIN subset_3_digest AS s3d
ON s3g."40g_ciat_id" = s3d."32_ciat_id"
AND s3g."40g_batch" = s3d."32_batch"
AND s3g."40g_replication" = s3d."32_replication"
AND s3g."40g_syrange_no" = s3d."32_syrange_no"

LEFT JOIN subset_3_gas_ori AS s3go
ON s3g."40g_ciat_id" = s3go."31_ciat_id"
AND s3g."40g_no" = s3go."31_no"
AND s3g."40g_replication" = s3go."31_replication"
AND s3g."40g_syrange_no" = s3go."31_syrangue_no"

ORDER BY
    CAST(no AS INTEGER) ASC
"""




subset_3_gas_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_3_gas_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#         no requisitioner    id_lab                                      id  \
# 0        3  Genetic bank  F24-3540                               CIAT-1467
# 1        4  Genetic bank  F24-3540                               CIAT-1467
# 2        5  Genetic bank  F24-3540                               CIAT-1467
# 3        6  Genetic bank  F24-3541                               CIAT-1475
# 4        7  Genetic bank  F24-3541                               CIAT-1475
# ...    ...           ...       ...                                     ...
# 1467  1281  Genetic bank  F24-3581                              CIAT-12758
# 1468  1282  Genetic bank  F24-3581                              CIAT-12758
# 1469  1283           LMF  F25-2134  Hohenheimer-Heustandard-IAG-2025/1-S-1
# 1470  1284           LMF  F25-2134  Hohenheimer-Heustandard-IAG-2025/1-S-1
# 1471  1285           LMF  F25-2134  Hohenheimer-Heustandard-IAG-2025/1-S-1
#
#         tax_order        family         genus      species  \
# 0         Fabales      Fabaceae  Stylosanthes       hamata
# 1         Fabales      Fabaceae  Stylosanthes       hamata
# 2         Fabales      Fabaceae  Stylosanthes       hamata
# 3         Fabales      Fabaceae  Stylosanthes       hamata
# 4         Fabales      Fabaceae  Stylosanthes       hamata
# ...           ...           ...           ...          ...
# 1467      Fabales      Fabaceae  Stylosanthes   guianensis
# 1468      Fabales      Fabaceae  Stylosanthes   guianensis
# 1469  Green meal    Heustandard   Hohenheimer  Heustandard
# 1470  Green meal    Heustandard   Hohenheimer  Heustandard
# 1471  Green meal    Heustandard   Hohenheimer  Heustandard
#
#                      tax_name    functional_group  ...  \
# 0         Stylosanthes hamata  Herbaceous_legumes  ...
# 1         Stylosanthes hamata  Herbaceous_legumes  ...
# 2         Stylosanthes hamata  Herbaceous_legumes  ...
# 3         Stylosanthes hamata  Herbaceous_legumes  ...
# 4         Stylosanthes hamata  Herbaceous_legumes  ...
# ...                       ...                 ...  ...
# 1467  Stylosanthes guianensis  Herbaceous_legumes  ...
# 1468  Stylosanthes guianensis  Herbaceous_legumes  ...
# 1469  Hohenheimer Heustandard                None  ...
# 1470  Hohenheimer Heustandard                None  ...
# 1471  Hohenheimer Heustandard                None  ...
#
#      ch4_ml_g_dm_incubated_24h ch4_ml_g_ndf_digested_24h methane_intensity  \
# 0                         None                      None              None
# 1                  31.07894731               235.4330642       50.84123828
# 2                         None                      None              None
# 3                  32.51384553               239.5726225       51.71448076
# 4                  31.18086905               256.0454461       56.40388724
# ...                        ...                       ...               ...
# 1467               17.93571056               181.8243261       39.77315131
# 1468               18.10743223               195.9198359       42.85647275
# 1469               16.52896461               156.4811952       34.22946966
# 1470               30.26393334               195.9248522       85.80678795
# 1471               30.14390947               139.7793988       61.21745709
#
#              tddm information_remarks_1 information_remarks_2  \
# 0            None                OT-033                  None
# 1     61.12940668                OT-033                  None
# 2            None                OT-033                  None
# 3     62.87183987                OT-033                  None
# 4     55.28141866                OT-033                  None
# ...           ...                   ...                   ...
# 1467  45.09502006         OT-033 (2024)                  None
# 1468  42.25133584         OT-033 (2024)                  None
# 1469  48.28869618                OT-017                  None
# 1470  35.26985925                OT-017                  None
# 1471   49.2407083                OT-017                  None
#
#                      gas_remarks_1  gas_remarks_2  \
# 0     Eliminado por digestibilidad           None
# 1                             None           None
# 2                             None  Eliminada Dig
# 3                             None           None
# 4                             None           None
# ...                            ...            ...
# 1467                          None           None
# 1468                          None           None
# 1469                          None           None
# 1470                          None           None
# 1471                          None           None
#
#                                        digest_remarks_1 digest_remarks_2
# 0                                                  None             None
# 1                                                  None             None
# 2     Se descarta muestra, porque a la hora del filt...             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1467                                               None             None
# 1468                                               None             None
# 1469                                               None             None
# 1470                                               None             None
# 1471                                               None             None
#
# [1472 rows x 37 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_3_gas_sorted_by_sql = subset_3_gas_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_3_gas_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_3_gas_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (1286, 37)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab         id tax_order    family         genus  \
# 0  3  Genetic bank  F24-3540  CIAT-1467   Fabales  Fabaceae  Stylosanthes
# 1  4  Genetic bank  F24-3540  CIAT-1467   Fabales  Fabaceae  Stylosanthes
# 2  5  Genetic bank  F24-3540  CIAT-1467   Fabales  Fabaceae  Stylosanthes
# 3  6  Genetic bank  F24-3541  CIAT-1475   Fabales  Fabaceae  Stylosanthes
# 4  7  Genetic bank  F24-3541  CIAT-1475   Fabales  Fabaceae  Stylosanthes
#
#   species             tax_name    functional_group  ...  \
# 0  hamata  Stylosanthes hamata  Herbaceous_legumes  ...
# 1  hamata  Stylosanthes hamata  Herbaceous_legumes  ...
# 2  hamata  Stylosanthes hamata  Herbaceous_legumes  ...
# 3  hamata  Stylosanthes hamata  Herbaceous_legumes  ...
# 4  hamata  Stylosanthes hamata  Herbaceous_legumes  ...
#
#   ch4_ml_g_dm_incubated_24h ch4_ml_g_ndf_digested_24h methane_intensity  \
# 0                      None                      None              None
# 1               31.07894731               235.4330642       50.84123828
# 2                      None                      None              None
# 3               32.51384553               239.5726225       51.71448076
# 4               31.18086905               256.0454461       56.40388724
#
#           tddm information_remarks_1 information_remarks_2  \
# 0         None                OT-033                  None
# 1  61.12940668                OT-033                  None
# 2         None                OT-033                  None
# 3  62.87183987                OT-033                  None
# 4  55.28141866                OT-033                  None
#
#                   gas_remarks_1  gas_remarks_2  \
# 0  Eliminado por digestibilidad           None
# 1                          None           None
# 2                          None  Eliminada Dig
# 3                          None           None
# 4                          None           None
#
#                                     digest_remarks_1 digest_remarks_2
# 0                                               None             None
# 1                                               None             None
# 2  Se descarta muestra, porque a la hora del filt...             None
# 3                                               None             None
# 4                                               None             None
#
# [5 rows x 37 columns]

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 3
subset_3_gas_sorted_by_sql.insert(0, 'subset', 3)

print("DataFrame with new 'subset' column:")
display(subset_3_gas_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab         id tax_order    family  \
# 0       3  3  Genetic bank  F24-3540  CIAT-1467   Fabales  Fabaceae
# 1       3  4  Genetic bank  F24-3540  CIAT-1467   Fabales  Fabaceae
# 2       3  5  Genetic bank  F24-3540  CIAT-1467   Fabales  Fabaceae
# 3       3  6  Genetic bank  F24-3541  CIAT-1475   Fabales  Fabaceae
# 4       3  7  Genetic bank  F24-3541  CIAT-1475   Fabales  Fabaceae
#
#           genus species             tax_name  ... ch4_ml_g_dm_incubated_24h  \
# 0  Stylosanthes  hamata  Stylosanthes hamata  ...                      None
# 1  Stylosanthes  hamata  Stylosanthes hamata  ...               31.07894731
# 2  Stylosanthes  hamata  Stylosanthes hamata  ...                      None
# 3  Stylosanthes  hamata  Stylosanthes hamata  ...               32.51384553
# 4  Stylosanthes  hamata  Stylosanthes hamata  ...               31.18086905
#
#   ch4_ml_g_ndf_digested_24h methane_intensity         tddm  \
# 0                      None              None         None
# 1               235.4330642       50.84123828  61.12940668
# 2                      None              None         None
# 3               239.5726225       51.71448076  62.87183987
# 4               256.0454461       56.40388724  55.28141866
#
#   information_remarks_1 information_remarks_2                 gas_remarks_1  \
# 0                OT-033                  None  Eliminado por digestibilidad
# 1                OT-033                  None                          None
# 2                OT-033                  None                          None
# 3                OT-033                  None                          None
# 4                OT-033                  None                          None
#
#    gas_remarks_2                                   digest_remarks_1  \
# 0           None                                               None
# 1           None                                               None
# 2  Eliminada Dig  Se descarta muestra, porque a la hora del filt...
# 3           None                                               None
# 4           None                                               None
#
#   digest_remarks_2
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
#
# [5 rows x 38 columns]

# %%
subset_3_gas_sorted_by_sql.to_csv('gas3.csv', index=None)

# %% [markdown]
# ### 3.3.2. Nutrition

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_3_information_samples.to_sql('subset_3_information_samples', conn_new, if_exists='replace', index=False)
subset_3_nutrition.to_sql('subset_3_nutrition', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_3_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner',
#        '10_requisitioner_2', '10_set_ciat', '10_ciat_lab_id',
#        '10_gene_bank_breeding_program_id', '10_genus', '10_species',
#        '10_tax_name', '10_family', '10_order', '10_functional_group',
#        '10_remarks_1', '10_id_lab', '10_remarks_2'],
#       dtype='object')

# %%
subset_3_nutrition.head()
# Out:
#   40n_no 40n_set_ciat 40n_sample_id 40n_gene_bank_breeding_program_id  \
# 1      1           23      F24-3540                         CIAT-1467
# 2      2           23      F24-3540                         CIAT-1467
# 3      3           23      F24-3541                         CIAT-1475
# 4      4           23      F24-3541                         CIAT-1475
# 5      5           23      F25-0954                        CIAT-23326
#
#       40n_genus 40n_species         40n_tax_name 40n_family 40n_order  \
# 1  Stylosanthes      hamata  Stylosanthes hamata   Fabaceae   Fabales
# 2  Stylosanthes      hamata  Stylosanthes hamata   Fabaceae   Fabales
# 3  Stylosanthes      hamata  Stylosanthes hamata   Fabaceae   Fabales
# 4  Stylosanthes      hamata  Stylosanthes hamata   Fabaceae   Fabales
# 5     Desmodium   velutinum  Desmodium velutinum   Fabaceae   Fabales
#
#   40n_functional_group  ... 40n_ash_dm 40n_av_ash_percentage  \
# 1           Herbaceous  ...       8.49                  8.54
# 2           Herbaceous  ...       8.59                   NaN
# 3           Herbaceous  ...        8.7                 8.755
# 4           Herbaceous  ...       8.81                   NaN
# 5                Shrub  ...      14.95                 15.05
#
#   40n_om_percentage 40n_om_percentage.1 40n_pc_percentage_dm  \
# 1             91.51               91.46                13.64
# 2             91.41                 NaN                13.64
# 3              91.3              91.245                17.29
# 4             91.19                 NaN                17.29
# 5             85.05               84.95                18.11
#
#   40n_av_pc_percentage 40n_adf_percentage_dm 40n_av_adf_percentage_dm  \
# 1                13.64                 35.11                   34.775
# 2                  NaN                 34.44                      NaN
# 3                17.29                 37.69                    37.43
# 4                  NaN                 37.17                      NaN
# 5                18.11                 23.08                       23
#
#   40n_ndf_percentage_dm 40n_av_ndf_percentage_dm
# 1           53.65239714              52.92729421
# 2           52.20219129                      NaN
# 3            58.2158637              56.45312509
# 4           54.69038649                      NaN
# 5                 40.57                       40
#
# [5 rows x 23 columns]

# %%
query_combined = """

SELECT
    s3n."40n_no" as no,
    s3i."10_requisitioner" as requisitioner,
    s3i."10_ciat_lab_id" as id_lab,
    s3i."10_gene_bank_breeding_program_id" as id,
    s3i."10_order" as tax_order,
    s3i."10_family" as family,
    s3i."10_genus" as genus,
    s3i."10_species" as species,
    s3i."10_tax_name" as tax_name,
    s3i."10_functional_group" as functional_group,
    s3i."10_set_ciat" as set_ciat,
    s3n."40n_dm_percentage" as dm_percentage,
    s3n."40n_ash_dm" as ash_dm,
    s3n."40n_om_percentage" as om_percentage,
    s3n."40n_pc_percentage_dm" as pc_percentage_dm,
    s3n."40n_adf_percentage_dm" as adf_percentage_dm,
    s3n."40n_ndf_percentage_dm" as ndf_percentage_dm



FROM
    subset_3_information_samples AS s3i
JOIN
    subset_3_nutrition AS s3n
ON
    s3i."10_ciat_lab_id" = s3n."40n_sample_id"
ORDER BY
    CAST(no AS INTEGER) ASC NULLS LAST
"""

subset_3_nutrition_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_3_nutrition_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#       no requisitioner    id_lab                                      id  \
# 0      1  Genetic bank  F24-3540                               CIAT-1467
# 1      2  Genetic bank  F24-3540                               CIAT-1467
# 2      3  Genetic bank  F24-3541                               CIAT-1475
# 3      4  Genetic bank  F24-3541                               CIAT-1475
# 4      5  Genetic bank  F25-0954                              CIAT-23326
# ..   ...           ...       ...                                     ...
# 319  264  Genetic bank  F24-3580                              CIAT-12710
# 320  265  Genetic bank  F24-3581                              CIAT-12758
# 321  266  Genetic bank  F24-3581                              CIAT-12758
# 322  267           LMF  F25-2134  Hohenheimer-Heustandard-IAG-2025/1-S-1
# 323  268           LMF  F25-2134  Hohenheimer-Heustandard-IAG-2025/1-S-1
#
#        tax_order        family         genus      species  \
# 0        Fabales      Fabaceae  Stylosanthes       hamata
# 1        Fabales      Fabaceae  Stylosanthes       hamata
# 2        Fabales      Fabaceae  Stylosanthes       hamata
# 3        Fabales      Fabaceae  Stylosanthes       hamata
# 4        Fabales      Fabaceae     Desmodium    velutinum
# ..           ...           ...           ...          ...
# 319      Fabales      Fabaceae  Stylosanthes       scabra
# 320      Fabales      Fabaceae  Stylosanthes   guianensis
# 321      Fabales      Fabaceae  Stylosanthes   guianensis
# 322  Green meal    Heustandard   Hohenheimer  Heustandard
# 323  Green meal    Heustandard   Hohenheimer  Heustandard
#
#                     tax_name    functional_group set_ciat dm_percentage  \
# 0        Stylosanthes hamata  Herbaceous_legumes       23          92.5
# 1        Stylosanthes hamata  Herbaceous_legumes       23         92.73
# 2        Stylosanthes hamata  Herbaceous_legumes       23         90.62
# 3        Stylosanthes hamata  Herbaceous_legumes       23         90.96
# 4        Desmodium velutinum         Shrub_Trees       23         95.77
# ..                       ...                 ...      ...           ...
# 319      Stylosanthes scabra  Herbaceous_legumes       26         91.77
# 320  Stylosanthes guianensis  Herbaceous_legumes       26         91.36
# 321  Stylosanthes guianensis  Herbaceous_legumes       26   91.39172166
# 322  Hohenheimer Heustandard                None       26   91.34432784
# 323  Hohenheimer Heustandard                None       26   91.32173565
#
#           ash_dm om_percentage pc_percentage_dm adf_percentage_dm  \
# 0           8.49         91.51            13.64             35.11
# 1           8.59         91.41            13.64             34.44
# 2            8.7          91.3            17.29             37.69
# 3           8.81         91.19            17.29             37.17
# 4          14.95         85.05            18.11             23.08
# ..           ...           ...              ...               ...
# 319   11.6653039    88.3346961      11.49501692       37.90430417
# 320  9.466395087   90.53360491      14.95347019       33.00440393
# 321  9.573918397    90.4260816      14.95347019       35.21337701
# 322  9.990152095    90.0098479                0                 0
# 323  10.12699803   89.87300197                0                 0
#
#     ndf_percentage_dm
# 0         53.65239714
# 1         52.20219129
# 2          58.2158637
# 3         54.69038649
# 4               40.57
# ..                ...
# 319        58.4861562
# 320       58.26469765
# 321       55.66886158
# 322                 0
# 323                 0
#
# [324 rows x 17 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_3_nutrition_sorted_by_sql = subset_3_nutrition_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_3_nutrition_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_3_nutrition_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (308, 17)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab          id tax_order    family         genus  \
# 0  1  Genetic bank  F24-3540   CIAT-1467   Fabales  Fabaceae  Stylosanthes
# 1  2  Genetic bank  F24-3540   CIAT-1467   Fabales  Fabaceae  Stylosanthes
# 2  3  Genetic bank  F24-3541   CIAT-1475   Fabales  Fabaceae  Stylosanthes
# 3  4  Genetic bank  F24-3541   CIAT-1475   Fabales  Fabaceae  Stylosanthes
# 4  5  Genetic bank  F25-0954  CIAT-23326   Fabales  Fabaceae     Desmodium
#
#      species             tax_name    functional_group set_ciat dm_percentage  \
# 0     hamata  Stylosanthes hamata  Herbaceous_legumes       23          92.5
# 1     hamata  Stylosanthes hamata  Herbaceous_legumes       23         92.73
# 2     hamata  Stylosanthes hamata  Herbaceous_legumes       23         90.62
# 3     hamata  Stylosanthes hamata  Herbaceous_legumes       23         90.96
# 4  velutinum  Desmodium velutinum         Shrub_Trees       23         95.77
#
#   ash_dm om_percentage pc_percentage_dm adf_percentage_dm ndf_percentage_dm
# 0   8.49         91.51            13.64             35.11       53.65239714
# 1   8.59         91.41            13.64             34.44       52.20219129
# 2    8.7          91.3            17.29             37.69        58.2158637
# 3   8.81         91.19            17.29             37.17       54.69038649
# 4  14.95         85.05            18.11             23.08             40.57

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 3
subset_3_nutrition_sorted_by_sql.insert(0, 'subset', 3)

print("DataFrame with new 'subset' column:")
display(subset_3_nutrition_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab          id tax_order    family  \
# 0       3  1  Genetic bank  F24-3540   CIAT-1467   Fabales  Fabaceae
# 1       3  2  Genetic bank  F24-3540   CIAT-1467   Fabales  Fabaceae
# 2       3  3  Genetic bank  F24-3541   CIAT-1475   Fabales  Fabaceae
# 3       3  4  Genetic bank  F24-3541   CIAT-1475   Fabales  Fabaceae
# 4       3  5  Genetic bank  F25-0954  CIAT-23326   Fabales  Fabaceae
#
#           genus    species             tax_name    functional_group set_ciat  \
# 0  Stylosanthes     hamata  Stylosanthes hamata  Herbaceous_legumes       23
# 1  Stylosanthes     hamata  Stylosanthes hamata  Herbaceous_legumes       23
# 2  Stylosanthes     hamata  Stylosanthes hamata  Herbaceous_legumes       23
# 3  Stylosanthes     hamata  Stylosanthes hamata  Herbaceous_legumes       23
# 4     Desmodium  velutinum  Desmodium velutinum         Shrub_Trees       23
#
#   dm_percentage ash_dm om_percentage pc_percentage_dm adf_percentage_dm  \
# 0          92.5   8.49         91.51            13.64             35.11
# 1         92.73   8.59         91.41            13.64             34.44
# 2         90.62    8.7          91.3            17.29             37.69
# 3         90.96   8.81         91.19            17.29             37.17
# 4         95.77  14.95         85.05            18.11             23.08
#
#   ndf_percentage_dm
# 0       53.65239714
# 1       52.20219129
# 2        58.2158637
# 3       54.69038649
# 4             40.57

# %% [markdown]
# # 4. Subset 4

# %% [markdown]
# ## 4.1. Loading data

# %%
# Load the CSVs from Drive into pandas DataFrames
subset_4_information_samples = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_4/csv/10_information_samples.csv')
subset_4_gas_prod = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_4/csv/31_gas_prod_vf.csv')
subset_4_nutrition = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_4/csv/40_result_q_raw_data.csv')
subset_4_digest = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_4/csv/32_digest.csv')

# %% [markdown]
# ## 4.2. Cleaning and formatting

# %%
subset_4_digest.head()
# Out:
#   32_no 32_date 32_date_2 32_requisitioner 32_gene_bank_id      32_genus  \
# 0    No    Date      Date    Requisitioner    Gene Bank ID         Genus
# 1     1   45630     46041                0      BLANK 24 H         BLANK
# 2     2   45630     46041                0      BLANK 24 H         BLANK
# 3     3   45630     46041          Genbank      CIAT-13262  Dendrolobium
# 4     4   45630     46041          Genbank      CIAT-13262  Dendrolobium
#
#     32_species               32_tax_name 32_family 32_order  ...  \
# 0      Species                  Tax Name    Family    Order  ...
# 1            0                BLANK 24 H         0        0  ...
# 2            0                BLANK 24 H         0        0  ...
# 3  triangulare  Dendrolobium triangulare  Fabaceae  Fabales  ...
# 4  triangulare  Dendrolobium triangulare  Fabaceae  Fabales  ...
#
#   32_digested_weight_g 32_remarks_1 32_undigested_dm_g 32_digested_feed_mg  \
# 0   Digested weight, g      Remarks   Undigested DM, g   Digested feed, mg
# 1                  NaN          NaN                NaN                 NaN
# 2                  NaN          NaN                NaN                 NaN
# 3               0.8995          NaN             0.3288         146.5259358
# 4               1.0675          NaN                NaN                 NaN
#
#   32_percentage_truly_digestibility 32_ndf_incubated_mg  \
# 0        % DMD, Truly digestibility   NDF incubated, mg
# 1                               NaN                 NaN
# 2                               NaN                 NaN
# 3                       30.82641294         287.1175836
# 4                               NaN                 NaN
#
#   32_ndf_digestibility_mg 32_percentage_digestibility_in_24h 32_asterisk  \
# 0   NDF digestibility, mg        % NDF digestibility in 24 h     Remarks
# 1                     NaN                                NaN         NaN
# 2                     NaN                                NaN         NaN
# 3            -41.68241641                       -14.51754222         NaN
# 4                     NaN                                NaN           *
#
#              32_remarks_2
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4  Eliminado Dig negativo
#
# [5 rows x 28 columns]

# %%
# Clean first row containing orignal column names from excel files
subset_4_information_samples = remove_first_row(subset_4_information_samples)
subset_4_gas_prod = remove_first_row(subset_4_gas_prod)
subset_4_nutrition = remove_first_row(subset_4_nutrition)
subset_4_digest = remove_first_row(subset_4_digest)

# Add '-' to lab ids and ensure correct format FXX-XXXX
subset_4_information_samples['10_ciat_lab_id'] = clean_lab_ids(subset_4_information_samples['10_ciat_lab_id'])
subset_4_gas_prod['31_ciat_id'] = clean_lab_ids(subset_4_gas_prod['31_ciat_id'])
subset_4_nutrition['40_ciat_lab_id'] = clean_lab_ids(subset_4_nutrition['40_ciat_lab_id'])
subset_4_digest['32_ciat_id'] = clean_lab_ids(subset_4_digest['32_ciat_id'])

# Clean and standardize gene bank and breeding program ids
subset_4_information_samples['10_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_4_information_samples['10_gene_bank_breeding_program_id'])
subset_4_gas_prod['31_gene_bank_id'] = clean_standardize_ids(subset_4_gas_prod['31_gene_bank_id'])
subset_4_nutrition['40_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_4_nutrition['40_gene_bank_breeding_program_id'])
subset_4_digest['32_gene_bank_id'] = clean_standardize_ids(subset_4_digest['32_gene_bank_id'])

# %%
subset_4_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner', '10_set_ciat',
#        '10_ciat_lab_id', '10_gene_bank_breeding_program_id', '10_genus',
#        '10_species', '10_tax_name', '10_family', '10_order',
#        '10_functional_group', '10_batches_ciat', '10_id_lab', '10_remarks_1',
#        '10_remarks_2'],
#       dtype='object')

# %%
# Check functional groups categories
subset_4_information_samples['10_functional_group'].unique()
# Out:
# array(['Tree', 'grasses', 'Arbustiva ', 'Herbaceous', 'Shurb_Tree',
#        'Shrub'], dtype=object)

# %%
# Apply the mapping to centers datt
subset_4_information_samples['10_functional_group'] = subset_4_information_samples['10_functional_group'].replace(functional_group_mapping)

print('Updated functional group counts for subset_4_information_samples:')
display(subset_4_information_samples['10_functional_group'].value_counts())
# Out:
# Updated functional group counts for subset_4_information_samples:
# 10_functional_group
# Shrub_Trees           67
# Herbaceous_legumes    63
# Grass                 18
# Name: count, dtype: int64

# %% [markdown]
# ## 4.3. SQL query and dataframe creation

# %% [markdown]
# ### 4.3.1. Gas

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_4_information_samples.to_sql('subset_4_information_samples', conn_new, if_exists='replace', index=False)
subset_4_gas_prod.to_sql('subset_4_gas_prod', conn_new, if_exists='replace', index=False)
subset_4_digest.to_sql('subset_4_digest', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_4_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner', '10_set_ciat',
#        '10_ciat_lab_id', '10_gene_bank_breeding_program_id', '10_genus',
#        '10_species', '10_tax_name', '10_family', '10_order',
#        '10_functional_group', '10_batches_ciat', '10_id_lab', '10_remarks_1',
#        '10_remarks_2'],
#       dtype='object')

# %%
subset_4_gas_prod.columns
# Out:
# Index(['31_no', '31_date', '31_requisitioner', '31_gene_bank_id', '31_genus',
#        '31_species', '31_tax_name', '31_family', '31_order',
#        '31_functional_group', '31_ciat_id', '31_set_ciat', '31_batch',
#        '31_run', '31_replication', '31_syrange_no', '31_sample_weight_g',
#        '31_dm_incubated_mg', '31_digested_feed_mg', '31_time_0h',
#        '31_gas_0h_ml', '31_time_8h', '31_gas_8h_ml', '31_ch4_8h_percentage',
#        '31_v8_push_back_ml', '31_time_24h', '31_gas_24h_ml',
#        '31_ch4_24h_percentage', '31_remarks_1', '31_gp_8h_ml',
#        '31_gp_8_24h_ml', '31_net_gas_8h_ml', '31_net_gas_8_24h_ml',
#        '31_net_gas_24h_ml', '31_ch4_8h_ml', '31_ch4_8_24h_ml', '31_ch4_24h_ml',
#        '31_gas_ml_g_dm_incubated_24h', '31_percentage_dmd_truly_digestibility',
#        '31_part_fact', '31_ch4_ml_in_gas_8h', '31_ch4_ml_gas_24h',
#        '31_ch4_ml_g_dm_incubated_24h', '31_ch4_ml_g_dmd_24h2',
#        '31_ch4_ml_g_ndf_digested_in_24h', '31_ch4_g_g_dm_incubated_24h',
#        '31_ch4_g_g_dmd_24h', '31_remarks_2'],
#       dtype='object')

# %%
subset_4_digest.columns
# Out:
# Index(['32_no', '32_date', '32_date_2', '32_requisitioner', '32_gene_bank_id',
#        '32_genus', '32_species', '32_tax_name', '32_family', '32_order',
#        '32_functional_group', '32_ciat_id', '32_set_ciat', '32_batch',
#        '32_run', '32_replication', '32_syrange_no', '32_bag_weight_g',
#        '32_digested_weight_g', '32_remarks_1', '32_undigested_dm_g',
#        '32_digested_feed_mg', '32_percentage_truly_digestibility',
#        '32_ndf_incubated_mg', '32_ndf_digestibility_mg',
#        '32_percentage_digestibility_in_24h', '32_asterisk', '32_remarks_2'],
#       dtype='object')

# %%
# Note: For this subset the columns names '31_ch4_ml_in_gas_8h', '31_ch4_ml_gas_24h' are incorrect, since they refer to percentages in gas!!!!
query_combined = """
SELECT
    s4g."31_no" as no,
    s4i."10_requisitioner" as requisitioner,
    s4i."10_ciat_lab_id" as id_lab,
    s4i."10_gene_bank_breeding_program_id" as id,
    s4i."10_order" as tax_order,
    s4i."10_family" as family,
    s4i."10_genus" as genus,
    s4i."10_species" as species,
    s4i."10_tax_name" as tax_name,
    s4i."10_functional_group" as functional_group,

    s4g."31_set_ciat" as set_ciat,
    s4g."31_batch" as batch,
    s4g."31_run" as run,
    s4g."31_replication" as replication,
    s4g."31_syrange_no" as syrange,

    s4g."31_sample_weight_g" as sample_weight_g,
    s4d."32_undigested_dm_g" as undigested_dm_g,
    s4g."31_dm_incubated_mg" as dm_incubated,
    s4g."31_digested_feed_mg" as digested_feed_mg,

    s4g."31_net_gas_8h_ml" as net_gas_8h_ml,
    s4g."31_net_gas_24h_ml" as net_gas_24h_ml,
    s4g."31_ch4_8h_ml" as ch4_8h_ml,
    s4g."31_ch4_24h_ml" as ch4_24h_ml,
    s4g."31_ch4_ml_in_gas_8h" as ch4_percentage_in_gas_8h,
    s4g."31_ch4_ml_gas_24h" as ch4_percentage_in_gas_24h,

    s4g."31_gas_ml_g_dm_incubated_24h" as gas_ml_g_dm_incubated_24h,
    s4g."31_part_fact" as part_fact,

    s4g."31_ch4_ml_g_dm_incubated_24h" as ch4_ml_g_dm_incubated_24h,
    s4g."31_ch4_ml_g_ndf_digested_in_24h" as ch4_ml_g_ndf_digested_24h,
    s4g."31_ch4_ml_g_dmd_24h2" as methane_intensity,
    s4g."31_percentage_dmd_truly_digestibility" as tddm,


    s4i."10_remarks_1" as information_remarks_1,
    s4i."10_remarks_2" as information_remarks_2,
    s4g."31_remarks_1" as gas_remarks_1,
    s4g."31_remarks_2" as gas_remarks_2,
    s4d."32_remarks_1" as digest_remarks_1,
    s4d."32_remarks_2" as digest_remarks_2

FROM subset_4_information_samples AS s4i
JOIN subset_4_gas_prod AS s4g
ON s4i."10_ciat_lab_id" = s4g."31_ciat_id"

LEFT JOIN subset_4_digest AS s4d
ON s4g."31_ciat_id" = s4d."32_ciat_id"
AND s4g."31_no" = s4d."32_no"
AND s4g."31_replication" = s4d."32_replication"
AND s4g."31_syrange_no" = s4d."32_syrange_no"

ORDER BY
    CAST(no AS INTEGER) ASC
"""

subset_4_gas_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_4_gas_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#         no                     requisitioner    id_lab          id tax_order  \
# 0        3                           Genbank  F25-1728  CIAT-13262   Fabales
# 1        4                           Genbank  F25-1728  CIAT-13262   Fabales
# 2        5                           Genbank  F25-1728  CIAT-13262   Fabales
# 3        6                           Genbank  F25-1729  CIAT-13528   Fabales
# 4        7                           Genbank  F25-1729  CIAT-13528   Fabales
# ...    ...                               ...       ...         ...       ...
# 1283  1218   Jacobo Arango/Alejandro Montoya  F25-0008    Sample-8    Poales
# 1284  1218   Jacobo Arango/Alejandro Montoya  F25-0008    Sample-8    Poales
# 1285  1218  Jacobo Arango/ Alejandro Montoya  F25-0008    Sample-8    Poales
# 1286  1218  Jacobo Arango/ Alejandro Montoya  F25-0008    Sample-8    Poales
# 1287  1218  Jacobo Arango/ Alejandro Montoya  F25-0008    Sample-8    Poales
#
#         family         genus        species                  tax_name  \
# 0     Fabaceae  Dendrolobium    triangulare  Dendrolobium triangulare
# 1     Fabaceae  Dendrolobium    triangulare  Dendrolobium triangulare
# 2     Fabaceae  Dendrolobium    triangulare  Dendrolobium triangulare
# 3     Fabaceae  Dendrolobium    lanceolatum  Dendrolobium lanceolatum
# 4     Fabaceae  Dendrolobium    lanceolatum  Dendrolobium lanceolatum
# ...        ...           ...            ...                       ...
# 1283   Poaceae       Cynodon   nlemfuensis       Cynodon nlemfuensis
# 1284   Poaceae       Cynodon   nlemfuensis       Cynodon nlemfuensis
# 1285   Poaceae       Cynodon   nlemfuensis       Cynodon nlemfuensis
# 1286   Poaceae       Cynodon   nlemfuensis       Cynodon nlemfuensis
# 1287   Poaceae       Cynodon   nlemfuensis       Cynodon nlemfuensis
#
#      functional_group  ... ch4_ml_g_dm_incubated_24h  \
# 0         Shrub_Trees  ...               14.60522081
# 1         Shrub_Trees  ...                      None
# 2         Shrub_Trees  ...                15.9267685
# 3         Shrub_Trees  ...               11.39377265
# 4         Shrub_Trees  ...               11.12865003
# ...               ...  ...                       ...
# 1283            Grass  ...               24.06079675
# 1284            Grass  ...               24.06079675
# 1285            Grass  ...               24.06079675
# 1286            Grass  ...               24.06079675
# 1287            Grass  ...               24.06079675
#
#      ch4_ml_g_ndf_digested_24h methane_intensity         tddm  \
# 0                 -0.478196663       47.37891768  30.82641294
# 1                         None              None         None
# 2                 -0.301241039       65.21577414   24.4216506
# 3                 -0.129878029       58.70892202   19.4072251
# 4                 -0.159296905       45.95279388  24.21757002
# ...                        ...               ...          ...
# 1283                0.93285091       72.69629761  33.09769209
# 1284                0.93285091       72.69629761  33.09769209
# 1285                0.93285091       72.69629761  33.09769209
# 1286                0.93285091       72.69629761  33.09769209
# 1287                0.93285091       72.69629761  33.09769209
#
#      information_remarks_1 information_remarks_2 gas_remarks_1  gas_remarks_2  \
# 0                     None                  None          None           None
# 1                     None                  None          None  Elimn Dig neg
# 2                     None                  None          None           None
# 3                     None                  None          None           None
# 4                     None                  None          None           None
# ...                    ...                   ...           ...            ...
# 1283                  None                  None          None           None
# 1284                  None                  None          None           None
# 1285                  None                  None          None           None
# 1286                  None                  None          None           None
# 1287                  None                  None          None           None
#
#      digest_remarks_1        digest_remarks_2
# 0                None                    None
# 1                None  Eliminado Dig negativo
# 2                None  Eliminado Dig negativo
# 3                None                    None
# 4                None                    None
# ...               ...                     ...
# 1283             None                    None
# 1284             None                    None
# 1285             None                    None
# 1286             None                    None
# 1287             None                    None
#
# [1288 rows x 37 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_4_gas_sorted_by_sql = subset_4_gas_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_4_gas_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_4_gas_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (1183, 37)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab          id tax_order    family         genus  \
# 0  3       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae  Dendrolobium
# 1  4       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae  Dendrolobium
# 2  5       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae  Dendrolobium
# 3  6       Genbank  F25-1729  CIAT-13528   Fabales  Fabaceae  Dendrolobium
# 4  7       Genbank  F25-1729  CIAT-13528   Fabales  Fabaceae  Dendrolobium
#
#        species                  tax_name functional_group  ...  \
# 0  triangulare  Dendrolobium triangulare      Shrub_Trees  ...
# 1  triangulare  Dendrolobium triangulare      Shrub_Trees  ...
# 2  triangulare  Dendrolobium triangulare      Shrub_Trees  ...
# 3  lanceolatum  Dendrolobium lanceolatum      Shrub_Trees  ...
# 4  lanceolatum  Dendrolobium lanceolatum      Shrub_Trees  ...
#
#   ch4_ml_g_dm_incubated_24h ch4_ml_g_ndf_digested_24h methane_intensity  \
# 0               14.60522081              -0.478196663       47.37891768
# 1                      None                      None              None
# 2                15.9267685              -0.301241039       65.21577414
# 3               11.39377265              -0.129878029       58.70892202
# 4               11.12865003              -0.159296905       45.95279388
#
#           tddm information_remarks_1 information_remarks_2 gas_remarks_1  \
# 0  30.82641294                  None                  None          None
# 1         None                  None                  None          None
# 2   24.4216506                  None                  None          None
# 3   19.4072251                  None                  None          None
# 4  24.21757002                  None                  None          None
#
#    gas_remarks_2 digest_remarks_1        digest_remarks_2
# 0           None             None                    None
# 1  Elimn Dig neg             None  Eliminado Dig negativo
# 2           None             None  Eliminado Dig negativo
# 3           None             None                    None
# 4           None             None                    None
#
# [5 rows x 37 columns]

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 4
subset_4_gas_sorted_by_sql.insert(0, 'subset', 4)

print("DataFrame with new 'subset' column:")
display(subset_4_gas_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab          id tax_order    family  \
# 0       4  3       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae
# 1       4  4       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae
# 2       4  5       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae
# 3       4  6       Genbank  F25-1729  CIAT-13528   Fabales  Fabaceae
# 4       4  7       Genbank  F25-1729  CIAT-13528   Fabales  Fabaceae
#
#           genus      species                  tax_name  ...  \
# 0  Dendrolobium  triangulare  Dendrolobium triangulare  ...
# 1  Dendrolobium  triangulare  Dendrolobium triangulare  ...
# 2  Dendrolobium  triangulare  Dendrolobium triangulare  ...
# 3  Dendrolobium  lanceolatum  Dendrolobium lanceolatum  ...
# 4  Dendrolobium  lanceolatum  Dendrolobium lanceolatum  ...
#
#   ch4_ml_g_dm_incubated_24h ch4_ml_g_ndf_digested_24h methane_intensity  \
# 0               14.60522081              -0.478196663       47.37891768
# 1                      None                      None              None
# 2                15.9267685              -0.301241039       65.21577414
# 3               11.39377265              -0.129878029       58.70892202
# 4               11.12865003              -0.159296905       45.95279388
#
#           tddm information_remarks_1 information_remarks_2 gas_remarks_1  \
# 0  30.82641294                  None                  None          None
# 1         None                  None                  None          None
# 2   24.4216506                  None                  None          None
# 3   19.4072251                  None                  None          None
# 4  24.21757002                  None                  None          None
#
#    gas_remarks_2 digest_remarks_1        digest_remarks_2
# 0           None             None                    None
# 1  Elimn Dig neg             None  Eliminado Dig negativo
# 2           None             None  Eliminado Dig negativo
# 3           None             None                    None
# 4           None             None                    None
#
# [5 rows x 38 columns]

# %%
subset_4_gas_sorted_by_sql.to_csv('gas4.csv', index=None)

# %% [markdown]
# ### 4.3.2. Nutrition

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_4_information_samples.to_sql('subset_4_information_samples', conn_new, if_exists='replace', index=False)
subset_4_nutrition.to_sql('subset_4_nutrition', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_4_information_samples.head()
# Out:
#   10_sample_serial_no 10_date 10_requisitioner 10_set_ciat 10_ciat_lab_id  \
# 1                   1   46041          Genbank          27       F25-1728
# 2                   2   46041          Genbank          27       F25-1729
# 3                   3   46041          Genbank          27       F25-1730
# 4                   4   46041          Genbank          27       F25-1731
# 5                   5   46041          Genbank          27       F25-1732
#
#   10_gene_bank_breeding_program_id      10_genus   10_species  \
# 1                       CIAT-13262  Dendrolobium  triangulare
# 2                       CIAT-13528  Dendrolobium  lanceolatum
# 3                       CIAT-13529  Dendrolobium  triangulare
# 4                       CIAT-13710  Dendrolobium  lanceolatum
# 5                       CIAT-22004  Dendrolobium  triangulare
#
#                 10_tax_name 10_family 10_order 10_functional_group  \
# 1  Dendrolobium triangulare  Fabaceae  Fabales         Shrub_Trees
# 2  Dendrolobium lanceolatum  Fabaceae  Fabales         Shrub_Trees
# 3  Dendrolobium triangulare  Fabaceae  Fabales         Shrub_Trees
# 4  Dendrolobium lanceolatum  Fabaceae  Fabales         Shrub_Trees
# 5  Dendrolobium triangulare  Fabaceae  Fabales         Shrub_Trees
#
#   10_batches_ciat      10_id_lab 10_remarks_1 10_remarks_2
# 1       58,59, 69  OT-010 (2025)          NaN          NaN
# 2       58,59, 69  OT-010 (2025)          NaN          NaN
# 3       58,59, 69  OT-010 (2025)          NaN          NaN
# 4       58,59, 69  OT-010 (2025)          NaN          NaN
# 5       58,59, 69  OT-010 (2025)          NaN          NaN

# %%
subset_4_nutrition.head()
# Out:
#   40_sample_serial_no 40_date 40_requisitioner 40_set_ciat 40_ciat_lab_id  \
# 1                   1   46041          Genbank          27       F25-1728
# 2                   2   46041          Genbank          27       F25-1728
# 3                   3   46041          Genbank          27       F25-1729
# 4                   4   46041          Genbank          27       F25-1729
# 5                   5   46041          Genbank          27       F25-1730
#
#   40_gene_bank_breeding_program_id      40_genus   40_species  \
# 1                       CIAT-13262  Dendrolobium  triangulare
# 2                       CIAT-13262  Dendrolobium  triangulare
# 3                       CIAT-13528  Dendrolobium  lanceolatum
# 4                       CIAT-13528  Dendrolobium  lanceolatum
# 5                       CIAT-13529  Dendrolobium  triangulare
#
#                 40_tax_name 40_family  ...    40_ash_dm 40_av_ash_percentage  \
# 1  Dendrolobium triangulare  Fabaceae  ...  8.675533642          8.697026471
# 2  Dendrolobium triangulare  Fabaceae  ...    8.7185193                  NaN
# 3  Dendrolobium lanceolatum  Fabaceae  ...  7.585062735          7.584683557
# 4  Dendrolobium lanceolatum  Fabaceae  ...   7.58430438                  NaN
# 5  Dendrolobium triangulare  Fabaceae  ...  6.715805626          6.690322969
#
#   40_om_percentage 40_av_om_percentage 40_pc_percentage_dm  \
# 1      91.32446636         91.30297353         18.98095108
# 2       91.2814807                 NaN         18.98095108
# 3      92.41493727         92.41531644         16.89700161
# 4      92.41569562                 NaN         16.89700161
# 5      93.28419437         93.30967703         18.17097604
#
#   40_av_pc_percentage 40_adf_percentage_dm 40_av_adf_percentage_dm  \
# 1         18.98095108          47.87499326             47.52317706
# 2                 NaN          47.17136086                     NaN
# 3         16.89700161          48.31275422             48.36218724
# 4                 NaN          48.41162026                     NaN
# 5         18.17097604          44.49306584             45.32812119
#
#   40_ndf_percentage_dm 40_av_ndf_percentage_dm
# 1          61.50467768             60.40435877
# 2          59.30403987                     NaN
# 3          57.21705512             56.87954787
# 4          56.54204062                     NaN
# 5          61.91582388             59.94398484
#
# [5 rows x 24 columns]

# %%
query_combined = """
SELECT
    s4n."40_sample_serial_no" as no,
    s4i."10_requisitioner" as requisitioner,
    s4i."10_ciat_lab_id" as id_lab,
    s4i."10_gene_bank_breeding_program_id" as id,
    s4i."10_order" as tax_order,
    s4i."10_family" as family,
    s4i."10_genus" as genus,
    s4i."10_species" as species,
    s4i."10_tax_name" as tax_name,
    s4i."10_functional_group" as functional_group,
    s4i."10_set_ciat" as set_ciat,
    s4n."40_dm_percentage" as dm_percentage,
    s4n."40_ash_dm" as ash_dm,
    s4n."40_om_percentage" as om_percentage,
    s4n."40_pc_percentage_dm" as pc_percentage_dm,
    s4n."40_adf_percentage_dm" as adf_percentage_dm,
    s4n."40_ndf_percentage_dm" as ndf_percentage_dm



FROM
    subset_4_information_samples AS s4i
JOIN
    subset_4_nutrition AS s4n
ON
    s4i."10_ciat_lab_id" = s4n."40_ciat_lab_id"
ORDER BY
    CAST(no AS INTEGER) ASC NULLS LAST
"""

subset_4_nutrition_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_4_nutrition_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#        no                     requisitioner    id_lab               id  \
# 0       1                           Genbank  F25-1728       CIAT-13262
# 1       2                           Genbank  F25-1728       CIAT-13262
# 2       3                           Genbank  F25-1729       CIAT-13528
# 3       4                           Genbank  F25-1729       CIAT-13528
# 4       5                           Genbank  F25-1730       CIAT-13529
# ..    ...                               ...       ...              ...
# 331  None                          Breeding  F25-2104  CIAT-BR-06-1348
# 332  None                          Breeding  F25-2166  CIAT-BH-22-0528
# 333  None                          Breeding  F25-2166  CIAT-BH-22-0528
# 334  None  Jacobo Arango/ Alejandro Montoya  F25-0008         Sample-8
# 335  None  Jacobo Arango/ Alejandro Montoya  F25-0008         Sample-8
#
#     tax_order    family         genus          species  \
# 0     Fabales  Fabaceae  Dendrolobium      triangulare
# 1     Fabales  Fabaceae  Dendrolobium      triangulare
# 2     Fabales  Fabaceae  Dendrolobium      lanceolatum
# 3     Fabales  Fabaceae  Dendrolobium      lanceolatum
# 4     Fabales  Fabaceae  Dendrolobium      triangulare
# ..        ...       ...           ...              ...
# 331    Poales   Poaceae      Urochloa  interespecifico
# 332    Poales   Poaceae      Urochloa       humidicola
# 333    Poales   Poaceae      Urochloa       humidicola
# 334    Poales   Poaceae       Cynodon     nlemfuensis
# 335    Poales   Poaceae       Cynodon     nlemfuensis
#
#                        tax_name functional_group set_ciat dm_percentage  \
# 0      Dendrolobium triangulare      Shrub_Trees       27   94.90254873
# 1      Dendrolobium triangulare      Shrub_Trees       27   94.96201519
# 2      Dendrolobium lanceolatum      Shrub_Trees       27   95.00049995
# 3      Dendrolobium lanceolatum      Shrub_Trees       27    95.0909818
# 4      Dendrolobium triangulare      Shrub_Trees       27   94.30284858
# ..                          ...              ...      ...           ...
# 331  Brachiaria interespecifico            Grass       30         93.16
# 332         Urochloa humidicola            Grass       30          98.2
# 333         Urochloa humidicola            Grass       30         98.22
# 334        Cynodon nlemfuensis             Grass       30          93.6
# 335        Cynodon nlemfuensis             Grass       30          93.8
#
#           ash_dm om_percentage pc_percentage_dm adf_percentage_dm  \
# 0    8.675533642   91.32446636      18.98095108       47.87499326
# 1      8.7185193    91.2814807      18.98095108       47.17136086
# 2    7.585062735   92.41493727      16.89700161       48.31275422
# 3     7.58430438   92.41569562      16.89700161       48.41162026
# 4    6.715805626   93.28419437      18.17097604       44.49306584
# ..           ...           ...              ...               ...
# 331        14.68         85.32            12.18             25.85
# 332        12.48         87.52              8.8             36.63
# 333        15.08         84.92             8.73             36.96
# 334         11.3          88.7             13.1              37.8
# 335         11.5          88.5             13.1              37.8
#
#     ndf_percentage_dm
# 0         61.50467768
# 1         59.30403987
# 2         57.21705512
# 3         56.54204062
# 4         61.91582388
# ..                ...
# 331             60.28
# 332             73.37
# 333             73.74
# 334              76.1
# 335              76.1
#
# [336 rows x 17 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_4_nutrition_sorted_by_sql = subset_4_nutrition_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_4_nutrition_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_4_nutrition_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (336, 17)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab          id tax_order    family         genus  \
# 0  1       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae  Dendrolobium
# 1  2       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae  Dendrolobium
# 2  3       Genbank  F25-1729  CIAT-13528   Fabales  Fabaceae  Dendrolobium
# 3  4       Genbank  F25-1729  CIAT-13528   Fabales  Fabaceae  Dendrolobium
# 4  5       Genbank  F25-1730  CIAT-13529   Fabales  Fabaceae  Dendrolobium
#
#        species                  tax_name functional_group set_ciat  \
# 0  triangulare  Dendrolobium triangulare      Shrub_Trees       27
# 1  triangulare  Dendrolobium triangulare      Shrub_Trees       27
# 2  lanceolatum  Dendrolobium lanceolatum      Shrub_Trees       27
# 3  lanceolatum  Dendrolobium lanceolatum      Shrub_Trees       27
# 4  triangulare  Dendrolobium triangulare      Shrub_Trees       27
#
#   dm_percentage       ash_dm om_percentage pc_percentage_dm adf_percentage_dm  \
# 0   94.90254873  8.675533642   91.32446636      18.98095108       47.87499326
# 1   94.96201519    8.7185193    91.2814807      18.98095108       47.17136086
# 2   95.00049995  7.585062735   92.41493727      16.89700161       48.31275422
# 3    95.0909818   7.58430438   92.41569562      16.89700161       48.41162026
# 4   94.30284858  6.715805626   93.28419437      18.17097604       44.49306584
#
#   ndf_percentage_dm
# 0       61.50467768
# 1       59.30403987
# 2       57.21705512
# 3       56.54204062
# 4       61.91582388

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 4
subset_4_nutrition_sorted_by_sql.insert(0, 'subset', 4)

print("DataFrame with new 'subset' column:")
display(subset_4_nutrition_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab          id tax_order    family  \
# 0       4  1       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae
# 1       4  2       Genbank  F25-1728  CIAT-13262   Fabales  Fabaceae
# 2       4  3       Genbank  F25-1729  CIAT-13528   Fabales  Fabaceae
# 3       4  4       Genbank  F25-1729  CIAT-13528   Fabales  Fabaceae
# 4       4  5       Genbank  F25-1730  CIAT-13529   Fabales  Fabaceae
#
#           genus      species                  tax_name functional_group  \
# 0  Dendrolobium  triangulare  Dendrolobium triangulare      Shrub_Trees
# 1  Dendrolobium  triangulare  Dendrolobium triangulare      Shrub_Trees
# 2  Dendrolobium  lanceolatum  Dendrolobium lanceolatum      Shrub_Trees
# 3  Dendrolobium  lanceolatum  Dendrolobium lanceolatum      Shrub_Trees
# 4  Dendrolobium  triangulare  Dendrolobium triangulare      Shrub_Trees
#
#   set_ciat dm_percentage       ash_dm om_percentage pc_percentage_dm  \
# 0       27   94.90254873  8.675533642   91.32446636      18.98095108
# 1       27   94.96201519    8.7185193    91.2814807      18.98095108
# 2       27   95.00049995  7.585062735   92.41493727      16.89700161
# 3       27    95.0909818   7.58430438   92.41569562      16.89700161
# 4       27   94.30284858  6.715805626   93.28419437      18.17097604
#
#   adf_percentage_dm ndf_percentage_dm
# 0       47.87499326       61.50467768
# 1       47.17136086       59.30403987
# 2       48.31275422       57.21705512
# 3       48.41162026       56.54204062
# 4       44.49306584       61.91582388

# %% [markdown]
# # Subset 5

# %% [markdown]
# ## 5.1 Loading data

# %%
# Load the CSVs from Drive into pandas DataFrames
subset_5_information_samples = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_5/csv/10_information_samples.csv')
subset_5_gas_prod = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_5/csv/31b_gas_prod_vf.csv')
subset_5_nutrition = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_5/csv/40_result_q_raw_data.csv')
subset_5_digest = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_5/csv/32_digest.csv')

# %% [markdown]
# ## 5.2 Cleaning and formating

# %%
subset_5_information_samples.iloc[0:5,0:15]
# Out:
#   10_sample_serial_no       10_date 10_requisitioner_1 10_requisitioner_2  \
# 0    Sample serial No  Date (M,D.Y)      Requisitioner      Requisitioner
# 1                   1         46090           Genebank                NaN
# 2                   2         46090           Genebank                NaN
# 3                   3         46090           Genebank                NaN
# 4                   4         46090           Genebank                NaN
#
#   10_set_ciat 10_ciat_lab_id 10_gene_bank_breeding_program_id     10_genus  \
# 0    Set CIAT    CIAT Lab-ID   Gene bank /Breeding program ID        Genus
# 1          32        F260043                        CIAT43427    Desmodium
# 2          32        F260044                          CIAT601  Hyparrhenia
# 3          32        F260045                          CIAT606   Brachiaria
# 4          32        F260046                         CIAT6038      Sorghum
#
#      10_species             10_tax_name 10_family 10_order  \
# 0       Species                Tax Name    Family    Order
# 1  nicaraguense  Desmodium nicaraguense  Fabaceae  Fabales
# 2          rufa        Hyparrhenia rufa   Poaceae   Poales
# 3     decumbens    Brachiaria decumbens   Poaceae   Poales
# 4         almum           Sorghum almum   Poaceae   Poales
#
#   10_functional_group 10_batches_ciat      10_id_lab
# 0    Functional Group   Batches  CIAT         ID LAB
# 1          Shurb_Tree      72. 73, 74  OT-002 (2026)
# 2             Grasses      72. 73, 74  OT-002 (2026)
# 3             Grasses      72. 73, 74  OT-002 (2026)
# 4             Grasses      72. 73, 74  OT-002 (2026)

# %%
# Clean first row containing orignal column names from excel files
subset_5_information_samples = remove_first_row(subset_5_information_samples)
subset_5_gas_prod = remove_first_row(subset_5_gas_prod)
subset_5_nutrition = remove_first_row(subset_5_nutrition)
subset_5_digest = remove_first_row(subset_5_digest)

# Add '-' to lab ids and ensure correct format FXX-XXXX
subset_5_information_samples['10_ciat_lab_id'] = clean_lab_ids(subset_5_information_samples['10_ciat_lab_id'])
subset_5_gas_prod['31b_ciat_id'] = clean_lab_ids(subset_5_gas_prod['31b_ciat_id'])
subset_5_nutrition['40_ciat_lab_id'] = clean_lab_ids(subset_5_nutrition['40_ciat_lab_id'])
subset_5_digest['32_ciat_id'] = clean_lab_ids(subset_5_digest['32_ciat_id'])

# Clean and standardize gene bank and breeding program ids
subset_5_information_samples['10_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_5_information_samples['10_gene_bank_breeding_program_id'])
subset_5_gas_prod['31b_gene_bank_id'] = clean_standardize_ids(subset_5_gas_prod['31b_gene_bank_id'])
subset_5_nutrition['40_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_5_nutrition['40_gene_bank_breeding_program_id'])
subset_5_digest['32_gene_bank_id'] = clean_standardize_ids(subset_5_digest['32_gene_bank_id'])

# %%
subset_5_information_samples['10_functional_group'] = subset_5_information_samples['10_functional_group'].replace(functional_group_mapping)
print('Updated functional group counts for subset_5_information_samples:')
display(subset_5_information_samples['10_functional_group'].value_counts())
# Out:
# Updated functional group counts for subset_5_information_samples:
# 10_functional_group
# Herbaceous_legumes    170
# Grass                 125
# Shrub_Trees            20
# Fabales                 1
# Name: count, dtype: int64

# %% [markdown]
# ## 5.3 SQL query and dataframe creation

# %% [markdown]
# ### 5.3.1 Gas

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_5_information_samples.to_sql('subset_5_information_samples', conn_new, if_exists='replace', index=False)
subset_5_gas_prod.to_sql('subset_5_gas_prod', conn_new, if_exists='replace', index=False)
subset_5_digest.to_sql('subset_5_digest', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_5_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner_1',
#        '10_requisitioner_2', '10_set_ciat', '10_ciat_lab_id',
#        '10_gene_bank_breeding_program_id', '10_genus', '10_species',
#        '10_tax_name', '10_family', '10_order', '10_functional_group',
#        '10_batches_ciat', '10_id_lab', '10_remarks_1', '10_remarks_2'],
#       dtype='object')

# %%
subset_5_digest.columns
# Out:
# Index(['32_no', '32_date_1', '32_date_2', '32_requisitioner',
#        '32_gene_bank_id', '32_genus', '32_species', '32_tax_name', '32_family',
#        '32_order', '32_functional_group', '32_ciat_id', '32_set_ciat',
#        '32_batch', '32_run', '32_replication', '32_syrange_no',
#        '32_bag_weight_g', '32_digested_weight_g', '32_remarks_1',
#        '32_undigested_dm_g', '32_digested_feed_mg',
#        '32_percentage_dmd_truly_digestibility', '32_ndf_incubated_mg',
#        '32_ndf_digestibility_mg', '32_percentage_ndf_digestibility_in_24h',
#        '32_remarks_2'],
#       dtype='object')

# %%
subset_5_gas_prod.columns
# Out:
# Index(['31b_no', '31b_date', '31b_requisitioner', '31b_gene_bank_id',
#        '31b_genus', '31b_species', '31b_tax_anme', '31b_family', '31b_order',
#        '31b_functional_group', '31b_ciat_id', '31b_set_ciat', '31b_batch',
#        '31b_run', '31b_replication', '31b_syrange_no', '31b_sample_weight_g',
#        '31b_dm_incubated_mg', '31b_digested_feed_mg', '31b_time0h',
#        '31b_gas_0h_ml', '31b_time_8h', '31b_gas_8h_ml',
#        '31b_ch4_8h_percentage', '31b_v8_push_back_ml', '31b_time_24h',
#        '31b_gas_24h_ml', '31b_ch4_24h_percentage', '31b_remarks_1',
#        '31b_gp_8h_ml', '31b_gp_8_24h_ml', '31b_net_gas_8h_ml',
#        '31b_net_gas_8_24h_ml', '31b_net_gas_24h_ml', '31b_ch4_8h_ml',
#        '31b_ch4_8_24h_ml', '31b_ch4_24h_ml',
#        '31b_gas_ml_g_dm_incubated_24h_24h',
#        '31b_percentage_dmd_truly_digestibility', '31b_part_fact',
#        '31b_ch4_ml_in_gas_8h', '31b_ch4_ml_in_gas_24h',
#        '31b_ch4_ml_g_dm_incubated_24h', '31b_ch4_ml_g_dmd_24h',
#        '31b_ch4_ml_g_ndf_digested_in_24h', '31b_ch4_g_g_dm_incubated_24h',
#        '31b_ch4_g_g_dmd_24h', '31b_remarks_2'],
#       dtype='object')

# %%
# Note: For this subset the columns names '31_ch4_ml_in_gas_8h', '31_ch4_ml_gas_24h' are incorrect, since they refer to percentages in gas!!!!
query_combined = """
SELECT
    s5g."31b_no" as no,
    s5i."10_requisitioner_1" as requisitioner,
    s5i."10_ciat_lab_id" as id_lab,
    s5i."10_gene_bank_breeding_program_id" as id,
    s5i."10_order" as tax_order,
    s5i."10_family" as family,
    s5i."10_genus" as genus,
    s5i."10_species" as species,
    s5i."10_tax_name" as tax_name,
    s5i."10_functional_group" as functional_group,

    s5g."31b_set_ciat" as set_ciat,
    s5g."31b_batch" as batch,
    s5g."31b_run" as run,
    s5g."31b_replication" as replication,
    s5g."31b_syrange_no" as syrange,

    s5g."31b_sample_weight_g" as sample_weight_g,
    s5d."32_undigested_dm_g" as undigested_dm_g,
    s5g."31b_dm_incubated_mg" as dm_incubated,
    s5g."31b_digested_feed_mg" as digested_feed_mg,

    s5g."31b_net_gas_8h_ml" as net_gas_8h_ml,
    s5g."31b_net_gas_24h_ml" as net_gas_24h_ml,
    s5g."31b_ch4_8h_ml" as ch4_8h_ml,
    s5g."31b_ch4_24h_ml" as ch4_24h_ml,
    s5g."31b_ch4_ml_in_gas_8h" as ch4_percentage_in_gas_8h,
    s5g."31b_ch4_ml_in_gas_24h" as ch4_percentage_in_gas_24h,

    s5g."31b_gas_ml_g_dm_incubated_24h_24h" as gas_ml_g_dm_incubated_24h,
    s5g."31b_part_fact" as part_fact,

    s5g."31b_ch4_ml_g_dm_incubated_24h" as ch4_ml_g_dm_incubated_24h,
    s5g."31b_ch4_ml_g_ndf_digested_in_24h" as ch4_ml_g_ndf_digested_24h,
    s5g."31b_ch4_ml_g_dmd_24h" as methane_intensity,
    s5g."31b_percentage_dmd_truly_digestibility" as tddm,


    s5i."10_remarks_1" as information_remarks_1,
    s5i."10_remarks_2" as information_remarks_2,
    s5g."31b_remarks_1" as gas_remarks_1,
    s5g."31b_remarks_2" as gas_remarks_2,
    s5d."32_remarks_1" as digest_remarks_1,
    s5d."32_remarks_2" as digest_remarks_2

FROM subset_5_information_samples AS s5i
JOIN subset_5_gas_prod AS s5g
ON s5i."10_ciat_lab_id" = s5g."31b_ciat_id"

LEFT JOIN subset_5_digest AS s5d
ON s5g."31b_ciat_id" = s5d."32_ciat_id"
AND s5g."31b_no" = s5d."32_no"
AND s5g."31b_replication" = s5d."32_replication"
AND s5g."31b_syrange_no" = s5d."32_syrange_no"

ORDER BY
    CAST(no AS INTEGER) ASC
"""

subset_5_gas_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_5_gas_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#         no requisitioner    id_lab          id tax_order    family  \
# 0        3      Genebank  F26-0043  CIAT-43427   Fabales  Fabaceae
# 1        4      Genebank  F26-0043  CIAT-43427   Fabales  Fabaceae
# 2        5      Genebank  F26-0044    CIAT-601    Poales   Poaceae
# 3        6      Genebank  F26-0044    CIAT-601    Poales   Poaceae
# 4        7      Genebank  F26-0045    CIAT-606    Poales   Poaceae
# ...    ...           ...       ...         ...       ...       ...
# 2527  2092           LMF  F25-0008    Sample-8    Poales   Poaceae
# 2528  2092           LMF  F25-0008    Sample-8    Poales   Poaceae
# 2529  2092           LMF  F25-0008    Sample-8    Poales   Poaceae
# 2530  2092           LMF  F25-0008    Sample-8    Poales   Poaceae
# 2531  2092           LMF  F25-0008    Sample-8    Poales   Poaceae
#
#             genus        species                tax_name functional_group  \
# 0       Desmodium   nicaraguense  Desmodium nicaraguense      Shrub_Trees
# 1       Desmodium   nicaraguense  Desmodium nicaraguense      Shrub_Trees
# 2     Hyparrhenia           rufa        Hyparrhenia rufa            Grass
# 3     Hyparrhenia           rufa        Hyparrhenia rufa            Grass
# 4      Brachiaria      decumbens    Brachiaria decumbens            Grass
# ...           ...            ...                     ...              ...
# 2527      Cynodon   nlemfuensis     Cynodon nlemfuensis             Grass
# 2528      Cynodon   nlemfuensis     Cynodon nlemfuensis              None
# 2529      Cynodon   nlemfuensis     Cynodon nlemfuensis              None
# 2530      Cynodon   nlemfuensis     Cynodon nlemfuensis              None
# 2531      Cynodon   nlemfuensis     Cynodon nlemfuensis             Grass
#
#       ... ch4_ml_g_dm_incubated_24h ch4_ml_g_ndf_digested_24h  \
# 0     ...               22.63676533               10.45739739
# 1     ...               24.03517882               1.136613212
# 2     ...               21.81001731               0.392328927
# 3     ...               22.49531305               0.496308055
# 4     ...               24.65953583                0.62991959
# ...   ...                       ...                       ...
# 2527  ...               20.86644231               0.775826214
# 2528  ...               20.86644231               0.775826214
# 2529  ...               20.86644231               0.775826214
# 2530  ...               20.86644231               0.775826214
# 2531  ...               20.86644231               0.775826214
#
#      methane_intensity         tddm information_remarks_1  \
# 0          59.28538931  38.18270503                  None
# 1          54.75848212  43.89306987                  None
# 2          43.03084146  50.68461729                  None
# 3          47.34103824  47.51757436                  None
# 4          55.36377586  44.54092129                  None
# ...                ...          ...                   ...
# 2527       62.20685088  33.54364031                  None
# 2528       62.20685088  33.54364031                  None
# 2529       62.20685088  33.54364031                  None
# 2530       62.20685088  33.54364031                  None
# 2531       62.20685088  33.54364031                  None
#
#      information_remarks_2                        gas_remarks_1 gas_remarks_2  \
# 0                     None  Se troca el embolo de la jeringa 13          None
# 1                     None                                 None          None
# 2                     None                                 None          None
# 3                     None                                 None          None
# 4                     None                                 None          None
# ...                    ...                                  ...           ...
# 2527                  None                                 None          None
# 2528                  None                                 None          None
# 2529                  None                                 None          None
# 2530                  None                                 None          None
# 2531                  None                                 None          None
#
#                          digest_remarks_1 digest_remarks_2
# 0     Se troca el embolo de la jeringa 13             None
# 1                                    None             None
# 2                                    None             None
# 3                                    None             None
# 4                                    None             None
# ...                                   ...              ...
# 2527                                 None             None
# 2528                                 None             None
# 2529                                 None             None
# 2530                                 None             None
# 2531                                 None             None
#
# [2532 rows x 37 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_5_gas_sorted_by_sql = subset_5_gas_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_5_gas_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_5_gas_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (2310, 37)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab          id tax_order    family        genus  \
# 0  3      Genebank  F26-0043  CIAT-43427   Fabales  Fabaceae    Desmodium
# 1  4      Genebank  F26-0043  CIAT-43427   Fabales  Fabaceae    Desmodium
# 2  5      Genebank  F26-0044    CIAT-601    Poales   Poaceae  Hyparrhenia
# 3  6      Genebank  F26-0044    CIAT-601    Poales   Poaceae  Hyparrhenia
# 4  7      Genebank  F26-0045    CIAT-606    Poales   Poaceae   Brachiaria
#
#         species                tax_name functional_group  ...  \
# 0  nicaraguense  Desmodium nicaraguense      Shrub_Trees  ...
# 1  nicaraguense  Desmodium nicaraguense      Shrub_Trees  ...
# 2          rufa        Hyparrhenia rufa            Grass  ...
# 3          rufa        Hyparrhenia rufa            Grass  ...
# 4     decumbens    Brachiaria decumbens            Grass  ...
#
#   ch4_ml_g_dm_incubated_24h ch4_ml_g_ndf_digested_24h methane_intensity  \
# 0               22.63676533               10.45739739       59.28538931
# 1               24.03517882               1.136613212       54.75848212
# 2               21.81001731               0.392328927       43.03084146
# 3               22.49531305               0.496308055       47.34103824
# 4               24.65953583                0.62991959       55.36377586
#
#           tddm information_remarks_1 information_remarks_2  \
# 0  38.18270503                  None                  None
# 1  43.89306987                  None                  None
# 2  50.68461729                  None                  None
# 3  47.51757436                  None                  None
# 4  44.54092129                  None                  None
#
#                          gas_remarks_1 gas_remarks_2  \
# 0  Se troca el embolo de la jeringa 13          None
# 1                                 None          None
# 2                                 None          None
# 3                                 None          None
# 4                                 None          None
#
#                       digest_remarks_1 digest_remarks_2
# 0  Se troca el embolo de la jeringa 13             None
# 1                                 None             None
# 2                                 None             None
# 3                                 None             None
# 4                                 None             None
#
# [5 rows x 37 columns]

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 5
subset_5_gas_sorted_by_sql.insert(0, 'subset', 5)

print("DataFrame with new 'subset' column:")
display(subset_5_gas_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab          id tax_order    family  \
# 0       5  3      Genebank  F26-0043  CIAT-43427   Fabales  Fabaceae
# 1       5  4      Genebank  F26-0043  CIAT-43427   Fabales  Fabaceae
# 2       5  5      Genebank  F26-0044    CIAT-601    Poales   Poaceae
# 3       5  6      Genebank  F26-0044    CIAT-601    Poales   Poaceae
# 4       5  7      Genebank  F26-0045    CIAT-606    Poales   Poaceae
#
#          genus       species                tax_name  ...  \
# 0    Desmodium  nicaraguense  Desmodium nicaraguense  ...
# 1    Desmodium  nicaraguense  Desmodium nicaraguense  ...
# 2  Hyparrhenia          rufa        Hyparrhenia rufa  ...
# 3  Hyparrhenia          rufa        Hyparrhenia rufa  ...
# 4   Brachiaria     decumbens    Brachiaria decumbens  ...
#
#   ch4_ml_g_dm_incubated_24h ch4_ml_g_ndf_digested_24h methane_intensity  \
# 0               22.63676533               10.45739739       59.28538931
# 1               24.03517882               1.136613212       54.75848212
# 2               21.81001731               0.392328927       43.03084146
# 3               22.49531305               0.496308055       47.34103824
# 4               24.65953583                0.62991959       55.36377586
#
#           tddm information_remarks_1 information_remarks_2  \
# 0  38.18270503                  None                  None
# 1  43.89306987                  None                  None
# 2  50.68461729                  None                  None
# 3  47.51757436                  None                  None
# 4  44.54092129                  None                  None
#
#                          gas_remarks_1 gas_remarks_2  \
# 0  Se troca el embolo de la jeringa 13          None
# 1                                 None          None
# 2                                 None          None
# 3                                 None          None
# 4                                 None          None
#
#                       digest_remarks_1 digest_remarks_2
# 0  Se troca el embolo de la jeringa 13             None
# 1                                 None             None
# 2                                 None             None
# 3                                 None             None
# 4                                 None             None
#
# [5 rows x 38 columns]

# %%
subset_5_gas_sorted_by_sql.to_csv('gas5.csv', index=None)

# %% [markdown]
# ### 5.3.2 Nutrition

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_5_information_samples.to_sql('subset_5_information_samples', conn_new, if_exists='replace', index=False)
subset_5_nutrition.to_sql('subset_5_nutrition', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_5_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner_1',
#        '10_requisitioner_2', '10_set_ciat', '10_ciat_lab_id',
#        '10_gene_bank_breeding_program_id', '10_genus', '10_species',
#        '10_tax_name', '10_family', '10_order', '10_functional_group',
#        '10_batches_ciat', '10_id_lab', '10_remarks_1', '10_remarks_2'],
#       dtype='object')

# %%
subset_5_nutrition.columns
# Out:
# Index(['40_sample_serial_no', '40_date', '40_requisitioner', '40_set_ciat',
#        '40_ciat_lab_id', '40_gene_bank_breeding_program_id', '40_genus',
#        '40_species', '40_tax_name', '40_family', '40_order',
#        '40_functional_group', '40_dm_percentage', '40_av_dm_105', '40_ash_dm',
#        '40_av_ash_percentage', '40_om_percentage', '40_om_percentage.1',
#        '40_pc_percentage_dm', '40_av_pc_percentage', '40_adf_percentage_dm',
#        '40_av_adf_percentage_dm', '40_ndf_percentage_dm',
#        '40_av_ndf_percentage_dm'],
#       dtype='object')

# %%
query_combined = """
SELECT
    s5n."40_sample_serial_no" as no,
    s5i."10_requisitioner_1" as requisitioner,
    s5i."10_ciat_lab_id" as id_lab,
    s5i."10_gene_bank_breeding_program_id" as id,
    s5i."10_order" as tax_order,
    s5i."10_family" as family,
    s5i."10_genus" as genus,
    s5i."10_species" as species,
    s5i."10_tax_name" as tax_name,
    s5i."10_functional_group" as functional_group,
    s5i."10_set_ciat" as set_ciat,
    s5n."40_dm_percentage" as dm_percentage,
    s5n."40_ash_dm" as ash_dm,
    s5n."40_om_percentage" as om_percentage,
    s5n."40_pc_percentage_dm" as pc_percentage_dm,
    s5n."40_adf_percentage_dm" as adf_percentage_dm,
    s5n."40_ndf_percentage_dm" as ndf_percentage_dm



FROM
    subset_5_information_samples AS s5i
JOIN
    subset_5_nutrition AS s5n
ON
    s5i."10_ciat_lab_id" = s5n."40_ciat_lab_id"
ORDER BY
    CAST(no AS INTEGER) ASC NULLS LAST
"""

subset_5_nutrition_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_5_nutrition_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#        no requisitioner    id_lab          id tax_order    family  \
# 0       1      Genebank  F26-0043  CIAT-43427   Fabales  Fabaceae
# 1       2      Genebank  F26-0043  CIAT-43427   Fabales  Fabaceae
# 2       3      Genebank  F26-0044    CIAT-601    Poales   Poaceae
# 3       4      Genebank  F26-0044    CIAT-601    Poales   Poaceae
# 4       5      Genebank  F26-0045    CIAT-606    Poales   Poaceae
# ..    ...           ...       ...         ...       ...       ...
# 837  None           LMF  F25-0008    Sample-8    Poales   Poaceae
# 838  None           LMF  F25-0008    Sample-8    Poales   Poaceae
# 839  None           LMF  F25-0008    Sample-8    Poales   Poaceae
# 840  None           LMF  F25-0008    Sample-8    Poales   Poaceae
# 841  None           LMF  F25-0008    Sample-8    Poales   Poaceae
#
#            genus        species                tax_name functional_group  \
# 0      Desmodium   nicaraguense  Desmodium nicaraguense      Shrub_Trees
# 1      Desmodium   nicaraguense  Desmodium nicaraguense      Shrub_Trees
# 2    Hyparrhenia           rufa        Hyparrhenia rufa            Grass
# 3    Hyparrhenia           rufa        Hyparrhenia rufa            Grass
# 4     Brachiaria      decumbens    Brachiaria decumbens            Grass
# ..           ...            ...                     ...              ...
# 837      Cynodon   nlemfuensis     Cynodon nlemfuensis             Grass
# 838      Cynodon   nlemfuensis     Cynodon nlemfuensis             Grass
# 839      Cynodon   nlemfuensis     Cynodon nlemfuensis             Grass
# 840      Cynodon   nlemfuensis     Cynodon nlemfuensis             Grass
# 841      Cynodon   nlemfuensis     Cynodon nlemfuensis             Grass
#
#     set_ciat dm_percentage       ash_dm om_percentage pc_percentage_dm  \
# 0         32   96.14077185  9.228180435   90.77181957      19.92066962
# 1         32   96.49140344  9.226335537   90.77366446      19.92066962
# 2         32   92.80071993  15.59978469   84.40021531      16.16407202
# 3         32   92.82430542  15.87195614   84.12804386      16.16407202
# 4         32   96.26224265  13.81500044   86.18499956      14.87095296
# ..       ...           ...          ...           ...              ...
# 837       37   93.64063594  11.32941805   88.67058195      18.77653815
# 838       37   93.82123575  11.49829497   88.50170503             13.1
# 839       37   93.82123575  11.49829497   88.50170503             13.1
# 840       37   93.82123575  11.49829497   88.50170503             13.1
# 841       37   93.82123575  11.49829497   88.50170503             13.1
#
#     adf_percentage_dm ndf_percentage_dm
# 0         31.93755773       62.95859574
# 1         32.06854815       61.97841312
# 2         31.23963872       66.73529486
# 3         31.94758379       66.19551853
# 4         29.18439096       69.44402904
# ..                ...               ...
# 837              37.8             76.05
# 838              37.7             76.05
# 839              37.7             76.05
# 840              37.7             76.05
# 841              37.7             76.05
#
# [842 rows x 17 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_5_nutrition_sorted_by_sql = subset_5_nutrition_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_5_nutrition_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_5_nutrition_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (790, 17)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab          id tax_order    family        genus  \
# 0  1      Genebank  F26-0043  CIAT-43427   Fabales  Fabaceae    Desmodium
# 1  2      Genebank  F26-0043  CIAT-43427   Fabales  Fabaceae    Desmodium
# 2  3      Genebank  F26-0044    CIAT-601    Poales   Poaceae  Hyparrhenia
# 3  4      Genebank  F26-0044    CIAT-601    Poales   Poaceae  Hyparrhenia
# 4  5      Genebank  F26-0045    CIAT-606    Poales   Poaceae   Brachiaria
#
#         species                tax_name functional_group set_ciat  \
# 0  nicaraguense  Desmodium nicaraguense      Shrub_Trees       32
# 1  nicaraguense  Desmodium nicaraguense      Shrub_Trees       32
# 2          rufa        Hyparrhenia rufa            Grass       32
# 3          rufa        Hyparrhenia rufa            Grass       32
# 4     decumbens    Brachiaria decumbens            Grass       32
#
#   dm_percentage       ash_dm om_percentage pc_percentage_dm adf_percentage_dm  \
# 0   96.14077185  9.228180435   90.77181957      19.92066962       31.93755773
# 1   96.49140344  9.226335537   90.77366446      19.92066962       32.06854815
# 2   92.80071993  15.59978469   84.40021531      16.16407202       31.23963872
# 3   92.82430542  15.87195614   84.12804386      16.16407202       31.94758379
# 4   96.26224265  13.81500044   86.18499956      14.87095296       29.18439096
#
#   ndf_percentage_dm
# 0       62.95859574
# 1       61.97841312
# 2       66.73529486
# 3       66.19551853
# 4       69.44402904

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 5
subset_5_nutrition_sorted_by_sql.insert(0, 'subset', 5)

print("DataFrame with new 'subset' column:")
display(subset_5_nutrition_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab          id tax_order    family  \
# 0       5  1      Genebank  F26-0043  CIAT-43427   Fabales  Fabaceae
# 1       5  2      Genebank  F26-0043  CIAT-43427   Fabales  Fabaceae
# 2       5  3      Genebank  F26-0044    CIAT-601    Poales   Poaceae
# 3       5  4      Genebank  F26-0044    CIAT-601    Poales   Poaceae
# 4       5  5      Genebank  F26-0045    CIAT-606    Poales   Poaceae
#
#          genus       species                tax_name functional_group  \
# 0    Desmodium  nicaraguense  Desmodium nicaraguense      Shrub_Trees
# 1    Desmodium  nicaraguense  Desmodium nicaraguense      Shrub_Trees
# 2  Hyparrhenia          rufa        Hyparrhenia rufa            Grass
# 3  Hyparrhenia          rufa        Hyparrhenia rufa            Grass
# 4   Brachiaria     decumbens    Brachiaria decumbens            Grass
#
#   set_ciat dm_percentage       ash_dm om_percentage pc_percentage_dm  \
# 0       32   96.14077185  9.228180435   90.77181957      19.92066962
# 1       32   96.49140344  9.226335537   90.77366446      19.92066962
# 2       32   92.80071993  15.59978469   84.40021531      16.16407202
# 3       32   92.82430542  15.87195614   84.12804386      16.16407202
# 4       32   96.26224265  13.81500044   86.18499956      14.87095296
#
#   adf_percentage_dm ndf_percentage_dm
# 0       31.93755773       62.95859574
# 1       32.06854815       61.97841312
# 2       31.23963872       66.73529486
# 3       31.94758379       66.19551853
# 4       29.18439096       69.44402904

# %% [markdown]
# # Subset 6

# %% [markdown]
# ## 6.1 Loading data

# %%
# Load the CSVs from Drive into pandas DataFrames
subset_6_information_samples = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_6/csv/10_information_samples.csv')
subset_6_gas_prod = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_6/csv/31b_gas_prod_vf.csv')
subset_6_nutrition = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_6/csv/40_result_q_raw_data.csv')
subset_6_digest = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_6/csv/32_digest.csv')

# %% [markdown]
# ## 6.2 Cleaning and formating

# %%
subset_6_digest.columns
# Out:
# Index(['32_no', '32_date_1', '32_date_2', '32_requisitioner',
#        '32_gene_bank_id', '32_genus', '32_species', '32_tax_name', '32_family',
#        '32_order', '32_functional_group', '32_ciat_id', '32_set_ciat',
#        '32_batch', '32_run', '32_replication', '32_syrange_no',
#        '32_bag_weight_g', '32_digested_weight_g', '32_remarks_1',
#        '32_undigested_dm_g', '32_digested_feed_mg',
#        '32_percentage_truly_digestibility', '32_ndf_incubated_mg',
#        '32_ndf_digestibility_mg', '32_percentage_ndf_digestibility_in_24h',
#        '32_remarks_2'],
#       dtype='object')

# %%
# Clean first row containing orignal column names from excel files
subset_6_information_samples = remove_first_row(subset_6_information_samples)
subset_6_gas_prod = remove_first_row(subset_6_gas_prod)
subset_6_nutrition = remove_first_row(subset_6_nutrition)
subset_6_digest = remove_first_row(subset_6_digest)

# Add '-' to lab ids and ensure correct format FXX-XXXX
subset_6_information_samples['10_ciat_lab_id'] = clean_lab_ids(subset_6_information_samples['10_ciat_lab_id'])
subset_6_gas_prod['31b_ciat_id'] = clean_lab_ids(subset_6_gas_prod['31b_ciat_id'])
subset_6_nutrition['40_ciat_lab_id'] = clean_lab_ids(subset_6_nutrition['40_ciat_lab_id'])
subset_6_digest['32_ciat_id'] = clean_lab_ids(subset_6_digest['32_ciat_id'])

# Clean and standardize gene bank and breeding program ids
subset_6_information_samples['10_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_6_information_samples['10_gene_bank_breeding_program_id'])
subset_6_gas_prod['31b_gene_bank_id'] = clean_standardize_ids(subset_6_gas_prod['31b_gene_bank_id'])
subset_6_nutrition['40_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_6_nutrition['40_gene_bank_breeding_program_id'])
subset_6_digest['32_gene_bank_id'] = clean_standardize_ids(subset_6_digest['32_gene_bank_id'])

# %%
# Check functional groups categories
subset_6_information_samples['10_functional_group'].unique()
# Out:
# array(['Grasses', 'Climber', 'Green Meal', 'Compound feed',
#        'Herbaceous_climber', 'Shurb_tree', 'Herbaceous', 'Shurb_Tree',
#        'Arbustivas', nan, 'grasses', 'Trepadoras'], dtype=object)

# %%
# Apply the mapping to centers datt
subset_6_information_samples['10_functional_group'] = subset_6_information_samples['10_functional_group'].replace(functional_group_mapping)

print('Updated functional group counts for subset_6_information_samples:')
display(subset_6_information_samples['10_functional_group'].value_counts())
# Out:
# Updated functional group counts for subset_6_information_samples:
# 10_functional_group
# Grass                 173
# Herbaceous_legumes     77
# Shrub_Trees            34
# Green Meal              3
# Compound feed           3
# Name: count, dtype: int64

# %%
subset_6_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner', '10_set_ciat',
#        '10_ciat_lab_id', '10_gene_bank_breeding_program_id', '10_genus',
#        '10_species', '10_tax_name', '10_family', '10_order',
#        '10_functional_group', '10_batches_ciat', '10_id_lab',
#        '10_observaciones'],
#       dtype='object')

# %% [markdown]
# ## 6.3 SQL query and dataframe creation

# %% [markdown]
# ### 6.3.1. Gas

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_6_information_samples.to_sql('subset_6_information_samples', conn_new, if_exists='replace', index=False)
subset_6_gas_prod.to_sql('subset_6_gas_prod', conn_new, if_exists='replace', index=False)
subset_6_digest.to_sql('subset_6_digest', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_6_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner', '10_set_ciat',
#        '10_ciat_lab_id', '10_gene_bank_breeding_program_id', '10_genus',
#        '10_species', '10_tax_name', '10_family', '10_order',
#        '10_functional_group', '10_batches_ciat', '10_id_lab',
#        '10_observaciones'],
#       dtype='object')

# %%
subset_6_digest.columns
# Out:
# Index(['32_no', '32_date_1', '32_date_2', '32_requisitioner',
#        '32_gene_bank_id', '32_genus', '32_species', '32_tax_name', '32_family',
#        '32_order', '32_functional_group', '32_ciat_id', '32_set_ciat',
#        '32_batch', '32_run', '32_replication', '32_syrange_no',
#        '32_bag_weight_g', '32_digested_weight_g', '32_remarks_1',
#        '32_undigested_dm_g', '32_digested_feed_mg',
#        '32_percentage_truly_digestibility', '32_ndf_incubated_mg',
#        '32_ndf_digestibility_mg', '32_percentage_ndf_digestibility_in_24h',
#        '32_remarks_2'],
#       dtype='object')

# %%
subset_6_gas_prod.columns
# Out:
# Index(['31b_no', '31b_date', '31b_requisitioner', '31b_gene_bank_id',
#        '31b_genus', '31b_species', '3b_tax_name', '31b_family', '31b_order',
#        '31b_functional_group', '31b_ciat_id', '31b_set_ciat', '31b_batch',
#        '31b_run', '31b_replication', '31b_syrange_no', '31b_sample_weight_g',
#        '31b_dm_incubated_mg', '31b_digested_feed_mg', '31b_time_0h',
#        '31b_gas_0h_ml', '31b_time_8h', '31b_gas_8h_ml',
#        '31b_ch4_8h_percentage', '31b_v8_push_back_ml', '31b_time_24h',
#        '31b_gas_24h_ml', '31b_ch4_24h_percentage', '31b_remarks',
#        '31b_gp_8h_ml', '31b_8_24h_ml', '31b_net_gas_8h_ml',
#        '31b_net_gas_8_24h_ml', '31b_net_gas_24h_ml', '31b_ch4_8h_ml',
#        '31b_ch4_8_24h_ml', '31b_ch4_24h_ml', '31b_gas_ml_g_dm_incubated_24h',
#        '31b_percentage_dmd_truly_digestibility', '31b_part_fact',
#        '31b_ch4_ml_in_gas_8h', '31b_ch4_ml_in_gas_24h',
#        '31b_ch4_ml_g_dm_incubated_24h', '31b_ch4_ml_g_dmd_24h',
#        '31b_ch4_ml_g_ndf_digested_in_24h', '31b_ch4_g_g_dm_incubated_24h',
#        '31b_ch4_g_g_dmd_24h', '31b_remarks_2'],
#       dtype='object')

# %%
query_combined = """
SELECT
    s6g."31b_no" as no,
    s6i."10_requisitioner" as requisitioner,
    s6i."10_ciat_lab_id" as id_lab,
    s6i."10_gene_bank_breeding_program_id" as id,
    s6i."10_order" as tax_order,
    s6i."10_family" as family,
    s6i."10_genus" as genus,
    s6i."10_species" as species,
    s6i."10_tax_name" as tax_name,
    s6i."10_functional_group" as functional_group,

    s6g."31b_set_ciat" as set_ciat,
    s6g."31b_batch" as batch,
    s6g."31b_run" as run,
    s6g."31b_replication" as replication,
    s6g."31b_syrange_no" as syrange,

    s6g."31b_sample_weight_g" as sample_weight_g,
    s6d."32_undigested_dm_g" as undigested_dm_g,
    s6g."31b_dm_incubated_mg" as dm_incubated,
    s6g."31b_digested_feed_mg" as digested_feed_mg,

    s6g."31b_net_gas_8h_ml" as net_gas_8h_ml,
    s6g."31b_net_gas_24h_ml" as net_gas_24h_ml,
    s6g."31b_ch4_8h_ml" as ch4_8h_ml,
    s6g."31b_ch4_24h_ml" as ch4_24h_ml,
    s6g."31b_ch4_ml_in_gas_8h" as ch4_percentage_in_gas_8h,
    s6g."31b_ch4_ml_in_gas_24h" as ch4_percentage_in_gas_24h,

    s6g."31b_gas_ml_g_dm_incubated_24h" as gas_ml_g_dm_incubated_24h,
    s6g."31b_part_fact" as part_fact,

    s6g."31b_ch4_ml_g_dm_incubated_24h" as ch4_ml_g_dm_incubated_24h,
    s6g."31b_ch4_ml_g_ndf_digested_in_24h" as ch4_ml_g_ndf_digested_24h,
    s6g."31b_ch4_ml_g_dmd_24h" as methane_intensity,
    s6g."31b_percentage_dmd_truly_digestibility" as tddm,


    s6i."10_observaciones" as information_remarks_1,
    s6i."10_observaciones" as information_remarks_2,
    s6g."31b_remarks" as gas_remarks_1,
    s6g."31b_remarks_2" as gas_remarks_2,
    s6d."32_remarks_1" as digest_remarks_1,
    s6d."32_remarks_2" as digest_remarks_2

FROM subset_6_information_samples AS s6i
JOIN subset_6_gas_prod AS s6g
ON s6i."10_ciat_lab_id" = s6g."31b_ciat_id"

LEFT JOIN subset_6_digest AS s6d
ON s6g."31b_ciat_id" = s6d."32_ciat_id"
AND s6g."31b_no" = s6d."32_no"
AND s6g."31b_replication" = s6d."32_replication"
AND s6g."31b_syrange_no" = s6d."32_syrange_no"

ORDER BY
    CAST(no AS INTEGER) ASC
"""

subset_6_gas_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_6_gas_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#         no                     requisitioner    id_lab          id tax_order  \
# 0        3                           GENBANK  F26-0108  CIAT-36090    Poales
# 1        4                           GENBANK  F26-0108  CIAT-36090    Poales
# 2        5                           GENBANK  F26-0429    CIAT-795   Fabales
# 3        6                           GENBANK  F26-0429    CIAT-795   Fabales
# 4        7                           GENBANK  F26-0432    CIAT-966   Fabales
# ...    ...                               ...       ...         ...       ...
# 2041  1868  JACOBO ARANGO/ ALEJANDRO MONTOYA  F25-0008    Sample-8    Poales
# 2042  1868  JACOBO ARANGO/ ALEJANDRO MONTOYA  F25-0008    Sample-8    Poales
# 2043  1868  JACOBO ARANGO/ ALEJANDRO MONTOYA  F25-0008    Sample-8    Poales
# 2044  1868  JACOBO ARANGO/ ALEJANDRO MONTOYA  F25-0008    Sample-8    Poales
# 2045  1868  JACOBO ARANGO/ ALEJANDRO MONTOYA  F25-0008    Sample-8    Poales
#
#         family       genus        species               tax_name  \
# 0      Poaceae    Cenchrus       ciliaris      Cenchrus ciliaris
# 1      Poaceae    Cenchrus       ciliaris      Cenchrus ciliaris
# 2     Fabaceae  Rhynchosia     reticulata  Rhynchosia reticulata
# 3     Fabaceae  Rhynchosia     reticulata  Rhynchosia reticulata
# 4     Fabaceae    Teramnus       labialis      Teramnus labialis
# ...        ...         ...            ...                    ...
# 2041   Poaceae     Cynodon   nlemfuensis    Cynodon nlemfuensis
# 2042   Poaceae     Cynodon   nlemfuensis    Cynodon nlemfuensis
# 2043   Poaceae     Cynodon   nlemfuensis    Cynodon nlemfuensis
# 2044   Poaceae     Cynodon   nlemfuensis    Cynodon nlemfuensis
# 2045   Poaceae     Cynodon   nlemfuensis    Cynodon nlemfuensis
#
#         functional_group  ... ch4_ml_g_dm_incubated_24h  \
# 0                  Grass  ...               20.60528911
# 1                  Grass  ...               22.38231888
# 2     Herbaceous_legumes  ...               17.32210284
# 3     Herbaceous_legumes  ...               16.38702625
# 4     Herbaceous_legumes  ...               21.84652279
# ...                  ...  ...                       ...
# 2041                None  ...                23.2630901
# 2042                None  ...                23.2630901
# 2043                None  ...                23.2630901
# 2044                None  ...                23.2630901
# 2045                None  ...                23.2630901
#
#      ch4_ml_g_ndf_digested_24h methane_intensity         tddm  \
# 0                  0.676308123       44.77179421  46.02292463
# 1                  0.496244417       44.80376225  49.95633795
# 2                  -0.41915907       66.17733297  26.17528097
# 3                 -0.480500285       57.94601684  28.27981481
# 4                 -2.257548054       49.46667177  44.16412506
# ...                        ...               ...          ...
# 2041               0.536728737       59.03751525  39.40391123
# 2042               0.536728737       59.03751525  39.40391123
# 2043               0.536728737       59.03751525  39.40391123
# 2044               0.536728737       59.03751525  39.40391123
# 2045               0.536728737       59.03751525  39.40391123
#
#      information_remarks_1 information_remarks_2 gas_remarks_1 gas_remarks_2  \
# 0                     None                  None             0          None
# 1                     None                  None          None          None
# 2                     None                  None          None          None
# 3                     None                  None          None          None
# 4                     None                  None          None          None
# ...                    ...                   ...           ...           ...
# 2041                  None                  None          None          None
# 2042                  None                  None          None          None
# 2043                  None                  None          None          None
# 2044                  None                  None          None          None
# 2045                  None                  None          None          None
#
#      digest_remarks_1 digest_remarks_2
# 0                None             None
# 1                None             None
# 2                None             None
# 3                None             None
# 4                None             None
# ...               ...              ...
# 2041             None             None
# 2042             None             None
# 2043             None             None
# 2044             None             None
# 2045             None             None
#
# [2046 rows x 37 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_6_gas_sorted_by_sql = subset_6_gas_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_6_gas_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_6_gas_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (1794, 37)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab          id tax_order    family       genus  \
# 0  3       GENBANK  F26-0108  CIAT-36090    Poales   Poaceae    Cenchrus
# 1  4       GENBANK  F26-0108  CIAT-36090    Poales   Poaceae    Cenchrus
# 2  5       GENBANK  F26-0429    CIAT-795   Fabales  Fabaceae  Rhynchosia
# 3  6       GENBANK  F26-0429    CIAT-795   Fabales  Fabaceae  Rhynchosia
# 4  7       GENBANK  F26-0432    CIAT-966   Fabales  Fabaceae    Teramnus
#
#       species               tax_name    functional_group  ...  \
# 0    ciliaris      Cenchrus ciliaris               Grass  ...
# 1    ciliaris      Cenchrus ciliaris               Grass  ...
# 2  reticulata  Rhynchosia reticulata  Herbaceous_legumes  ...
# 3  reticulata  Rhynchosia reticulata  Herbaceous_legumes  ...
# 4    labialis      Teramnus labialis  Herbaceous_legumes  ...
#
#   ch4_ml_g_dm_incubated_24h ch4_ml_g_ndf_digested_24h methane_intensity  \
# 0               20.60528911               0.676308123       44.77179421
# 1               22.38231888               0.496244417       44.80376225
# 2               17.32210284               -0.41915907       66.17733297
# 3               16.38702625              -0.480500285       57.94601684
# 4               21.84652279              -2.257548054       49.46667177
#
#           tddm information_remarks_1 information_remarks_2 gas_remarks_1  \
# 0  46.02292463                  None                  None             0
# 1  49.95633795                  None                  None          None
# 2  26.17528097                  None                  None          None
# 3  28.27981481                  None                  None          None
# 4  44.16412506                  None                  None          None
#
#   gas_remarks_2 digest_remarks_1 digest_remarks_2
# 0          None             None             None
# 1          None             None             None
# 2          None             None             None
# 3          None             None             None
# 4          None             None             None
#
# [5 rows x 37 columns]

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 6
subset_6_gas_sorted_by_sql.insert(0, 'subset', 6)

print("DataFrame with new 'subset' column:")
display(subset_6_gas_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab          id tax_order    family  \
# 0       6  3       GENBANK  F26-0108  CIAT-36090    Poales   Poaceae
# 1       6  4       GENBANK  F26-0108  CIAT-36090    Poales   Poaceae
# 2       6  5       GENBANK  F26-0429    CIAT-795   Fabales  Fabaceae
# 3       6  6       GENBANK  F26-0429    CIAT-795   Fabales  Fabaceae
# 4       6  7       GENBANK  F26-0432    CIAT-966   Fabales  Fabaceae
#
#         genus     species               tax_name  ...  \
# 0    Cenchrus    ciliaris      Cenchrus ciliaris  ...
# 1    Cenchrus    ciliaris      Cenchrus ciliaris  ...
# 2  Rhynchosia  reticulata  Rhynchosia reticulata  ...
# 3  Rhynchosia  reticulata  Rhynchosia reticulata  ...
# 4    Teramnus    labialis      Teramnus labialis  ...
#
#   ch4_ml_g_dm_incubated_24h ch4_ml_g_ndf_digested_24h methane_intensity  \
# 0               20.60528911               0.676308123       44.77179421
# 1               22.38231888               0.496244417       44.80376225
# 2               17.32210284               -0.41915907       66.17733297
# 3               16.38702625              -0.480500285       57.94601684
# 4               21.84652279              -2.257548054       49.46667177
#
#           tddm information_remarks_1 information_remarks_2 gas_remarks_1  \
# 0  46.02292463                  None                  None             0
# 1  49.95633795                  None                  None          None
# 2  26.17528097                  None                  None          None
# 3  28.27981481                  None                  None          None
# 4  44.16412506                  None                  None          None
#
#   gas_remarks_2 digest_remarks_1 digest_remarks_2
# 0          None             None             None
# 1          None             None             None
# 2          None             None             None
# 3          None             None             None
# 4          None             None             None
#
# [5 rows x 38 columns]

# %%
subset_6_gas_sorted_by_sql.to_csv('gas6.csv', index=None)

# %% [markdown]
# ### 6.3.2 Nutrition

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_6_information_samples.to_sql('subset_6_information_samples', conn_new, if_exists='replace', index=False)
subset_6_nutrition.to_sql('subset_6_nutrition', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_6_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner', '10_set_ciat',
#        '10_ciat_lab_id', '10_gene_bank_breeding_program_id', '10_genus',
#        '10_species', '10_tax_name', '10_family', '10_order',
#        '10_functional_group', '10_batches_ciat', '10_id_lab',
#        '10_observaciones'],
#       dtype='object')

# %%
subset_6_nutrition.columns
# Out:
# Index(['40_sample_serial_no', '40_date', '40_requisitioner', '40_set_ciat',
#        '40_ciat_lab_id', '40_gene_bank_breeding_program_id', '40_genus',
#        '40_species', '40_tax_name', '40_family', '40_order',
#        '40_functional_group', '40_dm_percentage', '40_av_dm_105', '40_ash_dm',
#        '40_av_ash_percentage', '40_om_percentage', '40_av_om_percentage',
#        '40_pc_percentage_dm', '40_av_pc_percentage', '40_adf_percentage_dm',
#        '40_av_adf_percentage_dm', '40_ndf_percentage_dm',
#        '40_av_ndf_percentage_dm'],
#       dtype='object')

# %%
query_combined = """
SELECT
    s6n."40_sample_serial_no" as no,
    s6i."10_requisitioner" as requisitioner,
    s6i."10_ciat_lab_id" as id_lab,
    s6i."10_gene_bank_breeding_program_id" as id,
    s6i."10_order" as tax_order,
    s6i."10_family" as family,
    s6i."10_genus" as genus,
    s6i."10_species" as species,
    s6i."10_tax_name" as tax_name,
    s6i."10_functional_group" as functional_group,
    s6i."10_set_ciat" as set_ciat,
    s6n."40_dm_percentage" as dm_percentage,
    s6n."40_ash_dm" as ash_dm,
    s6n."40_om_percentage" as om_percentage,
    s6n."40_pc_percentage_dm" as pc_percentage_dm,
    s6n."40_adf_percentage_dm" as adf_percentage_dm,
    s6n."40_ndf_percentage_dm" as ndf_percentage_dm



FROM
    subset_6_information_samples AS s6i
JOIN
    subset_6_nutrition AS s6n
ON
    s6i."10_ciat_lab_id" = s6n."40_ciat_lab_id"
ORDER BY
    CAST(no AS INTEGER) ASC NULLS LAST
"""

subset_6_nutrition_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_6_nutrition_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#        no                     requisitioner    id_lab          id tax_order  \
# 0       1                           GENBANK  F26-0108  CIAT-36090    Poales
# 1       2                           GENBANK  F26-0108  CIAT-36090    Poales
# 2       3                           GENBANK  F26-0429    CIAT-795   Fabales
# 3       4                           GENBANK  F26-0429    CIAT-795   Fabales
# 4       5                           GENBANK  F26-0432    CIAT-966   Fabales
# ..    ...                               ...       ...         ...       ...
# 677  None  JACOBO ARANGO/ ALEJANDRO MONTOYA  F25-0008    Sample-8    Poales
# 678  None  JACOBO ARANGO/ ALEJANDRO MONTOYA  F25-0008    Sample-8    Poales
# 679  None  JACOBO ARANGO/ ALEJANDRO MONTOYA  F25-0008    Sample-8    Poales
# 680  None  JACOBO ARANGO/ ALEJANDRO MONTOYA  F25-0008    Sample-8    Poales
# 681  None  JACOBO ARANGO/ ALEJANDRO MONTOYA  F25-0008    Sample-8    Poales
#
#        family       genus        species               tax_name  \
# 0     Poaceae    Cenchrus       ciliaris      Cenchrus ciliaris
# 1     Poaceae    Cenchrus       ciliaris      Cenchrus ciliaris
# 2    Fabaceae  Rhynchosia     reticulata  Rhynchosia reticulata
# 3    Fabaceae  Rhynchosia     reticulata  Rhynchosia reticulata
# 4    Fabaceae    Teramnus       labialis      Teramnus labialis
# ..        ...         ...            ...                    ...
# 677   Poaceae     Cynodon   nlemfuensis    Cynodon nlemfuensis
# 678   Poaceae     Cynodon   nlemfuensis    Cynodon nlemfuensis
# 679   Poaceae     Cynodon   nlemfuensis    Cynodon nlemfuensis
# 680   Poaceae     Cynodon   nlemfuensis    Cynodon nlemfuensis
# 681   Poaceae     Cynodon   nlemfuensis    Cynodon nlemfuensis
#
#        functional_group set_ciat dm_percentage       ash_dm om_percentage  \
# 0                 Grass       38          86.4        15.88         84.12
# 1                 Grass       38         86.34         15.6          84.4
# 2    Herbaceous_legumes       38   94.71211515  90.28316564   9.716834355
# 3    Herbaceous_legumes       38         94.78  90.18428815   9.815711849
# 4    Herbaceous_legumes       38   92.77072293  88.42650522   11.57349478
# ..                  ...      ...           ...          ...           ...
# 677                None       42   93.82123575  11.49829497   88.50170503
# 678                None       42   93.82123575  11.49829497   88.50170503
# 679                None       42   93.82123575  11.49829497   88.50170503
# 680                None       42   93.82123575  11.49829497   88.50170503
# 681                None       42   93.82123575  11.49829497   88.50170503
#
#     pc_percentage_dm adf_percentage_dm ndf_percentage_dm
# 0              17.78             35.88             61.83
# 1              17.78              37.5             62.48
# 2        16.71865494       46.93440679       61.56917235
# 3        16.71865494       46.23998851       61.90292306
# 4        18.12297408       37.58843795       53.69561175
# ..               ...               ...               ...
# 677             13.1              37.7             76.05
# 678             13.1              37.7             76.05
# 679             13.1              37.7             76.05
# 680             13.1              37.7             76.05
# 681             13.1              37.7             76.05
#
# [682 rows x 17 columns]
# SQLite connection closed.

# %%
# Remove duplicate rows, keeping the first occurrence
subset_6_nutrition_sorted_by_sql = subset_6_nutrition_sorted_by_sql.drop_duplicates(keep='first')

print("Shape of DataFrame after removing duplicates (keeping first):", subset_6_nutrition_sorted_by_sql.shape)
print("First 5 rows of DataFrame without duplicates (keeping first):")
display(subset_6_nutrition_sorted_by_sql.head())
# Out:
# Shape of DataFrame after removing duplicates (keeping first): (602, 17)
# First 5 rows of DataFrame without duplicates (keeping first):
#   no requisitioner    id_lab          id tax_order    family       genus  \
# 0  1       GENBANK  F26-0108  CIAT-36090    Poales   Poaceae    Cenchrus
# 1  2       GENBANK  F26-0108  CIAT-36090    Poales   Poaceae    Cenchrus
# 2  3       GENBANK  F26-0429    CIAT-795   Fabales  Fabaceae  Rhynchosia
# 3  4       GENBANK  F26-0429    CIAT-795   Fabales  Fabaceae  Rhynchosia
# 4  5       GENBANK  F26-0432    CIAT-966   Fabales  Fabaceae    Teramnus
#
#       species               tax_name    functional_group set_ciat  \
# 0    ciliaris      Cenchrus ciliaris               Grass       38
# 1    ciliaris      Cenchrus ciliaris               Grass       38
# 2  reticulata  Rhynchosia reticulata  Herbaceous_legumes       38
# 3  reticulata  Rhynchosia reticulata  Herbaceous_legumes       38
# 4    labialis      Teramnus labialis  Herbaceous_legumes       38
#
#   dm_percentage       ash_dm om_percentage pc_percentage_dm adf_percentage_dm  \
# 0          86.4        15.88         84.12            17.78             35.88
# 1         86.34         15.6          84.4            17.78              37.5
# 2   94.71211515  90.28316564   9.716834355      16.71865494       46.93440679
# 3         94.78  90.18428815   9.815711849      16.71865494       46.23998851
# 4   92.77072293  88.42650522   11.57349478      18.12297408       37.58843795
#
#   ndf_percentage_dm
# 0             61.83
# 1             62.48
# 2       61.56917235
# 3       61.90292306
# 4       53.69561175

# %%
# Add a new column 'subset' at the beginning of the DataFrame with value 6
subset_6_nutrition_sorted_by_sql.insert(0, 'subset', 6)

print("DataFrame with new 'subset' column:")
display(subset_6_nutrition_sorted_by_sql.head())
# Out:
# DataFrame with new 'subset' column:
#    subset no requisitioner    id_lab          id tax_order    family  \
# 0       6  1       GENBANK  F26-0108  CIAT-36090    Poales   Poaceae
# 1       6  2       GENBANK  F26-0108  CIAT-36090    Poales   Poaceae
# 2       6  3       GENBANK  F26-0429    CIAT-795   Fabales  Fabaceae
# 3       6  4       GENBANK  F26-0429    CIAT-795   Fabales  Fabaceae
# 4       6  5       GENBANK  F26-0432    CIAT-966   Fabales  Fabaceae
#
#         genus     species               tax_name    functional_group set_ciat  \
# 0    Cenchrus    ciliaris      Cenchrus ciliaris               Grass       38
# 1    Cenchrus    ciliaris      Cenchrus ciliaris               Grass       38
# 2  Rhynchosia  reticulata  Rhynchosia reticulata  Herbaceous_legumes       38
# 3  Rhynchosia  reticulata  Rhynchosia reticulata  Herbaceous_legumes       38
# 4    Teramnus    labialis      Teramnus labialis  Herbaceous_legumes       38
#
#   dm_percentage       ash_dm om_percentage pc_percentage_dm adf_percentage_dm  \
# 0          86.4        15.88         84.12            17.78             35.88
# 1         86.34         15.6          84.4            17.78              37.5
# 2   94.71211515  90.28316564   9.716834355      16.71865494       46.93440679
# 3         94.78  90.18428815   9.815711849      16.71865494       46.23998851
# 4   92.77072293  88.42650522   11.57349478      18.12297408       37.58843795
#
#   ndf_percentage_dm
# 0             61.83
# 1             62.48
# 2       61.56917235
# 3       61.90292306
# 4       53.69561175

# %% [markdown]
# # Subset 1H

# %% [markdown]
# ## 1H.1 Loading data

# %%
# Load the CSVs from Drive into pandas DataFrames
subset_1h_information_samples = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_1h/csv/10_information_samples.csv')
subset_1h_gas_prod = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_1h/csv/40_result_gp_raw_data_vf.csv')
subset_1h_dm = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_1h/csv/21_dm.csv')
subset_1h_digest = pd.read_csv('/content/drive/MyDrive/lmf/data/2026_09_24_sql_data_frame_creation_with_curated_subsets/subset_1h/csv/32_digest.csv')

# %% [markdown]
# ## 1H.2 Cleaning and formating

# %%
# Clean first row containing orignal column names from excel files
subset_1h_information_samples = remove_first_row(subset_1h_information_samples)
subset_1h_gas_prod = remove_first_row(subset_1h_gas_prod)
subset_1h_dm = remove_first_row(subset_1h_dm)
subset_1h_digest = remove_first_row(subset_1h_digest)

# Add '-' to lab ids and ensure correct format FXX-XXXX
subset_1h_information_samples['10_ciat_lab_id'] = clean_lab_ids(subset_1h_information_samples['10_ciat_lab_id'])
subset_1h_gas_prod['40_ciat_id'] = clean_lab_ids(subset_1h_gas_prod['40_ciat_id'])
subset_1h_dm['21_ciat_lab_id'] = clean_lab_ids(subset_1h_dm['21_ciat_lab_id'])
subset_1h_digest['32_ciat_id'] = clean_lab_ids(subset_1h_digest['32_ciat_id'])

# Clean and standardize gene bank and breeding program ids
subset_1h_information_samples['10_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_1h_information_samples['10_gene_bank_breeding_program_id'])
subset_1h_gas_prod['40_gene_bank_id'] = clean_standardize_ids(subset_1h_gas_prod['40_gene_bank_id'])
subset_1h_dm['21_gene_bank_breeding_program_id'] = clean_standardize_ids(subset_1h_dm['21_gene_bank_breeding_program_id'])
subset_1h_digest['32_gene_bank_id'] = clean_standardize_ids(subset_1h_digest['32_gene_bank_id'])

# %%
# Check functional groups categories
subset_1h_information_samples['10_functional_group'].unique()
# Out:
# array(['grasses', nan], dtype=object)

# %%
# Apply the mapping to centers datt
subset_1h_information_samples['10_functional_group'] = subset_1h_information_samples['10_functional_group'].replace(functional_group_mapping)

print('Updated functional group counts for subset_1h_information_samples:')
display(subset_1h_information_samples['10_functional_group'].value_counts())
# Out:
# Updated functional group counts for subset_1h_information_samples:
# 10_functional_group
# Grass    6
# Name: count, dtype: int64

# %% [markdown]
# ## 1H.3 SQL query and dataframe creation

# %% [markdown]
# ### 1H.3.1 Gas

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subset_1h_information_samples.to_sql('subset_1h_information_samples', conn_new, if_exists='replace', index=False)
subset_1h_gas_prod.to_sql('subset_1h_gas_prod', conn_new, if_exists='replace', index=False)
subset_1h_digest.to_sql('subset_1h_digest', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subset_1h_digest.columns
# Out:
# Index(['32_no', '32_date', '32_gene_bank_id', '32_tax_name', '32_family',
#        '32_order', '32_genus2', '32_species3', '32_functional_group',
#        '32_ciat_id', '32_set_ciat', '32_batch', '32_run', '32_replication',
#        '32_syrange_no', '32_bag_weight_g', '32_digested_weight_g',
#        '32_remarks_1', '32_undigested_dm_g', '32_digested_feed_mg',
#        '32_percentage_dmd_truly_digestibility', '32_ndf_incubated_mg',
#        '32_ndf_digestibility_mg', '32_percentage_ndf_digestibility_in_24_h',
#        '32_remarks_2'],
#       dtype='object')

# %%
subset_1h_information_samples.columns
# Out:
# Index(['10_sample_serial_no', '10_date', '10_requisitioner', '10_set_ciat',
#        '10_ciat_lab_id', '10_gene_bank_breeding_program_id', '10_genus',
#        '10_species', '10_tax_name', '10_family', '10_order',
#        '10_functional_group', '10_remarks_1', '10_id_lab', '10_remarks_2'],
#       dtype='object')

# %%
subset_1h_gas_prod.columns
# Out:
# Index(['40_no', '40_date', '40_requisitioner', '40_gene_bank_id',
#        '40_tax_name', '40_family', '40_order', '40_genus2', '40_species3',
#        '40_functional_group', '40_ciat_id', '40_set_ciat', '40_batch',
#        '40_run', '40_replication', '40_syrange_no', '40_net_gas_8h_ml',
#        '40_net_gas_8_24h_ml2', '40_net_gas_24h_ml', '40_ch4_8h_ml',
#        '40_ch4_8_24h_ml', '40_ch4_24h_ml', '40_gas_ml_g_md_incubated_24h',
#        '40_percentage_dmd_truly_digestibility', '40_part_fact',
#        '40_ch4_ml_in_gas_8h', '40_ch4_ml_in_gas_24h',
#        '40_ch4_ml_g_dm_incubated_24h', '40_ch4_ml_g_dmd_24h',
#        '40_ch4_ml_g_ndf_digested_in_24h', '40_ch4_g_g_dm_incubated_24h',
#        '40_ch4_g_dmd_24h'],
#       dtype='object')

# %%
query_combined = """
SELECT
    s1hg."40_no" as no,
    s1hi."10_requisitioner" as requisitioner,
    s1hi."10_ciat_lab_id" as id_lab,
    s1hi."10_gene_bank_breeding_program_id" as id,
    s1hi."10_order" as tax_order,
    s1hi."10_family" as family,
    s1hi."10_genus" as genus,
    s1hi."10_species" as species,
    s1hi."10_tax_name" as tax_name,
    s1hi."10_functional_group" as functional_group,

    s1hg."40_set_ciat" as set_ciat,
    s1hg."40_batch" as batch,
    s1hg."40_run" as run,
    s1hg."40_replication" as replication,
    s1hg."40_syrange_no" as syrange,

    s1hg." " as sample_weight_g,
    s1hd."32_undigested_dm_g" as undigested_dm_g,
    s1hg."" as dm_incubated,
    s1hd."32_digested_feed_mg" as digested_feed_mg,

    s1hg."40_net_gas_8h_ml" as net_gas_8h_ml,
    s1hg."40_net_gas_24h_ml" as net_gas_24h_ml,
    s1hg."40_ch4_8h_ml" as ch4_8h_ml,
    s1hg."40_ch4_24h_ml" as ch4_24h_ml,
    s6g."31b_ch4_ml_in_gas_8h" as ch4_percentage_in_gas_8h,
    s6g."31b_ch4_ml_in_gas_24h" as ch4_percentage_in_gas_24h,

    s6g."31b_gas_ml_g_dm_incubated_24h" as gas_ml_g_dm_incubated_24h,
    s6g."31b_part_fact" as part_fact,

    s6g."31b_ch4_ml_g_dm_incubated_24h" as ch4_ml_g_dm_incubated_24h,
    s6g."31b_ch4_ml_g_ndf_digested_in_24h" as ch4_ml_g_ndf_digested_24h,
    s6g."31b_ch4_ml_g_dmd_24h" as methane_intensity,
    s6g."31b_percentage_dmd_truly_digestibility" as tddm,


    s6i."10_observaciones" as information_remarks_1,
    s6i."10_observaciones" as information_remarks_2,
    s6g."31b_remarks" as gas_remarks_1,
    s6g."31b_remarks_2" as gas_remarks_2,
    s6d."32_remarks_1" as digest_remarks_1,
    s6d."32_remarks_2" as digest_remarks_2

FROM subset_6_information_samples AS s6i
JOIN subset_6_gas_prod AS s6g
ON s6i."10_ciat_lab_id" = s6g."31b_ciat_id"

LEFT JOIN subset_6_digest AS s6d
ON s6g."31b_ciat_id" = s6d."32_ciat_id"
AND s6g."31b_no" = s6d."32_no"
AND s6g."31b_replication" = s6d."32_replication"
AND s6g."31b_syrange_no" = s6d."32_syrange_no"

ORDER BY
    CAST(no AS INTEGER) ASC
"""

subset_6_gas_sorted_by_sql  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(subset_6_gas_sorted_by_sql)

conn_new.close()
print("\nSQLite connection closed.")

# %% [markdown]
# ### 1H.3.2 Nutrition

# %% [markdown]
# # IV. Data frames compilation

# %% [markdown]
# ## IV.A. Gas compilation (all samples)

# %%
subsets_1_2_3_4_gas_sorted_by_sql = pd.concat([
    subset_1_gas_sorted_by_sql,
    subset_2_gas_sorted_by_sql,
    subset_3_gas_sorted_by_sql,
    subset_4_gas_sorted_by_sql
], ignore_index=True)

subsets_1_2_3_4_gas_sorted_by_sql.tail()
# Out:
#       subset    no                     requisitioner    id_lab  \
# 7985       4  1216                          Breeding  F25-2166
# 7986       4  1217   Jacobo Arango/Alejandro Montoya  F25-0008
# 7987       4  1217  Jacobo Arango/ Alejandro Montoya  F25-0008
# 7988       4  1218   Jacobo Arango/Alejandro Montoya  F25-0008
# 7989       4  1218  Jacobo Arango/ Alejandro Montoya  F25-0008
#
#                    id tax_order   family     genus        species  \
# 7985  CIAT-BH-22-0528    Poales  Poaceae  Urochloa     humidicola
# 7986         Sample-8    Poales  Poaceae   Cynodon   nlemfuensis
# 7987         Sample-8    Poales  Poaceae   Cynodon   nlemfuensis
# 7988         Sample-8    Poales  Poaceae   Cynodon   nlemfuensis
# 7989         Sample-8    Poales  Poaceae   Cynodon   nlemfuensis
#
#                   tax_name  ... ch4_ml_g_dm_incubated_24h  \
# 7985   Urochloa humidicola  ...               26.53298459
# 7986  Cynodon nlemfuensis   ...               23.68140318
# 7987  Cynodon nlemfuensis   ...               23.68140318
# 7988  Cynodon nlemfuensis   ...               24.06079675
# 7989  Cynodon nlemfuensis   ...               24.06079675
#
#      ch4_ml_g_ndf_digested_24h methane_intensity         tddm  \
# 7985                0.77427287       68.31835898  38.83726861
# 7986               0.709198924       66.12652784  35.81225864
# 7987               0.709198924       66.12652784  35.81225864
# 7988                0.93285091       72.69629761  33.09769209
# 7989                0.93285091       72.69629761  33.09769209
#
#      information_remarks_1 information_remarks_2 gas_remarks_1 gas_remarks_2  \
# 7985                  None                  None          None          None
# 7986                  None                  None          None          None
# 7987                  None                  None          None          None
# 7988                  None                  None          None          None
# 7989                  None                  None          None          None
#
#      digest_remarks_1 digest_remarks_2
# 7985             None             None
# 7986             None             None
# 7987             None             None
# 7988             None             None
# 7989             None             None
#
# [5 rows x 38 columns]

# %%
#subsets_1_2_3_4_gas_sorted_by_sql.to_csv('/content/drive/MyDrive/lmf/output/2026_06_05_sql_data_frame_creation_with_curated_subsets/subsets_1_2_3_4_gas_sorted_by_sql.csv', index = None)

# %% [markdown]
# ## IV.B. Nutrition compilation

# %%
subsets_1_2_3_4_nutrition_sorted_by_sql = pd.concat([
    subset_1_nutrition_sorted_by_sql,
    subset_2_nutrition_sorted_by_sql,
    subset_3_nutrition_sorted_by_sql,
    subset_4_nutrition_sorted_by_sql
], ignore_index=True)

subsets_1_2_3_4_nutrition_sorted_by_sql.tail()
# Out:
#       subset    no                     requisitioner    id_lab  \
# 1909       4  None                          Breeding  F25-2104
# 1910       4  None                          Breeding  F25-2166
# 1911       4  None                          Breeding  F25-2166
# 1912       4  None  Jacobo Arango/ Alejandro Montoya  F25-0008
# 1913       4  None  Jacobo Arango/ Alejandro Montoya  F25-0008
#
#                    id tax_order   family     genus          species  \
# 1909  CIAT-BR-06-1348    Poales  Poaceae  Urochloa  interespecifico
# 1910  CIAT-BH-22-0528    Poales  Poaceae  Urochloa       humidicola
# 1911  CIAT-BH-22-0528    Poales  Poaceae  Urochloa       humidicola
# 1912         Sample-8    Poales  Poaceae   Cynodon     nlemfuensis
# 1913         Sample-8    Poales  Poaceae   Cynodon     nlemfuensis
#
#                         tax_name functional_group set_ciat dm_percentage  \
# 1909  Brachiaria interespecifico            Grass       30         93.16
# 1910         Urochloa humidicola            Grass       30          98.2
# 1911         Urochloa humidicola            Grass       30         98.22
# 1912        Cynodon nlemfuensis             Grass       30          93.6
# 1913        Cynodon nlemfuensis             Grass       30          93.8
#
#      ash_dm om_percentage pc_percentage_dm adf_percentage_dm ndf_percentage_dm
# 1909  14.68         85.32            12.18             25.85             60.28
# 1910  12.48         87.52              8.8             36.63             73.37
# 1911  15.08         84.92             8.73             36.96             73.74
# 1912   11.3          88.7             13.1              37.8              76.1
# 1913   11.5          88.5             13.1              37.8              76.1

# %%
#subsets_1_2_3_4_nutrition_sorted_by_sql.to_csv('/content/drive/MyDrive/lmf/output/2026_06_05_sql_data_frame_creation_with_curated_subsets/subsets_1_2_3_4_nutrition_sorted_by_sql.csv', index = None)

# %% [markdown]
# # V. Dashboards

# %% [markdown]
# ## V.A. Gas

# %%
#Columns processing

category_columns = ['subset', 'no', 'requisitioner', 'id_lab', 'id', 'tax_order', 'family',
       'genus', 'species', 'tax_name', 'functional_group', 'set_ciat', 'batch',
       'run', 'replication', 'syrange']
numeric_columns = ['sample_weight_g', 'undigested_dm_g', 'dm_incubated', 'digested_feed_mg' ,'net_gas_8h_ml', 'net_gas_24h_ml',
       'ch4_8h_ml', 'ch4_24h_ml', 'ch4_percentage_in_gas_8h', 'ch4_percentage_in_gas_24h','part_fact', 'ch4_ml_g_dm_incubated_24h',
       'ch4_ml_g_ndf_digested_24h', 'methane_intensity', 'tddm']

for df in [subset_1_gas_sorted_by_sql, subset_2_gas_sorted_by_sql, subset_3_gas_sorted_by_sql, subset_4_gas_sorted_by_sql]:
    for col in category_columns:
        if col in df.columns:
            df[col] = df[col].astype('category')
    for col in numeric_columns:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
#Group by id and calculate columns average and number of replicates
def mean_with_replicates(df, numeric_columns):
    mean_df = df.groupby('id')[numeric_columns].mean().round(2)
    mean_df['n_replicates'] = df.groupby('id').size()
    return mean_df.reset_index()

subset_1_gas_sorted_by_sql_mean = mean_with_replicates(subset_1_gas_sorted_by_sql, numeric_columns)
subset_2_gas_sorted_by_sql_mean = mean_with_replicates(subset_2_gas_sorted_by_sql, numeric_columns)
subset_3_gas_sorted_by_sql_mean = mean_with_replicates(subset_3_gas_sorted_by_sql, numeric_columns)
subset_4_gas_sorted_by_sql_mean = mean_with_replicates(subset_4_gas_sorted_by_sql, numeric_columns)
# Out:
# /tmp/ipykernel_6065/1419611704.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_df = df.groupby('id')[numeric_columns].mean().round(2)
# /tmp/ipykernel_6065/1419611704.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_df['n_replicates'] = df.groupby('id').size()
# /tmp/ipykernel_6065/1419611704.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_df = df.groupby('id')[numeric_columns].mean().round(2)
# /tmp/ipykernel_6065/1419611704.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_df['n_replicates'] = df.groupby('id').size()
# /tmp/ipykernel_6065/1419611704.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_df = df.groupby('id')[numeric_columns].mean().round(2)
# /tmp/ipykernel_6065/1419611704.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_df['n_replicates'] = df.groupby('id').size()
# /tmp/ipykernel_6065/1419611704.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_df = df.groupby('id')[numeric_columns].mean().round(2)
# /tmp/ipykernel_6065/1419611704.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_df['n_replicates'] = df.groupby('id').size()

# %%
subset_1_gas_sorted_by_sql_mean
# Out:
#                     id  sample_weight_g  undigested_dm_g  dm_incubated  \
# 0    AMC-ICARDA-156302              0.5             0.13        454.49
# 1    AMC-ICARDA-165072              0.5             0.20        454.34
# 2    AMC-ICARDA-168125              0.5             0.26        454.34
# 3           CIAT-10647              0.5             0.15        464.95
# 4           CIAT-11194              0.5             0.19        464.74
# ..                 ...              ...              ...           ...
# 204           Sample-4              0.5             0.27        483.79
# 205           Sample-5              0.5             0.30        485.19
# 206           Sample-6              0.5             0.31        473.11
# 207           Sample-7              0.5             0.32        480.25
# 208           Sample-8              0.5             0.33        468.87
#
#      digested_feed_mg  net_gas_8h_ml  net_gas_24h_ml  ch4_8h_ml  ch4_24h_ml  \
# 0              327.23          37.76           86.99       6.03       14.08
# 1              257.98          43.07           86.99       6.19       14.43
# 2              192.31          30.24           61.77       4.70       10.30
# 3              313.10          43.31           79.20       6.90       14.88
# 4              275.35          33.85           70.41       5.14       12.69
# ..                ...            ...             ...        ...         ...
# 204            216.22          26.40           69.44       3.86       10.72
# 205            181.59          25.37           63.83       3.66        9.87
# 206            162.71          24.93           64.72       3.59       10.10
# 207            156.38          25.67           63.98       3.62        9.60
# 208            137.07          19.77           49.45       2.91        8.05
#
#      ch4_percentage_in_gas_8h  ch4_percentage_in_gas_24h  part_fact  \
# 0                       15.97                      16.19       3.75
# 1                       14.37                      16.59       2.97
# 2                       15.53                      16.67       3.12
# 3                       15.90                      18.79       3.95
# 4                       15.17                      18.02       3.91
# ..                        ...                        ...        ...
# 204                     14.63                      15.44       3.11
# 205                     14.43                      15.46       2.85
# 206                     14.40                      15.61       2.51
# 207                     14.10                      15.00       2.44
# 208                     14.73                      16.27       2.77
#
#      ch4_ml_g_dm_incubated_24h  ch4_ml_g_ndf_digested_24h  methane_intensity  \
# 0                        30.99                     -25.03              43.67
# 1                        31.76                       0.00              56.12
# 2                        22.66                       0.00              55.10
# 3                        32.01                     151.04              48.31
# 4                        27.31                     184.66              46.12
# ..                         ...                        ...                ...
# 204                      22.16                       0.00              49.69
# 205                      20.33                       0.00              56.36
# 206                      21.35                       0.00              65.00
# 207                      19.98                       0.00              64.07
# 208                      17.17                       0.00              68.02
#
#       tddm  n_replicates
# 0    72.00             3
# 1    56.78             3
# 2    42.32             3
# 3    67.34             6
# 4    59.25             6
# ..     ...           ...
# 204  44.69             3
# 205  37.43             3
# 206  34.39             3
# 207  32.56             3
# 208  29.24             6
#
# [209 rows x 17 columns]

# %% [markdown]
# ### V.A.1. Complete

# %%
subset_1_gas_sorted_by_sql
# Out:
#      subset     no requisitioner    id_lab                       id  \
# 0         1  #REF!           LMF  F25-0017  Hohenheimer-Heustandard
# 1         1  #REF!           LMF  F25-0017  Hohenheimer-Heustandard
# 2         1  #REF!           LMF  F25-0017  Hohenheimer-Heustandard
# 3         1  #REF!           LMF  F25-0018    Homenheim-Concentrate
# 4         1  #REF!           LMF  F25-0018    Homenheim-Concentrate
# ...     ...    ...           ...       ...                      ...
# 2171      1   1627           LMF  F25-0019                 Sample-8
# 2172      1   1628           LMF  F25-0019                 Sample-8
# 2177      1   1628           LMF  F25-0019                 Sample-8
# 2178      1   1629           LMF  F25-0019                 Sample-8
# 2183      1   1629           LMF  F25-0019                 Sample-8
#
#         tax_order       family        genus        species  \
# 0          Forage       Forage  Hohenheimer    Heustandard
# 1          Forage       Forage  Hohenheimer    Heustandard
# 2          Forage       Forage  Hohenheimer    Heustandard
# 3     Concentrate  Concentrate    Homenheim    Concentrate
# 4     Concentrate  Concentrate    Homenheim    Concentrate
# ...           ...          ...          ...            ...
# 2171       Poales      Poaceae      Cynodon   nlemfuensis
# 2172       Poales      Poaceae      Cynodon   nlemfuensis
# 2177       Poales      Poaceae      Cynodon   nlemfuensis
# 2178       Poales      Poaceae      Cynodon   nlemfuensis
# 2183       Poales      Poaceae      Cynodon   nlemfuensis
#
#                      tax_name  ... ch4_ml_g_dm_incubated_24h  \
# 0     Hohenheimer Heustandard  ...                 33.240646
# 1     Hohenheimer Heustandard  ...                 32.485469
# 2     Hohenheimer Heustandard  ...                 33.705053
# 3       Homenheim Concentrate  ...                 44.140303
# 4       Homenheim Concentrate  ...                 42.179575
# ...                       ...  ...                       ...
# 2171     Cynodon nlemfuensis   ...                 17.727803
# 2172     Cynodon nlemfuensis   ...                 17.563005
# 2177     Cynodon nlemfuensis   ...                 17.563005
# 2178     Cynodon nlemfuensis   ...                 16.209367
# 2183     Cynodon nlemfuensis   ...                 16.209367
#
#      ch4_ml_g_ndf_digested_24h methane_intensity       tddm  \
# 0                          0.0         95.437541  34.829738
# 1                          0.0         89.752008  36.194699
# 2                          0.0         59.213980  56.920768
# 3                          0.0         70.132004  62.938887
# 4                          0.0         70.453273  59.868865
# ...                        ...               ...        ...
# 2171                       0.0         45.657236  38.828024
# 2172                       0.0        108.919905  16.124697
# 2177                       0.0        108.919905  16.124697
# 2178                       0.0         49.483514  32.757105
# 2183                       0.0         49.483514  32.757105
#
#      information_remarks_1 information_remarks_2  gas_remarks_1  \
# 0                  Standar                  None           None
# 1                  Standar                  None           None
# 2                  Standar                  None           None
# 3                  Standar                  None           None
# 4                  Standar                  None           None
# ...                    ...                   ...            ...
# 2171               Standar                OT-002           None
# 2172               Standar                  None           None
# 2177               Standar                OT-002           None
# 2178               Standar                  None           None
# 2183               Standar                OT-002           None
#
#       gas_remarks_2  digest_remarks_1  digest_remarks_2
# 0              None              None              None
# 1              None              None              None
# 2              None              None              None
# 3              None              None              None
# 4              None              None              None
# ...             ...               ...               ...
# 2171           None              None              None
# 2172           None              None              None
# 2177           None              None              None
# 2178           None              None              None
# 2183           None              None              None
#
# [1938 rows x 38 columns]

# %%
def summarize_by_id(df, category_columns, numeric_columns):
    """
    Group by 'id', keep the first value for categorical columns,
    calculate the mean for numeric columns, count replicates,
    exclude the 'no' column, and place subset, id and n_replicates
    as the first columns.
    """

    agg_functions = {}

    # For categorical columns, keep the first value within each group.
    # Exclude 'id' (grouping key) and 'no' (row identifier).
    for col in category_columns:
        if col not in ['id']:
            agg_functions[col] = (col, 'first')

    # For numeric columns, calculate the mean within each group
    for col in numeric_columns:
        agg_functions[col] = (col, 'mean')

    # Count the number of replicates (rows) per id
    agg_functions['n_replicates'] = ('id', 'size')

    # Group by id and apply all aggregations
    result = (
        df.groupby('id', observed=False)
        .agg(**agg_functions)
        .round(2)
        .reset_index()
    )

    # Reorder columns so that subset, id and n_replicates appear first
    first_columns = [	'subset','requisitioner', 'no','id_lab',	'id',	 'n_replicates']
    remaining_columns = [
        col for col in result.columns
        if col not in first_columns
    ]

    result = result[first_columns + remaining_columns]

    return result

# %%
subset_1_gas_sorted_by_sql_mean = summarize_by_id(subset_1_gas_sorted_by_sql, category_columns, numeric_columns)
subset_2_gas_sorted_by_sql_mean = summarize_by_id(subset_2_gas_sorted_by_sql, category_columns, numeric_columns)
subset_3_gas_sorted_by_sql_mean = summarize_by_id(subset_3_gas_sorted_by_sql, category_columns, numeric_columns)
subset_4_gas_sorted_by_sql_mean = summarize_by_id(subset_4_gas_sorted_by_sql, category_columns, numeric_columns)

# %%
subsets_1_2_3_4_gas_dashboard_complete = pd.concat([
    subset_1_gas_sorted_by_sql_mean,
    subset_2_gas_sorted_by_sql_mean,
    subset_3_gas_sorted_by_sql_mean,
    subset_4_gas_sorted_by_sql_mean
], ignore_index=True)

subsets_1_2_3_4_gas_dashboard_complete
# Out:
#      subset                    requisitioner     no    id_lab  \
# 0         1                              LMF  #REF!  F25-0769
# 1         1                              LMF  #REF!  F25-0770
# 2         1                              LMF  #REF!  F25-0773
# 3         1                     Genetic bank    715  F24-3469
# 4         1                     Genetic bank    718  F24-3470
# ..      ...                              ...    ...       ...
# 725       4                          Genbank    348  F25-2187
# 726       4                         Breeding   1066  F25-2104
# 727       4                    Isabel Molina     95  F25-2640
# 728       4  Jacobo Arango/Alejandro Montoya    101  F25-0008
# 729       4                  Mauricio Sotelo     98  F25-2641
#
#                     id  n_replicates tax_order    family         genus  \
# 0    AMC-ICARDA-156302             3   Fabales  Fabaceae     Trifolium
# 1    AMC-ICARDA-165072             3       NaN       NaN        Vicia
# 2    AMC-ICARDA-168125             3       NaN       NaN      Lathyrus
# 3           CIAT-10647             6   Fabales  Fabaceae  Stylosanthes
# 4           CIAT-11194             6   Fabales  Fabaceae  Stylosanthes
# ..                 ...           ...       ...       ...           ...
# 725    CIAT-BH-22-3830             8    Poales   Poaceae      Urochloa
# 726    CIAT-BR-06-1348             7    Poales   Poaceae      Urochloa
# 727  Cayman-Br-02-1752             8    Poales   Poaceae      Urochloa
# 728           Sample-8            70    Poales   Poaceae       Cynodon
# 729                nan             8   Fabales  Fabaceae  Gliricidia
#
#              species  ... net_gas_24h_ml ch4_8h_ml ch4_24h_ml  \
# 0             repens  ...          86.99      6.03      14.08
# 1         tenuifolia  ...          86.99      6.19      14.43
# 2         sylvestris  ...          61.77      4.70      10.30
# 3             scabra  ...          79.20      6.90      14.88
# 4             hamata  ...          70.41      5.14      12.69
# ..               ...  ...            ...       ...        ...
# 725       humidicola  ...          97.36      5.64      14.42
# 726  interespecifico  ...          89.04      5.29      12.99
# 727  interespecifico  ...          88.29      5.11      11.80
# 728     nlemfuensis   ...          59.62      3.34       9.43
# 729           sepium  ...          78.54      5.15      11.77
#
#     ch4_percentage_in_gas_8h ch4_percentage_in_gas_24h part_fact  \
# 0                      15.97                     16.19      3.75
# 1                      14.37                     16.59      2.97
# 2                      15.53                     16.67      3.12
# 3                      15.90                     18.79      3.95
# 4                      15.17                     18.02      3.91
# ..                       ...                       ...       ...
# 725                    13.90                     14.78      2.00
# 726                    13.46                     14.59      2.86
# 727                    12.99                     13.37      2.76
# 728                    14.95                     15.78      2.11
# 729                    13.69                     14.98      3.33
#
#     ch4_ml_g_dm_incubated_24h  ch4_ml_g_ndf_digested_24h  methane_intensity  \
# 0                       30.99                     -25.03              43.67
# 1                       31.76                       0.00              56.12
# 2                       22.66                       0.00              55.10
# 3                       32.01                     151.04              48.31
# 4                       27.31                     184.66              46.12
# ..                        ...                        ...                ...
# 725                     30.03                       0.76              75.10
# 726                     27.90                       0.63              51.50
# 727                     24.32                      -4.20              50.17
# 728                     20.15                       0.46              86.08
# 729                     25.16                      -3.09              45.48
#
#       tddm
# 0    72.00
# 1    56.78
# 2    42.32
# 3    67.34
# 4    59.25
# ..     ...
# 725  40.80
# 726  54.58
# 727  50.22
# 728  27.04
# 729  55.91
#
# [730 rows x 32 columns]

# %%
#subsets_1_2_3_4_gas_dashboard_complete.to_csv('subsets_1_2_3_4_gas_dashboard_complete.csv', index=None)

# %% [markdown]
# ### V.A.2. Small

# %%
subsets_1_2_3_4_gas_dashboard_complete.columns
# Out:
# Index(['subset', 'requisitioner', 'no', 'id_lab', 'id', 'n_replicates',
#        'tax_order', 'family', 'genus', 'species', 'tax_name',
#        'functional_group', 'set_ciat', 'batch', 'run', 'replication',
#        'syrange', 'sample_weight_g', 'undigested_dm_g', 'dm_incubated',
#        'digested_feed_mg', 'net_gas_8h_ml', 'net_gas_24h_ml', 'ch4_8h_ml',
#        'ch4_24h_ml', 'ch4_percentage_in_gas_8h', 'ch4_percentage_in_gas_24h',
#        'part_fact', 'ch4_ml_g_dm_incubated_24h', 'ch4_ml_g_ndf_digested_24h',
#        'methane_intensity', 'tddm'],
#       dtype='object')

# %%
subsets_1_2_3_4_gas_dashboard_small = subsets_1_2_3_4_gas_dashboard_complete[['subset', 'id_lab', 'id', 'tax_name', 'functional_group', 'ch4_percentage_in_gas_8h', 'ch4_percentage_in_gas_24h', 'methane_intensity', 'tddm']]
subsets_1_2_3_4_gas_dashboard_small
# Out:
#      subset    id_lab                 id                    tax_name  \
# 0         1  F25-0769  AMC-ICARDA-156302            Trifolium repens
# 1         1  F25-0770  AMC-ICARDA-165072            Vicia tenuifolia
# 2         1  F25-0773  AMC-ICARDA-168125         Lathyrus sylvestris
# 3         1  F24-3469         CIAT-10647         Stylosanthes scabra
# 4         1  F24-3470         CIAT-11194         Stylosanthes hamata
# ..      ...       ...                ...                         ...
# 725       4  F25-2187    CIAT-BH-22-3830         Urochloa humidicola
# 726       4  F25-2104    CIAT-BR-06-1348  Brachiaria interespecifico
# 727       4  F25-2640  Cayman-Br-02-1752    Urochloa interespecifico
# 728       4  F25-0008           Sample-8        Cynodon nlemfuensis
# 729       4  F25-2641                nan          Gliricidia sepium
#
#        functional_group  ch4_percentage_in_gas_8h  ch4_percentage_in_gas_24h  \
# 0    Herbaceous_legumes                     15.97                      16.19
# 1                   NaN                     14.37                      16.59
# 2                   NaN                     15.53                      16.67
# 3    Herbaceous_legumes                     15.90                      18.79
# 4    Herbaceous_legumes                     15.17                      18.02
# ..                  ...                       ...                        ...
# 725               Grass                     13.90                      14.78
# 726               Grass                     13.46                      14.59
# 727               Grass                     12.99                      13.37
# 728               Grass                     14.95                      15.78
# 729         Shrub_Trees                     13.69                      14.98
#
#      methane_intensity   tddm
# 0                43.67  72.00
# 1                56.12  56.78
# 2                55.10  42.32
# 3                48.31  67.34
# 4                46.12  59.25
# ..                 ...    ...
# 725              75.10  40.80
# 726              51.50  54.58
# 727              50.17  50.22
# 728              86.08  27.04
# 729              45.48  55.91
#
# [730 rows x 9 columns]

# %%
#subsets_1_2_3_4_gas_dashboard_small.to_csv('subsets_1_2_3_4_gas_dashboard_small.csv', index=None)

# %% [markdown]
# ## V.B. Nutrition

# %%
subset_1_nutrition_sorted_by_sql.columns
# Out:
# Index(['subset', 'no', 'requisitioner', 'id_lab', 'id', 'tax_order', 'family',
#        'genus', 'species', 'tax_name', 'functional_group', 'set_ciat',
#        'dm_percentage', 'ash_dm', 'om_percentage', 'pc_percentage_dm',
#        'adf_percentage_dm', 'ndf_percentage_dm'],
#       dtype='object')

# %%
#Columns processing

category_columns = ['subset', 'no', 'requisitioner', 'id_lab', 'id', 'tax_order', 'family',
       'genus', 'species', 'tax_name', 'functional_group', 'set_ciat']
numeric_columns = ['dm_percentage', 'ash_dm', 'om_percentage', 'pc_percentage_dm',
       'adf_percentage_dm', 'ndf_percentage_dm']

for df in [subset_1_nutrition_sorted_by_sql, subset_2_nutrition_sorted_by_sql, subset_3_nutrition_sorted_by_sql, subset_4_nutrition_sorted_by_sql]:
    for col in category_columns:
        if col in df.columns:
            df[col] = df[col].astype('category')
    for col in numeric_columns:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
subset_1_nutrition_dashboard = summarize_by_id(subset_1_nutrition_sorted_by_sql, category_columns, numeric_columns)
subset_2_nutrition_dashboard = summarize_by_id(subset_2_nutrition_sorted_by_sql, category_columns, numeric_columns)
subset_3_nutrition_dashboard = summarize_by_id(subset_3_nutrition_sorted_by_sql, category_columns, numeric_columns)
subset_4_nutrition_dashboard = summarize_by_id(subset_4_nutrition_sorted_by_sql, category_columns, numeric_columns)

# %%
subsets_1_2_3_4_nutrition_dashboard_complete = pd.concat([
    subset_1_nutrition_dashboard,
    subset_2_nutrition_dashboard,
    subset_3_nutrition_dashboard,
    subset_4_nutrition_dashboard
], ignore_index=True)

subsets_1_2_3_4_nutrition_dashboard_complete
# Out:
#      subset                    requisitioner   no    id_lab  \
# 0         1                     Genetic bank  197  F24-3469
# 1         1                     Genetic bank  199  F24-3470
# 2         1                     Genetic bank  201  F24-3471
# 3         1                     Genetic bank  203  F24-3472
# 4         1                     Genetic bank  113  F24-3427
# ..      ...                              ...  ...       ...
# 687       4                          Genbank  109  F25-2187
# 688       4                         Breeding  NaN  F25-2104
# 689       4                    Isabel Molina   61  F25-2640
# 690       4  Jacobo Arango/Alejandro Montoya   65  F25-0008
# 691       4                  Mauricio Sotelo   63  F25-2641
#
#                     id  n_replicates tax_order    family         genus  \
# 0           CIAT-10647             2   Fabales  Fabaceae  Stylosanthes
# 1           CIAT-11194             2   Fabales  Fabaceae  Stylosanthes
# 2           CIAT-11999             2   Fabales  Fabaceae  Stylosanthes
# 3           CIAT-12318             2   Fabales  Fabaceae  Stylosanthes
# 4            CIAT-1257             2   Fabales  Fabaceae  Stylosanthes
# ..                 ...           ...       ...       ...           ...
# 687    CIAT-BH-22-3830             2    Poales   Poaceae      Urochloa
# 688    CIAT-BR-06-1348             2    Poales   Poaceae      Urochloa
# 689  Cayman-Br-02-1752             2    Poales   Poaceae      Urochloa
# 690           Sample-8            50    Poales   Poaceae       Cynodon
# 691                nan             2   Fabales  Fabaceae  Gliricidia
#
#              species                    tax_name    functional_group set_ciat  \
# 0             scabra         Stylosanthes scabra  Herbaceous_legumes        6
# 1             hamata         Stylosanthes hamata  Herbaceous_legumes        6
# 2         guianensis     Stylosanthes guianensis  Herbaceous_legumes        7
# 3             hamata         Stylosanthes hamata  Herbaceous_legumes        7
# 4             scabra         Stylosanthes scabra  Herbaceous_legumes        5
# ..               ...                         ...                 ...      ...
# 687       humidicola         Urochloa humidicola               Grass       28
# 688  interespecifico  Brachiaria interespecifico               Grass       30
# 689  interespecifico    Urochloa interespecifico               Grass       27
# 690     nlemfuensis         Cynodon nlemfuensis                Grass       27
# 691           sepium          Gliricidia sepium          Shrub_Trees       27
#
#      dm_percentage  ash_dm  om_percentage  pc_percentage_dm  \
# 0            92.93    9.36          90.64             20.02
# 1            92.89    9.61          90.39             21.18
# 2            93.50   10.46          89.54             20.09
# 3            94.10   11.08          88.92             22.05
# 4            92.72    9.52          90.48             17.96
# ..             ...     ...            ...               ...
# 687          95.96   10.19          89.81              8.04
# 688          93.09   14.48          85.52             12.22
# 689          97.00    9.65          90.35              8.05
# 690          93.58   11.40          88.60              2.62
# 691          93.50    9.41          90.59             22.38
#
#      adf_percentage_dm  ndf_percentage_dm
# 0                32.44              56.19
# 1                30.18              55.94
# 2                33.90              61.32
# 3                29.34              55.26
# 4                35.90              69.91
# ..                 ...                ...
# 687              32.62              67.43
# 688              25.64              59.76
# 689              26.24              62.13
# 690               7.56              76.10
# 691              21.94              47.20
#
# [692 rows x 19 columns]

# %%
#subsets_1_2_3_4_nutrition_dashboard_complete.to_csv('subsets_1_2_3_4_nutrition_dashboard_complete.csv', index=None)

# %% [markdown]
# ## V.C. Calculated Methane Intensity and TDDM

# %%
# Reconnect to an in-memory SQLite database (since it was closed previously)
conn_new = sqlite3.connect(':memory:')

# Reload the pandas DataFrames into SQL tables in the database
subsets_1_2_3_4_gas_dashboard_complete.to_sql('gas', conn_new, if_exists='replace', index=False)
subsets_1_2_3_4_nutrition_dashboard_complete.to_sql('nutrition', conn_new, if_exists='replace', index=False)

print("DataFrames reloaded as tables in SQLite.")
# Out:
# DataFrames reloaded as tables in SQLite.

# %%
subsets_1_2_3_4_gas_dashboard_complete.columns
# Out:
# Index(['subset', 'requisitioner', 'no', 'id_lab', 'id', 'n_replicates',
#        'tax_order', 'family', 'genus', 'species', 'tax_name',
#        'functional_group', 'set_ciat', 'batch', 'run', 'replication',
#        'syrange', 'sample_weight_g', 'undigested_dm_g', 'dm_incubated',
#        'digested_feed_mg', 'net_gas_8h_ml', 'net_gas_24h_ml', 'ch4_8h_ml',
#        'ch4_24h_ml', 'ch4_percentage_in_gas_8h', 'ch4_percentage_in_gas_24h',
#        'part_fact', 'ch4_ml_g_dm_incubated_24h', 'ch4_ml_g_ndf_digested_24h',
#        'methane_intensity', 'tddm'],
#       dtype='object')

# %%
subsets_1_2_3_4_nutrition_dashboard_complete.columns
# Out:
# Index(['subset', 'requisitioner', 'no', 'id_lab', 'id', 'n_replicates',
#        'tax_order', 'family', 'genus', 'species', 'tax_name',
#        'functional_group', 'set_ciat', 'dm_percentage', 'ash_dm',
#        'om_percentage', 'pc_percentage_dm', 'adf_percentage_dm',
#        'ndf_percentage_dm'],
#       dtype='object')

# %%
query_combined = """

WITH step_1 AS (

SELECT
    g.*,
    n.dm_percentage/100 as new_dm_ratio,
    (n.dm_percentage/100*g.sample_weight_g*1000) as new_dm_incubated_mg

FROM gas g

LEFT JOIN nutrition n
ON g.id_lab = n.id_lab
AND g.subset = n.subset

),

step_2 AS (

SELECT
    *,
    (new_dm_incubated_mg - (undigested_dm_g*1000)) as new_digested_feed_mg
FROM step_1

)
,
step_3 AS (
SELECT
    *,
    ((ch4_24h_ml/new_digested_feed_mg)*1000) as new_methane_intensity,
    (new_digested_feed_mg/new_dm_incubated_mg)*100 as new_tddm
FROM step_2 )

SELECT
    *,
    (methane_intensity - new_methane_intensity) as diff_methane_intensity,
    (tddm - new_tddm) as diff_tddm
FROM step_3


ORDER BY
    subset,
    id_lab,
    CAST(no AS INTEGER) ASC

"""


calculated_gas  = pd.read_sql_query(query_combined, conn_new)

print("Result of the combined SQL query:")
display(calculated_gas)

conn_new.close()
print("\nSQLite connection closed.")
# Out:
# Result of the combined SQL query:
#      subset requisitioner    no    id_lab          id  n_replicates tax_order  \
# 0         1  Genetic bank     1  F24-3416    CIAT-705             9   Fabales
# 1         1  Genetic bank     4  F24-3417    CIAT-707             9   Fabales
# 2         1  Genetic bank     7  F24-3418    CIAT-712             9   Fabales
# 3         1  Genetic bank    10  F24-3419    CIAT-749             9   Fabales
# 4         1  Genetic bank    13  F24-3420    CIAT-768             9   Fabales
# ..      ...           ...   ...       ...         ...           ...       ...
# 725       4       Genbank  1051  F26-0038  CIAT-19165             7   Fabales
# 726       4       Genbank  1054  F26-0039  CIAT-21899             7   Fabales
# 727       4       Genbank  1057  F26-0040  CIAT-23414             7   Fabales
# 728       4       Genbank  1060  F26-0041  CIAT-23767             7   Fabales
# 729       4       Genbank  1063  F26-0042  CIAT-33127             7   Fabales
#
#        family         genus       species  ... ch4_ml_g_ndf_digested_24h  \
# 0    Fabaceae    Indigofera  suffruticosa  ...                    149.32
# 1    Fabaceae   Alysicarpus   ovalifolius  ...                    125.18
# 2    Fabaceae      Clitoria      ternatea  ...                    153.83
# 3    Fabaceae    Crotalaria        juncea  ...                    150.15
# 4    Fabaceae      Clitoria      ternatea  ...                    134.60
# ..        ...           ...           ...  ...                       ...
# 725  Fabaceae      Sesbania     keniensis  ...                     -8.23
# 726  Fabaceae      Sesbania        sesban  ...                      0.43
# 727  Fabaceae  Codariocalyx      motorius  ...                     -0.58
# 728  Fabaceae     Desmodium  nicaraguense  ...                      1.72
# 729  Fabaceae  Codariocalyx      motorius  ...                       NaN
#
#     methane_intensity   tddm new_dm_ratio new_dm_incubated_mg  \
# 0               31.84  74.34       0.9197              459.85
# 1               36.44  65.97       0.9009              450.45
# 2               40.73  62.66       0.9130              456.50
# 3               35.43  65.15       0.9175              458.75
# 4               39.08  64.82       0.9217              460.85
# ..                ...    ...          ...                 ...
# 725             56.24  44.03       0.9644              482.20
# 726             61.07  36.07       0.9584              479.20
# 727             73.03  26.23       0.9631              481.55
# 728             56.97  46.73       0.9500              475.00
# 729               NaN    NaN       0.9560              478.00
#
#     new_digested_feed_mg new_methane_intensity   new_tddm  \
# 0                 339.85             31.631602  73.904534
# 1                 300.45             35.846231  66.699967
# 2                 286.50             40.453752  62.760131
# 3                 298.75             35.313808  65.122616
# 4                 300.85             38.790095  65.281545
# ..                   ...                   ...        ...
# 725               212.20             54.571159  44.006636
# 726               169.20             60.283688  35.308848
# 727               141.55             63.864359  29.394663
# 728               225.00             55.866667  47.368421
# 729               158.00                   NaN  33.054393
#
#      diff_methane_intensity  diff_tddm
# 0                  0.208398   0.435466
# 1                  0.593769  -0.729967
# 2                  0.276248  -0.100131
# 3                  0.116192   0.027384
# 4                  0.289905  -0.461545
# ..                      ...        ...
# 725                1.668841   0.023364
# 726                0.786312   0.761152
# 727                9.165641  -3.164663
# 728                1.103333  -0.638421
# 729                     NaN        NaN
#
# [730 rows x 39 columns]
# SQLite connection closed.

# %%
# Round values to two decimals
calculated_gas = calculated_gas.round(2)
calculated_gas.head()
# Out:
#    subset requisitioner  no    id_lab        id  n_replicates tax_order  \
# 0       1  Genetic bank   1  F24-3416  CIAT-705             9   Fabales
# 1       1  Genetic bank   4  F24-3417  CIAT-707             9   Fabales
# 2       1  Genetic bank   7  F24-3418  CIAT-712             9   Fabales
# 3       1  Genetic bank  10  F24-3419  CIAT-749             9   Fabales
# 4       1  Genetic bank  13  F24-3420  CIAT-768             9   Fabales
#
#      family        genus       species  ... ch4_ml_g_ndf_digested_24h  \
# 0  Fabaceae   Indigofera  suffruticosa  ...                    149.32
# 1  Fabaceae  Alysicarpus   ovalifolius  ...                    125.18
# 2  Fabaceae     Clitoria      ternatea  ...                    153.83
# 3  Fabaceae   Crotalaria        juncea  ...                    150.15
# 4  Fabaceae     Clitoria      ternatea  ...                    134.60
#
#   methane_intensity   tddm new_dm_ratio new_dm_incubated_mg  \
# 0             31.84  74.34         0.92              459.85
# 1             36.44  65.97         0.90              450.45
# 2             40.73  62.66         0.91              456.50
# 3             35.43  65.15         0.92              458.75
# 4             39.08  64.82         0.92              460.85
#
#   new_digested_feed_mg new_methane_intensity  new_tddm  \
# 0               339.85                 31.63     73.90
# 1               300.45                 35.85     66.70
# 2               286.50                 40.45     62.76
# 3               298.75                 35.31     65.12
# 4               300.85                 38.79     65.28
#
#    diff_methane_intensity  diff_tddm
# 0                    0.21       0.44
# 1                    0.59      -0.73
# 2                    0.28      -0.10
# 3                    0.12       0.03
# 4                    0.29      -0.46
#
# [5 rows x 39 columns]

# %%
calculated_gas.to_csv('calculated_gas.csv', index=None)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.scatter(
    calculated_gas["methane_intensity"],
    calculated_gas["new_methane_intensity"]
)

plt.xlabel("methane_intensity")
plt.ylabel("new_methane_intensity")
plt.title("Scatterplot: Methane Intensity vs New Methane Intensity")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.scatter(
    calculated_gas["tddm"],
    calculated_gas["new_tddm"]
)

plt.xlabel("tddm")
plt.ylabel("new_tddm")
plt.title("Scatterplot: TDDM vs New TDDM")

plt.show()
